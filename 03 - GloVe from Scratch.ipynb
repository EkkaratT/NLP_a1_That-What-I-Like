# %% [markdown]
# # GloVE
#
# Let's work on implementation of GloVE.

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. Define some very simple data for understanding

# %%
import nltk
nltk.download('brown')
# Out:
# [nltk_data] Downloading package brown to
# [nltk_data]     C:\Users\Ekkar\AppData\Roaming\nltk_data...
# [nltk_data]   Package brown is already up-to-date!
# True

# %%
from nltk.corpus import brown

brown.categories()
corpus = brown.sents(categories="news")
corpus
# Out:
# [['The', 'Fulton', 'County', 'Grand', 'Jury', 'said', 'Friday', 'an', 'investigation', 'of', "Atlanta's", 'recent', 'primary', 'election', 'produced', '``', 'no', 'evidence', "''", 'that', 'any', 'irregularities', 'took', 'place', '.'], ['The', 'jury', 'further', 'said', 'in', 'term-end', 'presentments', 'that', 'the', 'City', 'Executive', 'Committee', ',', 'which', 'had', 'over-all', 'charge', 'of', 'the', 'election', ',', '``', 'deserves', 'the', 'praise', 'and', 'thanks', 'of', 'the', 'City', 'of', 'Atlanta', "''", 'for', 'the', 'manner', 'in', 'which', 'the', 'election', 'was', 'conducted', '.'], ...]

# %%
#get word sequences and unique words
flatten = lambda l: [item for sublist in l for item in sublist]
vocab = list(set(flatten(corpus)))
# vocab

# %%
#numericalization
word2index = {w: i for i, w in enumerate(vocab)}
print(word2index)
# Out:
# {'Clearwater': 0, 'rush': 1, 'Indonesia': 2, 'association': 3, 'slashed': 4, "writers'": 5, 'miscount': 6, 'forecasts': 7, 'Griffith-Jones': 8, 'bumper': 9, 'sacker': 10, 'stepping': 11, 'telling': 12, 'infant': 13, 'gloomily': 14, 'India': 15, 'Channel': 16, 'Town': 17, 'Truck': 18, 'suspect': 19, 'Washington-Oregon': 20, 'Souvanna': 21, 'burning': 22, 'temporarily': 23, 'summertime': 24, 'implement': 25, 'thoroughfare': 26, '3,000': 27, '10,000,000': 28, 'struggle': 29, 'nitroglycerine': 30, 'foster': 31, 'Westinghouse': 32, 'came': 33, '15th': 34, 'Greer': 35, 'oft-repeated': 36, 'Lummus': 37, 'specifications': 38, 'confronted': 39, '6,000': 40, 'cleared': 41, 'Ted': 42, 'outrun': 43, 'Greenberg': 44, 'smoldered': 45, 'attends': 46, '$5000': 47, 'posed': 48, 'rebound': 49, 'Tranquility': 50, 'respond': 51, 'grain': 52, 'portrayal': 53, 'forbid': 54, 'Eppler': 55, "Underwood's": 56, 'Flower': 57, 'Basketball': 58, 'white': 59, 'Arlington': 60, 'Corporation': 61, 'Ankara': 62, 'guests': 63, 'pianist': 64, 'Fargo': 65, 'impossibly': 66, 'shoe': 67, 'broadened': 68, 'jolt': 69, 'assemble': 70, 'pops': 71, 'condemned': 72, 'establish': 73, 'Harvey': 74, 'Lt.': 75, '$28,700,000': 76, 'topics': 77, 'Nobody': 78, 'chemistry': 79, 'alternative': 80, 'occasion': 81, 'loomed': 82, 'hopeful': 83, '676': 84, 'Holbrook': 85, 'Macassar': 86, 'executive': 87, 'Mayor': 88, 'grocery': 89, 'honors': 90, 'intervention': 91, 'yellow': 92, 'tardiness': 93, 'figured': 94, 'accounted': 95, 'earns': 96, 'Coopers': 97, 'stand': 98, 'Therefore': 99, 'freight': 100, 'sum': 101, 'Cerebral': 102, 'investigated': 103, 'Outlays': 104, 'Time': 105, 'Young': 106, 'Since': 107, 'chose': 108, 'efficiently': 109, 'availability': 110, 'astray': 111, 'April-June': 112, 'Premier': 113, 'LSU': 114, '5847': 115, 'knew': 116, 'hike': 117, 'Masque': 118, 'high': 119, "year's": 120, 'uncontrolled': 121, 'extensive': 122, 'Sabbath': 123, 'contribs': 124, 'fifth': 125, 'surely': 126, '228-229': 127, 'Award': 128, 'stove': 129, 'Grinsfelder': 130, 'snowfall': 131, 'Indianapolis': 132, 'Mill': 133, 'heartbreaking': 134, 'mechanics': 135, 'Sixty-seven': 136, 'outfit': 137, 'diplomat': 138, 'delay': 139, 'Duren': 140, 'submarine-ball': 141, 'lavishly': 142, 'percentage': 143, 'insist': 144, 'imprudently': 145, 'Clinton': 146, 'Quite': 147, 'medal': 148, 'drafted': 149, 'animated': 150, 'grandchildren': 151, 'rancho': 152, 'congressmen': 153, '27-year-old': 154, '8,280': 155, 'along': 156, 'Homeowners': 157, 'Saul': 158, 'go': 159, 'information': 160, 'moves': 161, 'offer': 162, 'Smythe': 163, 'public': 164, '1945': 165, 'Wellesley': 166, 'Persons': 167, 'museum': 168, 'drastic': 169, 'outnumber': 170, 'productions': 171, 'flies': 172, 'husbands': 173, 'catalogue': 174, 'delighted': 175, 'remarkable': 176, 'NE': 177, 'Camp': 178, 'projects': 179, 'campaigned': 180, 'L.': 181, 'Sandra': 182, 'seed': 183, 'clearing': 184, 'boom': 185, 'negotiation': 186, 'Presbyterian': 187, 'launched': 188, 'oriental': 189, 'magic': 190, '5835': 191, 'inappropriate': 192, 'sentencing': 193, 'vantage': 194, 'duplication': 195, 'customers': 196, 'compelled': 197, 'outstanding': 198, 'inefficient': 199, 'Members': 200, 'three-way': 201, 'Norris-LaGuardia': 202, 'Pirate': 203, 'cloakrooms': 204, '390-foot': 205, 'unified': 206, 'unmatched': 207, 'Solid': 208, 'Fifteen': 209, 'enables': 210, 'suited': 211, 'Salary': 212, 'NYU': 213, 'waited': 214, 'frustrated': 215, 'Socola': 216, 'fan': 217, 'allocation': 218, 'decrease': 219, 'organizing': 220, 'improperly': 221, 'Dave': 222, 'Goldwater': 223, 'contained': 224, 'Hester': 225, 'clerical': 226, 'Junior': 227, 'Carbones': 228, 'northernmost': 229, 'full': 230, 'Berlin': 231, 'deduction': 232, 'spider-leg': 233, 'Willard': 234, 'mechanisms': 235, 'Teller': 236, 'exploit': 237, 'Norm': 238, 'aforementioned': 239, 'discarded': 240, 'Bevo': 241, 'rentals': 242, 'Open': 243, 'Playboy': 244, 'irrationality': 245, 'assembled': 246, 'generously': 247, 'Woo ...

# %%
#vocab size
voc_size = len(vocab)
print(voc_size)
# Out:
# 14394

# %%
#append UNK
vocab.append('<UNK>')

# %%
vocab[:5]
# Out:
# ['Clearwater', 'rush', 'Indonesia', 'association', 'slashed']

# %%
word2index['<UNK>'] = 0

# %%
#just in case we need to use
index2word = {v:k for k, v in word2index.items()}

# %% [markdown]
# ## 2. Build Co-occurence Matrix X

# %% [markdown]
# Here, we need to count the co-occurence of two words given some window size.  We gonna use window size of 1.

# %%
from collections import Counter

X_i = Counter(flatten(corpus)) # X_i
X_i
# Out:
# Counter({'The': 806,
#          'Fulton': 14,
#          'County': 35,
#          'Grand': 6,
#          'Jury': 2,
#          'said': 402,
#          'Friday': 41,
#          'an': 300,
#          'investigation': 9,
#          'of': 2849,
#          "Atlanta's": 4,
#          'recent': 20,
#          'primary': 17,
#          'election': 38,
#          'produced': 6,
#          '``': 732,
#          'no': 109,
#          'evidence': 17,
#          "''": 702,
#          'that': 802,
#          'any': 90,
#          'irregularities': 3,
#          'took': 47,
#          'place': 25,
#          '.': 4030,
#          'jury': 44,
#          'further': 16,
#          'in': 1893,
#          'term-end': 1,
#          'presentments': 1,
#          'the': 5580,
#          'City': 44,
#          'Executive': 6,
#          'Committee': 37,
#          ',': 5188,
#          'which': 244,
#          'had': 279,
#          'over-all': 2,
#          'charge': 17,
#          'deserves': 3,
#          'praise': 2,
#          'and': 2146,
#          'thanks': 6,
#          'Atlanta': 14,
#          'for': 943,
#          'manner': 7,
#          'was': 717,
#          'conducted': 8,
#          'September-October': 1,
#          'term': 13,
#          'been': 212,
#          'charged': 12,
#          'by': 497,
#          'Superior': 5,
#          'Court': 26,
#          'Judge': 28,
#          'Durwood': 1,
#          'Pye': 1,
#          'to': 2116,
#          'investigate': 3,
#          'reports': 12,
#          'possible': 28,
#          'hard-fought': 1,
#          'won': 24,
#          'Mayor-nominate': 1,
#          'Ivan': 2,
#          'Allen': 7,
#          'Jr.': 46,
#          'Only': 8,
#          'a': 1993,
#          'relative': 3,
#          'handful': 1,
#          'such': 70,
#          'received': 33,
#          'considering': 2,
#          'widespread': 4,
#          'interest': 32,
#          'number': 32,
#          'voters': 12,
#          'size': 8,
#          'this': 250,
#          'city': 49,
#          'it': 363,
#          'did': 63,
#          'find': 16,
#          'many': 60,
#          "Georgia's": 7,
#          'registration': 2,
#          'laws': 30,
#          'are': 328,
#          'outmoded': 1,
#          'or': 173,
#          'inadequate': 4,
#          'often': 14,
#          'ambiguous': 1,
#          'It': 115,
#          'recommended': 9,
#          'legislators': 8,
#          'act': 20,
#          'have': 265,
#          'these': 59,
#          'studied': 7,
#          'revised': 2,
#          'end': 29,
#          'modernizing': 1,
#          'improving': 4,
#          'them': 96,
#          'grand': 13,
#          'commented': 7,
#          'on': 657,
#          'other': 149,
#          'topics': 2,
#          'among': 24,
#          'purchasing': 3,
#          'departments': 2,
#          'well': 43,
#          'operated': 4,
#          'follow': 12,
#          'generally': 14,
#          'accepted': 4,
#          'practices': 7,
#          'inure': 1,
#          'best': 29,
#          'both': 56,
#          'governments': 5,
#          'Merger': 1,
#          'proposed': 18,
#          'However': 12,
#          'believes': 8,
#          'two': 157,
#          'offices': 4,
#          'should': 59,
#          'be': 526,
#          'combined': 9,
#          'achieve': 6,
#          'greater': 10,
#          'efficiency': 2,
#          'reduce': 8,
#          'cost': 15,
#          'administration': 52,
#          'Purchasing': 1,
#          'Department': 20,
#          'is': 732,
#          'lacking': 3,
#          'experienced': 4,
#          'clerical': 4,
#          'personnel': 11,
#          'as': 481,
#          'result': 30,
#          'policies': 8,
#          'urged': 11,
#          'take': 48,
#          'steps': 8,
#          'remedy': 1,
#          'problem': 39,
#          'Implementation': 1,
#          'automobile': 4,
#          'title': 3,
#          'law': 38,
#          'also': 120,
#          'outgoing': 3,
#          'next': 40,
#          'Legislature': 19,
#          'provide': 24,
#          'enabling': 5,
#          'funds': 28,
#          're-set': 1,
#          'effective': 15,
#          'date': 16,
#          'so': 67,
#          'orderly': 3,
#          'implementation': 1,
#          'may': 66,
#          'effected': 1,
#          'swipe': 1,
#          'at': 598,
#          'State': 63,
#          'Welfare': 3,
#          "Department's": 2,
#          'handling': 3,
#          'federal': 35,
#          'granted': 5,
#          'child': 9,
#          'welfare': 13,
#          'services': 18,
#          'foster': 1,
#          'homes': 9,
#          'This': 70,
#          'one': 184,
#          'major': 28,
#          'items': 4,
#          'general': 29,
#          'assistance': 8,
#          'program': 66,
#          'but': 174,
#          'has': 300,
#          'seen': 7,
#          'fit': 3,
#          'distribute': 2,
#          'through': 54,
#          'all': 163,
#          'counties': 13,
#          'state': 90,
#          'with': 545,
#          'exception': 4,
#          'receives': 1,
#          'none': 7,
#          'money': 29,
#          'jurors': 4,
#          'they': 205,
#          'realize': 4,
#          'proportionate': 1,
#          'distribution': 7,
#          'might': 38,
#          'disable': 1,
#          'our': 55,
#          'less': 10,
#          'populous': 3,
#          'Nevertheless': 1,
#          'we': 77,
#          'feel': 19,
#          'future': 25,
#          'receive': 15,
#          'some': 95,
#          'portion': 2,
#          'available': 10,
#          'Failure': 2,
#          'do': 63,
#          'will': 389,
#          'continue': 11,
#          'disproportionate': 1,
#          'burden': 2,
#          'taxpayers': 5,
#          "ordinary's": 1,
#          'court': 29,
#          'under': 83,
#          'fire': 21,
#          'its': 174,
#          'appointment': 8,
#          'appraisers': 1,
#          'guardians': 2,
#          'administrators': 1,
#          'awarding': 1,
#          'fees': 13,
#          'compensation': 4,
#          'Wards': 1,
#          'protected': 1,
#          'found': 30,
#          'incorporated': 1,
#          'into': 114,
#          'operating': 4,
#          'procedures': 5,
#          'recommendations': 6,
#          'previous': 11,
#          'juries': 1,
#          'Bar': 2,
#          'Association': 18,
#          'interim': 2,
#          'citizens': 6,
#          'committee': 38,
#          'These': 11,
#          'actions': 6,
#          'serve': 7,
#          'protect': 2,
#          'fact': 25,
#          'effect': 17,
#          "court's": 1,
#          'wards': 1,
#          'from': 344,
#          'undue': 2,
#          'costs': 18,
#          'appointed': 6,
#          'elected': 11,
#          'servants': 5,
#          'unmeritorious': 1,
#          'criticisms': 2,
#          'Regarding': 1,
#          'new': 148,
#          'multi-million-dollar': 1,
#          'airport': 3,
#          'when': 128,
#          'management': 6,
#          'takes': 7,
#          'Jan.': 15,
#          '1': 47,
#          'eliminate': 5,
#          'political': 27,
#          'influences': 1,
#          'not': 254,
#          'elaborate': 3,
#          'added': 33,
#          'there': 131,
#          'periodic': 1,
#          'surveillance': 1,
#          'pricing': 3,
#          'concessionaires': 1,
#          'purpose': 9,
#          'keeping': 4,
#          'prices': 19,
#          'reasonable': 2,
#          'Ask': 1,
#          'jail': 6,
#          'deputies': 3,
#          'On': 34,
#          'matters': 3,
#          ':': 149,
#          '(': 168,
#          ')': 171,
#          'Four': 9,
#          'additional': 14,
#          'employed': 5,
#          'Jail': 2,
#          'doctor': 3,
#          'medical': 18,
#          'intern': 1,
#          'extern': 1,
#          'night': 64,
#          'weekend': 12,
#          'duty': 2,
#          '2': 33,
#          'work': 66,
#          'officials': 12,
#          'pass': 15,
#          'legislation': 14,
#          'permit': 6,
#          'establishment': 7,
#          'fair': 10,
#          'equitable': 1,
#          'pension': 5,
#          'plan': 45,
#          'employes': 9,
#          'praised': 3,
#          'operation': 15,
#          'Police': 9,
#          'Tax': 5,
#          "Commissioner's": 1,
#          'Office': 4,
#          'Bellwood': 1,
#          'Alpharetta': 1,
#          'prison': 7,
#          'farms': 3,
#          'Grady': 5,
#          'Hospital': 21,
#          'Health': 5,
#          'Mayor': 17,
#          'William': 36,
#          'B.': 31,
#          'Hartsfield': 5,
#          'filed': 7,
#          'suit': 6,
#          'divorce': 3,
#          'his': 399,
#          'wife': 35,
#          'Pearl': 1,
#          'Williams': 14,
#          'His': 29,
#          'petition': 6,
#          'mental': 1,
#          'cruelty': 1,
#          'couple': 13,
#          'married': 8,
#          'Aug.': 8,
#          '1913': 2,
#          'They': 62,
#          'son': 22,
#          'Berry': 5,
#          'daughter': 26,
#          'Mrs.': 253,
#          'J.': 42,
#          'M.': 22,
#          'Cheshire': 1,
#          'Griffin': 2,
#          'Attorneys': 2,
#          'mayor': 2,
#          'amicable': 1,
#          'property': 16,
#          'settlement': 3,
#          'agreed': 15,
#          'upon': 23,
#          'listed': 10,
#          "mayor's": 4,
#          'occupation': 4,
#          'attorney': 17,
#          'age': 11,
#          '71': 4,
#          "wife's": 1,
#          '74': 3,
#          'birth': 5,
#          'Opelika': 1,
#          'Ala.': 7,
#          'lived': 3,
#          'together': 27,
#          'man': 72,
#          'more': 171,
#          'than': 138,
#          'year': 138,
#          'home': 127,
#          '637': 1,
#          'E.': 34,
#          'Pelham': 5,
#          'Rd.': 3,
#          'Aj': 14,
#          'Henry': 18,
#          'L.': 25,
#          'Bowden': 2,
#          'brief': 2,
#          'interlude': 1,
#          'since': 61,
#          '1937': 2,
#          'career': 10,
#          'goes': 5,
#          'back': 69,
#          'council': 19,
#          '1923': 2,
#          'present': 30,
#          'office': 24,
#          'expires': 1,
#          'He': 191,
#          'succeeded': 3,
#          'who': 268,
#          'became': 20,
#          'candidate': 17,
#          'Sept.': 6,
#          '13': 16,
#          'after': 127,
#          'announced': 37,
#          'he': 451,
#          'would': 244,
#          'run': 35,
#          'reelection': 1,
#          'Georgia': 18,
#          'Republicans': 15,
#          'getting': 17,
#          'strong': 13,
#          'encouragement': 5,
#          'enter': 5,
#          '1962': 5,
#          "governor's": 4,
#          'race': 20,
#          'top': 34,
#          'official': 16,
#          'Wednesday': 22,
#          'Robert': 28,
#          'Snodgrass': 1,
#          'GOP': 5,
#          'chairman': 35,
#          'meeting': 62,
#          'held': 41,
#          'Tuesday': 43,
#          'Blue': 11,
#          'Ridge': 3,
#          'brought': 21,
#          'enthusiastic': 3,
#          'responses': 1,
#          'audience': 12,
#          'Party': 9,
#          'Chairman': 8,
#          'James': 37,
#          'W.': 38,
#          'Dorsey': 1,
#          'enthusiasm': 3,
#          'picking': 1,
#          'up': 168,
#          'rally': 3,
#          '8': 22,
#          'Savannah': 1,
#          'newly': 6,
#          'Texas': 48,
#          'Sen.': 18,
#          'John': 65,
#          'Tower': 1,
#          'featured': 3,
#          'speaker': 4,
#          'In': 127,
#          'warned': 2,
#          'entering': 5,
#          'governor': 13,
#          'force': 7,
#          'petitions': 6,
#          'out': 161,
#          'voting': 7,
#          'precincts': 4,
#          'obtain': 8,
#          'signatures': 5,
#          'registered': 2,
#          'Despite': 5,
#          'warning': 4,
#          'unanimous': 2,
#          'vote': 28,
#          'according': 23,
#          'attended': 10,
#          'When': 41,
#          'crowd': 8,
#          'asked': 34,
#          'whether': 18,
#          'wanted': 20,
#          'wait': 4,
#          'make': 43,
#          'voted': 9,
#          '--': 300,
#          'were': 252,
#          'dissents': 1,
#          'largest': 10,
#          'hurdle': 1,
#          'face': 19,
#          'says': 28,
#          'before': 86,
#          'making': 25,
#          'first': 143,
#          'alternative': 4,
#          'courses': 5,
#          'must': 50,
#          'taken': 30,
#          'Five': 4,
#          'per': 61,
#          'cent': 51,
#          'each': 61,
#          'county': 26,
#          'sign': 9,
#          'requesting': 1,
#          'allowed': 8,
#          'names': 6,
#          'candidates': 10,
#          'ballot': 8,
#          'hold': 10,
#          'unit': 10,
#          'system': 47,
#          'party': 34,
#          'opposes': 2,
#          'platform': 2,
#          'Sam': 13,
#          'Caldwell': 2,
#          'Highway': 6,
#          'public': 51,
#          'relations': 16,
#          'director': 30,
#          'resigned': 5,
#          'Lt.': 1,
#          'Gov.': 10,
#          'Garland': 3,
#          "Byrd's": 1,
#          'campaign': 17,
#          "Caldwell's": 1,
#          'resignation': 4,
#          'expected': 40,
#          'time': 97,
#          'Rob': 1,
#          'Ledford': 1,
#          'Gainesville': 1,
#          'assistant': 10,
#          'three': 97,
#          'years': 102,
#          'gubernatorial': 6,
#          'starts': 9,
#          'become': 23,
#          'coordinator': 5,
#          'Byrd': 1,
#          'wind': 4,
#          '1961': 42,
#          'session': 37,
#          'Monday': 54,
#          'head': 24,
#          'where': 58,
#          'highway': 7,
#          'bond': 11,
#          'approved': 8,
#          'shortly': 5,
#          'Before': 7,
#          'adjournment': 2,
#          'afternoon': 19,
#          'Senate': 32,
#          'approve': 2,
#          'study': 13,
#          'allotted': 2,
#          'rural': 9,
#          'urban': 4,
#          'areas': 12,
#          'determine': 3,
#          'what': 76,
#          'adjustments': 2,
#          'made': 107,
#          'Vandiver': 4,
#          'traditional': 8,
#          'visit': 6,
#          'chambers': 2,
#          'toward': 23,
#          'likely': 7,
#          'mention': 6,
#          '$100': 7,
#          'million': 45,
#          'issue': 30,
#          'earlier': 24,
#          'priority': 4,
#          'item': 1,
#          'Construction': 2,
#          'bonds': 29,
#          'Meanwhile': 4,
#          'learned': 7,
#          'very': 33,
#          'near': 16,
#          'being': 56,
#          'ready': 12,
#          '$30': 1,
#          'worth': 15,
#          'reconstruction': 1,
#          'go': 41,
#          'courts': 6,
#          'friendly': 3,
#          'test': 15,
#          'validity': 1,
#          'then': 56,
#          'sales': 51,
#          'begin': 10,
#          'contracts': 4,
#          'let': 10,
#          'repair': 2,
#          'most': 74,
#          'heavily': 5,
#          'traveled': 2,
#          'highways': 3,
#          'A': 137,
#          'source': 7,
#          '$3': 1,
#          '$4': 1,
#          'Rural': 2,
#          'Roads': 2,
#          'Authority': 4,
#          'road': 12,
#          'construction': 14,
#          'revolving': 3,
#          'fund': 12,
#          'department': 12,
#          'apparently': 12,
#          'intends': 1,
#          'issued': 8,
#          'every': 25,
#          'old': 23,
#          'ones': 8,
#          'paid': 25,
#          'off': 73,
#          'tax': 53,
#          'authorities': 7,
#          'opened': 9,
#          '1958': 19,
#          'battle': 15,
#          'against': 78,
#          'issuance': 2,
#          '$50': 2,
#          'roads': 10,
#          'Marvin': 2,
#          'told': 53,
#          'Constitution': 4,
#          'however': 37,
#          'consulted': 4,
#          'yet': 10,
#          'about': 136,
#          'plans': 22,
#          'Schley': 1,
#          'Rep.': 10,
#          'D.': 24,
#          'offer': 9,
#          'resolution': 21,
#          'House': 71,
#          'rescind': 2,
#          "body's": 1,
#          'action': 20,
#          'itself': 10,
#          '$10': 3,
#          'day': 61,
#          'increase': 24,
#          'expense': 7,
#          'allowances': 3,
#          'Sunday': 51,
#          'research': 15,
#          'done': 24,
#          'quickie': 1,
#          'can': 93,
#          'repealed': 1,
#          'outright': 3,
#          'notice': 5,
#          'given': 37,
#          'reconsideration': 2,
#          'sought': 6,
#          'While': 12,
#          'emphasizing': 1,
#          'technical': 7,
#          'details': 3,
#          'fully': 6,
#          'worked': 12,
#          'seek': 12,
#          'set': 51,
#          'aside': 5,
#          'privilege': 3,
#          '87-31': 1,
#          'similar': 17,
#          'passed': 18,
#          '29-5': 1,
#          'As': 36,
#          'word': 14,
#          'offered': 11,
#          'pointed': 9,
#          'last': 161,
#          'November': 10,
#          'rejected': 8,
#          'constitutional': 8,
#          'amendment': 5,
#          'allow': 5,
#          'pay': 33,
#          'raises': 3,
#          'sessions': 6,
#          'veteran': 11,
#          'Jackson': 5,
#          'legislator': 2,
#          'ask': 7,
#          'aid': 25,
#          'education': 31,
#          'something': 14,
#          'consistently': 1,
#          'opposed': 9,
#          'past': 35,
#          'Mac': 1,
#          'Barber': 5,
#          'Commerce': 7,
#          'asking': 5,
#          'endorse': 3,
#          'increased': 10,
#          'support': 24,
#          'provided': 8,
#          'expended': 1,
#          '13th': 5,
#          'members': 69,
#          'congressional': 6,
#          'delegation': 3,
#          'Washington': 48,
#          'like': 46,
#          'see': 38,
#          'But': 109,
#          'congressmen': 3,
#          'specifically': 1,
#          'him': 93,
#          'tossed': 1,
#          'hopper': 1,
#          'formally': 7,
#          'read': 13,
#          'event': 15,
#          'Congress': 21,
#          'does': 26,
#          'Board': 17,
#          'Education': 15,
#          'directed': 8,
#          'give': 32,
#          'teacher': 9,
#          'Colquitt': 2,
#          'After': 24,
#          'long': 39,
#          'hot': 9,
#          'controversy': 5,
#          'Miller': 3,
#          'school': 65,
#          'superintendent': 9,
#          'policeman': 2,
#          'put': 27,
#          'coolest': 2,
#          'I': 179,
#          'ever': 32,
#          'saw': 17,
#          'Harry': 10,
#          'Davis': 13,
#          'agriculture': 2,
#          'defeated': 5,
#          'Felix': 2,
#          'Bush': 3,
#          'principal': 9,
#          'Democratic': 37,
#          '1,119': 1,
#          'votes': 7,
#          "Saturday's": 2,
#          'got': 45,
#          '402': 1,
#          'Ordinary': 2,
#          'Carey': 5,
#          'armed': 7,
#          'pistol': 3,
#          'stood': 4,
#          'polls': 3,
#          'insure': 2,
#          'order': 19,
#          'calmest': 1,
#          'Policeman': 1,
#          'Tom': 6,
#          'Being': 1,
#          'just': 42,
#          'church': 16,
#          "didn't": 15,
#          'smell': 2,
#          'drop': 6,
#          'liquor': 4,
#          'bit': 7,
#          'trouble': 8,
#          'leading': 11,
#          'quiet': 5,
#          'marked': 4,
#          'anonymous': 4,
#          'midnight': 4,
#          'phone': 5,
#          'calls': 13,
#          'veiled': 3,
#          'threats': 1,
#          'violence': 3,
#          'former': 27,
#          'George': 23,
#          'P.': 18,
#          'Callan': 1,
#          'shot': 14,
#          'himself': 21,
#          'death': 10,
#          'March': 36,
#          '18': 20,
#          'four': 73,
#          'days': 38,
#          'post': 10,
#          'dispute': 2,
#          'board': 47,
#          'During': 5,
#          'reportedly': 4,
#          'telephone': 8,
#          'too': 37,
#          'subjected': 2,
#          'soon': 15,
#          'scheduled': 14,
#          'Many': 12,
#          'local': 39,
#          'feared': 1,
#          'carry': 11,
#          'gun': 2,
#          'promised': 4,
#          'Sheriff': 2,
#          'Tabb': 1,
#          'ordinary': 7,
#          'good': 50,
#          'promise': 3,
#          'Everything': 1,
#          'went': 37,
#          'real': 24,
#          'smooth': 1,
#          'sheriff': 3,
#          'There': 58,
#          "wasn't": 3,
#          'Austin': 15,
#          'approval': 8,
#          'Price': 3,
#          "Daniel's": 1,
#          'abandoned': 3,
#          'seemed': 12,
#          'certain': 18,
#          'Thursday': 20,
#          'despite': 11,
#          'adamant': 2,
#          'protests': 1,
#          'bankers': 8,
#          'Daniel': 5,
#          'personally': 3,
#          'led': 17,
#          'fight': 14,
#          'measure': 13,
#          'watered': 1,
#          'down': 50,
#          'considerably': 5,
#          'rejection': 3,
#          'Legislatures': 1,
#          'hearing': 14,
#          'Revenue': 5,
#          'Taxation': 1,
#          'Under': 8,
#          'rules': 11,
#          'automatically': 3,
#          'subcommittee': 1,
#          'week': 86,
#          'questions': 8,
#          'taunted': 1,
#          'appearing': 1,
#          'witnesses': 7,
#          'left': 39,
#          'little': 35,
#          'doubt': 6,
#          'recommend': 4,
#          'passage': 3,
#          'termed': 4,
#          'extremely': 2,
#          'conservative': 5,
#          'estimate': 3,
#          'produce': 7,
#          '17': 14,
#          'dollars': 15,
#          'help': 30,
#          'erase': 1,
#          'anticipated': 4,
#          'deficit': 1,
#          '63': 1,
#          'current': 13,
#          'fiscal': 5,
#          '31': 6,
#          'merely': 15,
#          'means': 18,
#          'enforcing': 1,
#          'escheat': 2,
#          'books': 12,
#          'republic': 1,
#          'permits': 4,
#          'over': 115,
#          'bank': 11,
#          'accounts': 2,
#          'stocks': 10,
#          'personal': 12,
#          'persons': 24,
#          'missing': 3,
#          'seven': 16,
#          'bill': 45,
#          'drafted': 1,
#          'banks': 4,
#          'insurance': 4,
#          'firms': 15,
#          'pipeline': 2,
#          'companies': 18,
#          'corporations': 2,
#          'report': 25,
#          'treasurer': 6,
#          'cannot': 15,
#          'enforced': 3,
#          'now': 76,
#          'because': 51,
#          'almost': 24,
#          'impossible': 4,
#          'locate': 1,
#          'declared': 15,
#          'Dewey': 1,
#          'Lawrence': 12,
#          'Tyler': 2,
#          'lawyer': 9,
#          'representing': 8,
#          'Bankers': 3,
#          'sounded': 1,
#          'opposition': 8,
#          'keynote': 3,
#          'violate': 2,
#          'their': 219,
#          'contractual': 1,
#          'obligations': 4,
#          'depositors': 1,
#          'undermine': 1,
#          'confidence': 6,
#          'customers': 7,
#          'If': 29,
#          'you': 55,
#          'destroy': 5,
#          'economy': 9,
#          'You': 11,
#          'circulation': 2,
#          'millions': 9,
#          'Charles': 22,
#          'Hughes': 22,
#          'Sherman': 9,
#          'sponsor': 4,
#          'failure': 5,
#          'enact': 1,
#          'amount': 18,
#          'gift': 5,
#          "taxpayers'": 2,
#          'pockets': 2,
#          'contention': 2,
#          'denied': 5,
#          'several': 34,
#          'including': 25,
#          'Scott': 3,
#          'Hudson': 2,
#          'Gaynor': 1,
#          'Jones': 22,
#          'Houston': 15,
#          'Brady': 1,
#          'Harlingen': 1,
#          'Howard': 13,
#          'Cox': 4,
#          'argued': 7,
#          'probably': 19,
#          'unconstitutional': 1,
#          'impair': 1,
#          'complained': 4,
#          'enough': 27,
#          'introduced': 10,
#          'only': 103,
#          'Senators': 4,
#          'unanimously': 2,
#          'Parkhouse': 5,
#          'Dallas': 49,
#          'authorizing': 2,
#          'schools': 37,
#          'deaf': 5,
#          'designed': 16,
#          'special': 41,
#          'schooling': 2,
#          ...})

# %%
# Make skip gram of one size window
window_size = 2
# Make skip gram of one size window
skip_grams = []
# loop each word sequence
# we starts from 1 because 0 has no context
# we stop at second last for the same reason
for sent in corpus:
    for i in range(window_size, len(sent) - window_size):
        target = sent[i]

        context = []
        for j in range(1, window_size):
            context.append(sent[i - j])
            context.append(sent[i + j])

        # for each outside word, append to a skip_grams
        for w in context:
            skip_grams.append((target, w))

skip_grams
# Out:
# [('County', 'Fulton'),
#  ('County', 'Grand'),
#  ('Grand', 'County'),
#  ('Grand', 'Jury'),
#  ('Jury', 'Grand'),
#  ('Jury', 'said'),
#  ('said', 'Jury'),
#  ('said', 'Friday'),
#  ('Friday', 'said'),
#  ('Friday', 'an'),
#  ('an', 'Friday'),
#  ('an', 'investigation'),
#  ('investigation', 'an'),
#  ('investigation', 'of'),
#  ('of', 'investigation'),
#  ('of', "Atlanta's"),
#  ("Atlanta's", 'of'),
#  ("Atlanta's", 'recent'),
#  ('recent', "Atlanta's"),
#  ('recent', 'primary'),
#  ('primary', 'recent'),
#  ('primary', 'election'),
#  ('election', 'primary'),
#  ('election', 'produced'),
#  ('produced', 'election'),
#  ('produced', '``'),
#  ('``', 'produced'),
#  ('``', 'no'),
#  ('no', '``'),
#  ('no', 'evidence'),
#  ('evidence', 'no'),
#  ('evidence', "''"),
#  ("''", 'evidence'),
#  ("''", 'that'),
#  ('that', "''"),
#  ('that', 'any'),
#  ('any', 'that'),
#  ('any', 'irregularities'),
#  ('irregularities', 'any'),
#  ('irregularities', 'took'),
#  ('took', 'irregularities'),
#  ('took', 'place'),
#  ('further', 'jury'),
#  ('further', 'said'),
#  ('said', 'further'),
#  ('said', 'in'),
#  ('in', 'said'),
#  ('in', 'term-end'),
#  ('term-end', 'in'),
#  ('term-end', 'presentments'),
#  ('presentments', 'term-end'),
#  ('presentments', 'that'),
#  ('that', 'presentments'),
#  ('that', 'the'),
#  ('the', 'that'),
#  ('the', 'City'),
#  ('City', 'the'),
#  ('City', 'Executive'),
#  ('Executive', 'City'),
#  ('Executive', 'Committee'),
#  ('Committee', 'Executive'),
#  ('Committee', ','),
#  (',', 'Committee'),
#  (',', 'which'),
#  ('which', ','),
#  ('which', 'had'),
#  ('had', 'which'),
#  ('had', 'over-all'),
#  ('over-all', 'had'),
#  ('over-all', 'charge'),
#  ('charge', 'over-all'),
#  ('charge', 'of'),
#  ('of', 'charge'),
#  ('of', 'the'),
#  ('the', 'of'),
#  ('the', 'election'),
#  ('election', 'the'),
#  ('election', ','),
#  (',', 'election'),
#  (',', '``'),
#  ('``', ','),
#  ('``', 'deserves'),
#  ('deserves', '``'),
#  ('deserves', 'the'),
#  ('the', 'deserves'),
#  ('the', 'praise'),
#  ('praise', 'the'),
#  ('praise', 'and'),
#  ('and', 'praise'),
#  ('and', 'thanks'),
#  ('thanks', 'and'),
#  ('thanks', 'of'),
#  ('of', 'thanks'),
#  ('of', 'the'),
#  ('the', 'of'),
#  ('the', 'City'),
#  ('City', 'the'),
#  ('City', 'of'),
#  ('of', 'City'),
#  ('of', 'Atlanta'),
#  ('Atlanta', 'of'),
#  ('Atlanta', "''"),
#  ("''", 'Atlanta'),
#  ("''", 'for'),
#  ('for', "''"),
#  ('for', 'the'),
#  ('the', 'for'),
#  ('the', 'manner'),
#  ('manner', 'the'),
#  ('manner', 'in'),
#  ('in', 'manner'),
#  ('in', 'which'),
#  ('which', 'in'),
#  ('which', 'the'),
#  ('the', 'which'),
#  ('the', 'election'),
#  ('election', 'the'),
#  ('election', 'was'),
#  ('was', 'election'),
#  ('was', 'conducted'),
#  ('term', 'September-October'),
#  ('term', 'jury'),
#  ('jury', 'term'),
#  ('jury', 'had'),
#  ('had', 'jury'),
#  ('had', 'been'),
#  ('been', 'had'),
#  ('been', 'charged'),
#  ('charged', 'been'),
#  ('charged', 'by'),
#  ('by', 'charged'),
#  ('by', 'Fulton'),
#  ('Fulton', 'by'),
#  ('Fulton', 'Superior'),
#  ('Superior', 'Fulton'),
#  ('Superior', 'Court'),
#  ('Court', 'Superior'),
#  ('Court', 'Judge'),
#  ('Judge', 'Court'),
#  ('Judge', 'Durwood'),
#  ('Durwood', 'Judge'),
#  ('Durwood', 'Pye'),
#  ('Pye', 'Durwood'),
#  ('Pye', 'to'),
#  ('to', 'Pye'),
#  ('to', 'investigate'),
#  ('investigate', 'to'),
#  ('investigate', 'reports'),
#  ('reports', 'investigate'),
#  ('reports', 'of'),
#  ('of', 'reports'),
#  ('of', 'possible'),
#  ('possible', 'of'),
#  ('possible', '``'),
#  ('``', 'possible'),
#  ('``', 'irregularities'),
#  ('irregularities', '``'),
#  ('irregularities', "''"),
#  ("''", 'irregularities'),
#  ("''", 'in'),
#  ('in', "''"),
#  ('in', 'the'),
#  ('the', 'in'),
#  ('the', 'hard-fought'),
#  ('hard-fought', 'the'),
#  ('hard-fought', 'primary'),
#  ('primary', 'hard-fought'),
#  ('primary', 'which'),
#  ('which', 'primary'),
#  ('which', 'was'),
#  ('was', 'which'),
#  ('was', 'won'),
#  ('won', 'was'),
#  ('won', 'by'),
#  ('by', 'won'),
#  ('by', 'Mayor-nominate'),
#  ('Mayor-nominate', 'by'),
#  ('Mayor-nominate', 'Ivan'),
#  ('Ivan', 'Mayor-nominate'),
#  ('Ivan', 'Allen'),
#  ('Allen', 'Ivan'),
#  ('Allen', 'Jr.'),
#  ('a', 'Only'),
#  ('a', 'relative'),
#  ('relative', 'a'),
#  ('relative', 'handful'),
#  ('handful', 'relative'),
#  ('handful', 'of'),
#  ('of', 'handful'),
#  ('of', 'such'),
#  ('such', 'of'),
#  ('such', 'reports'),
#  ('reports', 'such'),
#  ('reports', 'was'),
#  ('was', 'reports'),
#  ('was', 'received'),
#  ('received', 'was'),
#  ('received', "''"),
#  ("''", 'received'),
#  ("''", ','),
#  (',', "''"),
#  (',', 'the'),
#  ('the', ','),
#  ('the', 'jury'),
#  ('jury', 'the'),
#  ('jury', 'said'),
#  ('said', 'jury'),
#  ('said', ','),
#  (',', 'said'),
#  (',', '``'),
#  ('``', ','),
#  ('``', 'considering'),
#  ('considering', '``'),
#  ('considering', 'the'),
#  ('the', 'considering'),
#  ('the', 'widespread'),
#  ('widespread', 'the'),
#  ('widespread', 'interest'),
#  ('interest', 'widespread'),
#  ('interest', 'in'),
#  ('in', 'interest'),
#  ('in', 'the'),
#  ('the', 'in'),
#  ('the', 'election'),
#  ('election', 'the'),
#  ('election', ','),
#  (',', 'election'),
#  (',', 'the'),
#  ('the', ','),
#  ('the', 'number'),
#  ('number', 'the'),
#  ('number', 'of'),
#  ('of', 'number'),
#  ('of', 'voters'),
#  ('voters', 'of'),
#  ('voters', 'and'),
#  ('and', 'voters'),
#  ('and', 'the'),
#  ('the', 'and'),
#  ('the', 'size'),
#  ('size', 'the'),
#  ('size', 'of'),
#  ('of', 'size'),
#  ('of', 'this'),
#  ('this', 'of'),
#  ('this', 'city'),
#  ('city', 'this'),
#  ('city', "''"),
#  ('said', 'jury'),
#  ('said', 'it'),
#  ('it', 'said'),
#  ('it', 'did'),
#  ('did', 'it'),
#  ('did', 'find'),
#  ('find', 'did'),
#  ('find', 'that'),
#  ('that', 'find'),
#  ('that', 'many'),
#  ('many', 'that'),
#  ('many', 'of'),
#  ('of', 'many'),
#  ('of', "Georgia's"),
#  ("Georgia's", 'of'),
#  ("Georgia's", 'registration'),
#  ('registration', "Georgia's"),
#  ('registration', 'and'),
#  ('and', 'registration'),
#  ('and', 'election'),
#  ('election', 'and'),
#  ('election', 'laws'),
#  ('laws', 'election'),
#  ('laws', '``'),
#  ('``', 'laws'),
#  ('``', 'are'),
#  ('are', '``'),
#  ('are', 'outmoded'),
#  ('outmoded', 'are'),
#  ('outmoded', 'or'),
#  ('or', 'outmoded'),
#  ('or', 'inadequate'),
#  ('inadequate', 'or'),
#  ('inadequate', 'and'),
#  ('and', 'inadequate'),
#  ('and', 'often'),
#  ('often', 'and'),
#  ('often', 'ambiguous'),
#  ('ambiguous', 'often'),
#  ('ambiguous', "''"),
#  ('that', 'recommended'),
#  ('that', 'Fulton'),
#  ('Fulton', 'that'),
#  ('Fulton', 'legislators'),
#  ('legislators', 'Fulton'),
#  ('legislators', 'act'),
#  ('act', 'legislators'),
#  ('act', '``'),
#  ('``', 'act'),
#  ('``', 'to'),
#  ('to', '``'),
#  ('to', 'have'),
#  ('have', 'to'),
#  ('have', 'these'),
#  ('these', 'have'),
#  ('these', 'laws'),
#  ('laws', 'these'),
#  ('laws', 'studied'),
#  ('studied', 'laws'),
#  ('studied', 'and'),
#  ('and', 'studied'),
#  ('and', 'revised'),
#  ('revised', 'and'),
#  ('revised', 'to'),
#  ('to', 'revised'),
#  ('to', 'the'),
#  ('the', 'to'),
#  ('the', 'end'),
#  ('end', 'the'),
#  ('end', 'of'),
#  ('of', 'end'),
#  ('of', 'modernizing'),
#  ('modernizing', 'of'),
#  ('modernizing', 'and'),
#  ('and', 'modernizing'),
#  ('and', 'improving'),
#  ('improving', 'and'),
#  ('improving', 'them'),
#  ('them', 'improving'),
#  ('them', "''"),
#  ('jury', 'grand'),
#  ('jury', 'commented'),
#  ('commented', 'jury'),
#  ('commented', 'on'),
#  ('on', 'commented'),
#  ('on', 'a'),
#  ('a', 'on'),
#  ('a', 'number'),
#  ('number', 'a'),
#  ('number', 'of'),
#  ('of', 'number'),
#  ('of', 'other'),
#  ('other', 'of'),
#  ('other', 'topics'),
#  ('topics', 'other'),
#  ('topics', ','),
#  (',', 'topics'),
#  (',', 'among'),
#  ('among', ','),
#  ('among', 'them'),
#  ('them', 'among'),
#  ('them', 'the'),
#  ('the', 'them'),
#  ('the', 'Atlanta'),
#  ('Atlanta', 'the'),
#  ('Atlanta', 'and'),
#  ('and', 'Atlanta'),
#  ('and', 'Fulton'),
#  ('Fulton', 'and'),
#  ('Fulton', 'County'),
#  ('County', 'Fulton'),
#  ('County', 'purchasing'),
#  ('purchasing', 'County'),
#  ('purchasing', 'departments'),
#  ('departments', 'purchasing'),
#  ('departments', 'which'),
#  ('which', 'departments'),
#  ('which', 'it'),
#  ('it', 'which'),
#  ('it', 'said'),
#  ('said', 'it'),
#  ('said', '``'),
#  ('``', 'said'),
#  ('``', 'are'),
#  ('are', '``'),
#  ('are', 'well'),
#  ('well', 'are'),
#  ('well', 'operated'),
#  ('operated', 'well'),
#  ('operated', 'and'),
#  ('and', 'operated'),
#  ('and', 'follow'),
#  ('follow', 'and'),
#  ('follow', 'generally'),
#  ('generally', 'follow'),
#  ('generally', 'accepted'),
#  ('accepted', 'generally'),
#  ('accepted', 'practices'),
#  ('practices', 'accepted'),
#  ('practices', 'which'),
#  ('which', 'practices'),
#  ('which', 'inure'),
#  ('inure', 'which'),
#  ('inure', 'to'),
#  ('to', 'inure'),
#  ('to', 'the'),
#  ('the', 'to'),
#  ('the', 'best'),
#  ('best', 'the'),
#  ('best', 'interest'),
#  ('interest', 'best'),
#  ('interest', 'of'),
#  ('of', 'interest'),
#  ('of', 'both'),
#  ('both', 'of'),
#  ('both', 'governments'),
#  ('governments', 'both'),
#  ('governments', "''"),
#  ('the', ','),
#  ('the', 'jury'),
#  ('jury', 'the'),
#  ('jury', 'said'),
#  ('said', 'jury'),
#  ('said', 'it'),
#  ('it', 'said'),
#  ('it', 'believes'),
#  ('believes', 'it'),
#  ('believes', '``'),
#  ('``', 'believes'),
#  ('``', 'these'),
#  ('these', '``'),
#  ('these', 'two'),
#  ('two', 'these'),
#  ('two', 'offices'),
#  ('offices', 'two'),
#  ('offices', 'should'),
#  ('should', 'offices'),
#  ('should', 'be'),
#  ('be', 'should'),
#  ('be', 'combined'),
#  ('combined', 'be'),
#  ('combined', 'to'),
#  ('to', 'combined'),
#  ('to', 'achieve'),
#  ('achieve', 'to'),
#  ('achieve', 'greater'),
#  ('greater', 'achieve'),
#  ('greater', 'efficiency'),
#  ('efficiency', 'greater'),
#  ('efficiency', 'and'),
#  ('and', 'efficiency'),
#  ('and', 'reduce'),
#  ('reduce', 'and'),
#  ('reduce', 'the'),
#  ('the', 'reduce'),
#  ('the', 'cost'),
#  ('cost', 'the'),
#  ('cost', 'of'),
#  ('of', 'cost'),
#  ('of', 'administration'),
#  ('administration', 'of'),
#  ('administration', "''"),
#  ('Purchasing', 'City'),
#  ('Purchasing', 'Department'),
#  ('Department', 'Purchasing'),
#  ('Department', ','),
#  (',', 'Department'),
#  (',', 'the'),
#  ('the', ','),
#  ('the', 'jury'),
#  ('jury', 'the'),
#  ('jury', 'said'),
#  ('said', 'jury'),
#  ('said', ','),
#  (',', 'said'),
#  (',', '``'),
#  ('``', ','),
#  ('``', 'is'),
#  ('is', '``'),
#  ('is', 'lacking'),
#  ('lacking', 'is'),
#  ('lacking', 'in'),
#  ('in', 'lacking'),
#  ('in', 'experienced'),
#  ('experienced', 'in'),
#  ('experienced', 'clerical'),
#  ('clerical', 'experienced'),
#  ('clerical', 'personnel'),
#  ('personnel', 'clerical'),
#  ('personnel', 'as'),
#  ('as', 'personnel'),
#  ('as', 'a'),
#  ('a', 'as'),
#  ('a', 'result'),
#  ('result', 'a'),
#  ('result', 'of'),
#  ('of', 'result'),
#  ('of', 'city'),
#  ('city', 'of'),
#  ('city', 'personnel'),
#  ('personnel', 'city'),
#  ('personnel', 'policies'),
#  ('policies', 'personnel'),
#  ('policies', "''"),
#  ('that', 'urged'),
#  ('that', 'the'),
#  ('the', 'that'),
#  ('the', 'city'),
#  ('city', 'the'),
#  ('city', '``'),
#  ('``', 'city'),
#  ('``', 'take'),
#  ('take', '``'),
#  ('take', 'steps'),
#  ('steps', 'take'),
#  ('steps', 'to'),
#  ('to', 'steps'),
#  ('to', 'remedy'),
#  ('remedy', 'to'),
#  ('remedy', "''"),
#  ("''", 'remedy'),
#  ("''", 'this'),
#  ('this', "''"),
#  ('this', 'problem'),
#  ("Georgia's", 'of'),
#  ("Georgia's", 'automobile'),
#  ('automobile', "Georgia's"),
#  ('automobile', 'title'),
#  ('title', 'automobile'),
#  ('title', 'law'),
#  ('law', 'title'),
#  ('law', 'was'),
#  ('was', 'law'),
#  ('was', 'also'),
#  ('also', 'was'),
#  ('also', 'recommended'),
#  ('recommended', 'also'),
#  ('recommended', 'by'),
#  ('by', 'recommended'),
#  ('by', 'the'),
#  ('the', 'by'),
#  ('the', 'outgoing'),
#  ('outgoing', 'the'),
#  ('outgoing', 'jury'),
#  ('that', 'urged'),
#  ('that', 'the'),
#  ('the', 'that'),
#  ('the', 'next'),
#  ('next', 'the'),
#  ('next', 'Legislature'),
#  ('Legislature', 'next'),
#  ('Legislature', '``'),
#  ('``', 'Legislature'),
#  ('``', 'provide'),
#  ('provide', '``'),
#  ('provide', 'enabling'),
#  ('enabling', 'provide'),
#  ('enabling', 'funds'),
#  ('funds', 'enabling'),
#  ('funds', 'and'),
#  ('and', 'funds'),
#  ('and', 're-set'),
#  ('re-set', 'and'),
#  ('re-set', 'the'),
#  ('the', 're-set'),
#  ('the', 'effective'),
#  ('effective', 'the'),
#  ('effective', 'date'),
#  ('date', 'effective'),
#  ('date', 'so'),
#  ('so', 'date'),
#  ('so', 'that'),
#  ('that', 'so'),
#  ('that', 'an'),
#  ('an', 'that'),
#  ('an', 'orderly'),
#  ('orderly', 'an'),
#  ('orderly', 'implementation'),
#  ('implementation', 'orderly'),
#  ('implementation', 'of'),
#  ('of', 'implementation'),
#  ('of', 'the'),
#  ('the', 'of'),
#  ('the', 'law'),
#  ('law', 'the'),
#  ('law', 'may'),
#  ('may', 'law'),
#  ('may', 'be'),
#  ('be', 'may'),
#  ('be', 'effected'),
#  ('effected', 'be'),
#  ('effected', "''"),
#  ('jury', 'grand'),
#  ('jury', 'took'),
#  ('took', 'jury'),
#  ('took', 'a'),
#  ('a', 'took'),
#  ('a', 'swipe'),
#  ('swipe', 'a'),
#  ('swipe', 'at'),
#  ('at', 'swipe'),
#  ('at', 'the'),
#  ('the', 'at'),
#  ('the', 'State'),
#  ('State', 'the'),
#  ('State', 'Welfare'),
#  ('Welfare', 'State'),
#  ('Welfare', "Department's"),
#  ("Department's", 'Welfare'),
#  ("Department's", 'handling'),
#  ('handling', "Department's"),
#  ('handling', 'of'),
#  ('of', 'handling'),
#  ('of', 'federal'),
#  ('federal', 'of'),
#  ('federal', 'funds'),
#  ('funds', 'federal'),
#  ('funds', 'granted'),
#  ('granted', 'funds'),
#  ('granted', 'for'),
#  ('for', 'granted'),
#  ('for', 'child'),
#  ('child', 'for'),
#  ('child', 'welfare'),
#  ('welfare', 'child'),
#  ('welfare', 'services'),
#  ('services', 'welfare'),
#  ('services', 'in'),
#  ('in', 'services'),
#  ('in', 'foster'),
#  ('foster', 'in'),
#  ('foster', 'homes'),
#  ('is', 'This'),
#  ('is', 'one'),
#  ('one', 'is'),
#  ('one', 'of'),
#  ('of', 'one'),
#  ('of', 'the'),
#  ('the', 'of'),
#  ('the', 'major'),
#  ('major', 'the'),
#  ('major', 'items'),
#  ('items', 'major'),
#  ('items', 'in'),
#  ('in', 'items'),
#  ('in', 'the'),
#  ('the', 'in'),
#  ('the', 'Fulton'),
#  ('Fulton', 'the'),
#  ('Fulton', 'County'),
#  ('County', 'Fulton'),
#  ('County', 'general'),
#  ('general', 'County'),
#  ('general', 'assistance'),
#  ('assistance', 'general'),
#  ('assistance', 'program'),
#  ('program', 'assistance'),
#  ('program', "''"),
#  ("''", 'program'),
#  ("''", ','),
#  (',', "''"),
#  (',', 'the'),
#  ('the', ','),
#  ('the', 'jury'),
#  ('jury', 'the'),
#  ('jury', 'said'),
#  ('said', 'jury'),
#  ('said', ','),
#  (',', 'said'),
#  (',', 'but'),
#  ('but', ','),
#  ('but', 'the'),
#  ('the', 'but'),
#  ('the', 'State'),
#  ('State', 'the'),
#  ('State', 'Welfare'),
#  ('Welfare', 'State'),
#  ('Welfare', 'Department'),
#  ('Department', 'Welfare'),
#  ('Department', '``'),
#  ('``', 'Department'),
#  ('``', 'has'),
#  ('has', '``'),
#  ('has', 'seen'),
#  ('seen', 'has'),
#  ('seen', 'fit'),
#  ('fit', 'seen'),
#  ('fit', 'to'),
#  ('to', 'fit'),
#  ('to', 'distribute'),
#  ('distribute', 'to'),
#  ('distribute', 'these'),
#  ('these', 'distribute'),
#  ('these', 'funds'),
#  ('funds', 'these'),
#  ('funds', 'through'),
#  ('through', 'funds'),
#  ('through', 'the'),
#  ('the', 'through'),
#  ('the', 'welfare'),
#  ('welfare', 'the'),
#  ('welfare', 'departments'),
#  ('departments', 'welfare'),
#  ('departments', 'of'),
#  ('of', 'departments'),
#  ('of', 'all'),
#  ('all', 'of'),
#  ('all', 'the'),
#  ('the', 'all'),
#  ('the', 'counties'),
#  ('counties', 'the'),
#  ('counties', 'in'),
#  ('in', 'counties'),
#  ('in', 'the'),
#  ('the', 'in'),
#  ('the', 'state'),
#  ('state', 'the'),
#  ('state', 'with'),
#  ('with', 'state'),
#  ('with', 'the'),
#  ('the', 'with'),
#  ('the', 'exception'),
#  ('exception', 'the'),
#  ('exception', 'of'),
#  ('of', 'exception'),
#  ('of', 'Fulton'),
#  ('Fulton', 'of'),
#  ('Fulton', 'County'),
#  ('County', 'Fulton'),
#  ('County', ','),
#  (',', 'County'),
#  (',', 'which'),
#  ('which', ','),
#  ('which', 'receives'),
#  ('receives', 'which'),
#  ('receives', 'none'),
#  ('none', 'receives'),
#  ('none', 'of'),
#  ('of', 'none'),
#  ('of', 'this'),
#  ('this', 'of'),
#  ('this', 'money'),
#  ('said', 'jurors'),
#  ('said', 'they'),
#  ('they', 'said'),
#  ('they', 'realize'),
#  ('realize', 'they'),
#  ('realize', '``'),
#  ('``', 'realize'),
#  ('``', 'a'),
#  ('a', '``'),
#  ('a', 'proportionate'),
#  ('proportionate', 'a'),
#  ('proportionate', 'distribution'),
#  ('distribution', 'proportionate'),
#  ('distribution', 'of'),
#  ('of', 'distribution'),
#  ('of', 'these'),
#  ('these', 'of'),
#  ('these', 'funds'),
#  ('funds', 'these'),
#  ('funds', 'might'),
#  ('might', 'funds'),
#  ('might', 'disable'),
#  ('disable', 'might'),
#  ('disable', 'this'),
#  ('this', 'disable'),
#  ('this', 'program'),
#  ('program', 'this'),
#  ('program', 'in'),
#  ('in', 'program'),
#  ('in', 'our'),
#  ('our', 'in'),
#  ('our', 'less'),
#  ('less', 'our'),
#  ('less', 'populous'),
#  ('populous', 'less'),
#  ('populous', 'counties'),
#  ('counties', 'populous'),
#  ('counties', "''"),
#  ('``', ','),
#  ('``', 'we'),
#  ('we', '``'),
#  ('we', 'feel'),
#  ('feel', 'we'),
#  ('feel', 'that'),
#  ('that', 'feel'),
#  ('that', 'in'),
#  ('in', 'that'),
#  ('in', 'the'),
#  ('the', 'in'),
#  ('the', 'future'),
#  ('future', 'the'),
#  ('future', 'Fulton'),
#  ('Fulton', 'future'),
#  ('Fulton', 'County'),
#  ('County', 'Fulton'),
#  ('County', 'should'),
#  ('should', 'County'),
#  ('should', 'receive'),
#  ('receive', 'should'),
#  ('receive', 'some'),
#  ('some', 'receive'),
#  ('some', 'portion'),
#  ('portion', 'some'),
#  ('portion', 'of'),
#  ('of', 'portion'),
#  ('of', 'these'),
#  ('these', 'of'),
#  ('these', 'available'),
#  ('available', 'these'),
#  ('available', 'funds'),
#  ('funds', 'available'),
#  ('funds', "''"),
#  ("''", 'funds'),
#  ("''", ','),
#  (',', "''"),
#  (',', 'the'),
#  ('the', ','),
#  ('the', 'jurors'),
#  ('jurors', 'the'),
#  ('jurors', 'said'),
#  ('to', 'Failure'),
#  ('to', 'do'),
#  ('do', 'to'),
#  ('do', 'this'),
#  ('this', 'do'),
#  ('this', 'will'),
#  ('will', 'this'),
#  ('will', 'continue'),
#  ('continue', 'will'),
#  ('continue', 'to'),
#  ('to', 'continue'),
#  ('to', 'place'),
#  ('place', 'to'),
#  ('place', 'a'),
#  ('a', 'place'),
#  ('a', 'disproportionate'),
#  ('disproportionate', 'a'),
#  ('disproportionate', 'burden'),
#  ('burden', 'disproportionate'),
#  ('burden', "''"),
#  ("''", 'burden'),
#  ("''", 'on'),
#  ('on', "''"),
#  ('on', 'Fulton'),
#  ('Fulton', 'on'),
#  ('Fulton', 'taxpayers'),
#  ('also', 'jury'),
#  ('also', 'commented'),
#  ('commented', 'also'),
#  ('commented', 'on'),
#  ('on', 'commented'),
#  ('on', 'the'),
#  ('the', 'on'),
#  ('the', 'Fulton'),
#  ('Fulton', 'the'),
#  ('Fulton', "ordinary's"),
#  ("ordinary's", 'Fulton'),
#  ("ordinary's", 'court'),
#  ('court', "ordinary's"),
#  ('court', 'which'),
#  ('which', 'court'),
#  ('which', 'has'),
#  ('has', 'which'),
#  ('has', 'been'),
#  ('been', 'has'),
#  ('been', 'under'),
#  ('under', 'been'),
#  ('under', 'fire'),
#  ('fire', 'under'),
#  ('fire', 'for'),
#  ('for', 'fire'),
#  ('for', 'its'),
#  ('its', 'for'),
#  ('its', 'practices'),
#  ('practices', 'its'),
#  ('practices', 'in'),
#  ('in', 'practices'),
#  ('in', 'the'),
#  ('the', 'in'),
#  ('the', 'appointment'),
#  ('appointment', 'the'),
#  ('appointment', 'of'),
#  ('of', 'appointment'),
#  ('of', 'appraisers'),
#  ('appraisers', 'of'),
#  ('appraisers', ','),
#  (',', 'appraisers'),
#  (',', 'guardians'),
#  ('guardians', ','),
#  ('guardians', 'and'),
#  ('and', 'guardians'),
#  ('and', 'administrators'),
#  ('administrators', 'and'),
#  ('administrators', 'and'),
#  ('and', 'administrators'),
#  ('and', 'the'),
#  ('the', 'and'),
#  ('the', 'awarding'),
#  ('awarding', 'the'),
#  ('awarding', 'of'),
#  ('of', 'awarding'),
#  ('of', 'fees'),
#  ('fees', 'of'),
#  ('fees', 'and'),
#  ('and', 'fees'),
#  ('and', 'compensation'),
#  ('said', 'jury'),
#  ('said', 'it'),
#  ('it', 'said'),
#  ('it', 'found'),
#  ('found', 'it'),
#  ('found', 'the'),
#  ('the', 'found'),
#  ('the', 'court'),
#  ('court', 'the'),
#  ('court', '``'),
#  ('``', 'court'),
#  ('``', 'has'),
#  ('has', '``'),
#  ('has', 'incorporated'),
#  ('incorporated', 'has'),
#  ('incorporated', 'into'),
#  ('into', 'incorporated'),
#  ('into', 'its'),
#  ('its', 'into'),
#  ('its', 'operating'),
#  ('operating', 'its'),
#  ('operating', 'procedures'),
#  ('procedures', 'operating'),
#  ('procedures', 'the'),
#  ('the', 'procedures'),
#  ('the', 'recommendations'),
#  ('recommendations', 'the'),
#  ('recommendations', "''"),
#  ("''", 'recommendations'),
#  ("''", 'of'),
#  ('of', "''"),
#  ('of', 'two'),
#  ('two', 'of'),
#  ('two', 'previous'),
#  ('previous', 'two'),
#  ('previous', 'grand'),
#  ('grand', 'previous'),
#  ('grand', 'juries'),
#  ('juries', 'grand'),
#  ('juries', ','),
#  (',', 'juries'),
#  (',', 'the'),
#  ('the', ','),
#  ('the', 'Atlanta'),
#  ('Atlanta', 'the'),
#  ('Atlanta', 'Bar'),
#  ('Bar', 'Atlanta'),
#  ('Bar', 'Association'),
#  ('Association', 'Bar'),
#  ('Association', 'and'),
#  ('and', 'Association'),
#  ('and', 'an'),
#  ('an', 'and'),
#  ('an', 'interim'),
#  ('interim', 'an'),
#  ('interim', 'citizens'),
#  ('citizens', 'interim'),
#  ('citizens', 'committee'),
#  ('actions', 'These'),
#  ('actions', 'should'),
#  ('should', 'actions'),
#  ('should', 'serve'),
#  ('serve', 'should'),
#  ('serve', 'to'),
#  ('to', 'serve'),
#  ('to', 'protect'),
#  ('protect', 'to'),
#  ('protect', 'in'),
#  ('in', 'protect'),
#  ('in', 'fact'),
#  ('fact', 'in'),
#  ('fact', 'and'),
#  ('and', 'fact'),
#  ('and', 'in'),
#  ('in', 'and'),
#  ('in', 'effect'),
#  ('effect', 'in'),
#  ('effect', 'the'),
#  ('the', 'effect'),
#  ('the', "court's"),
#  ("court's", 'the'),
#  ("court's", 'wards'),
#  ('wards', "court's"),
#  ('wards', 'from'),
#  ('from', 'wards'),
#  ('from', 'undue'),
#  ('undue', 'from'),
#  ('undue', 'costs'),
#  ('costs', 'undue'),
#  ('costs', 'and'),
#  ('and', 'costs'),
#  ('and', 'its'),
#  ('its', 'and'),
#  ('its', 'appointed'),
#  ('appointed', 'its'),
#  ('appointed', 'and'),
#  ('and', 'appointed'),
#  ('and', 'elected'),
#  ('elected', 'and'),
#  ('elected', 'servants'),
#  ('servants', 'elected'),
#  ('servants', 'from'),
#  ('from', 'servants'),
#  ('from', 'unmeritorious'),
#  ...]

# %%
X_ik_skipgram = Counter(skip_grams) # Co-occurece in window size 2
X_ik_skipgram
# Out:
# Counter({('County', 'Fulton'): 6,
#          ('County', 'Grand'): 1,
#          ('Grand', 'County'): 1,
#          ('Grand', 'Jury'): 1,
#          ('Jury', 'Grand'): 2,
#          ('Jury', 'said'): 1,
#          ('said', 'Jury'): 1,
#          ('said', 'Friday'): 4,
#          ('Friday', 'said'): 3,
#          ('Friday', 'an'): 1,
#          ('an', 'Friday'): 1,
#          ('an', 'investigation'): 3,
#          ('investigation', 'an'): 4,
#          ('investigation', 'of'): 4,
#          ('of', 'investigation'): 5,
#          ('of', "Atlanta's"): 1,
#          ("Atlanta's", 'of'): 1,
#          ("Atlanta's", 'recent'): 1,
#          ('recent', "Atlanta's"): 1,
#          ('recent', 'primary'): 1,
#          ('primary', 'recent'): 1,
#          ('primary', 'election'): 2,
#          ('election', 'primary'): 2,
#          ('election', 'produced'): 1,
#          ('produced', 'election'): 1,
#          ('produced', '``'): 1,
#          ('``', 'produced'): 1,
#          ('``', 'no'): 1,
#          ('no', '``'): 1,
#          ('no', 'evidence'): 2,
#          ('evidence', 'no'): 2,
#          ('evidence', "''"): 2,
#          ("''", 'evidence'): 1,
#          ("''", 'that'): 2,
#          ('that', "''"): 3,
#          ('that', 'any'): 4,
#          ('any', 'that'): 4,
#          ('any', 'irregularities'): 1,
#          ('irregularities', 'any'): 1,
#          ('irregularities', 'took'): 1,
#          ('took', 'irregularities'): 1,
#          ('took', 'place'): 4,
#          ('further', 'jury'): 1,
#          ('further', 'said'): 2,
#          ('said', 'further'): 2,
#          ('said', 'in'): 6,
#          ('in', 'said'): 6,
#          ('in', 'term-end'): 1,
#          ('term-end', 'in'): 1,
#          ('term-end', 'presentments'): 1,
#          ('presentments', 'term-end'): 1,
#          ('presentments', 'that'): 1,
#          ('that', 'presentments'): 1,
#          ('that', 'the'): 145,
#          ('the', 'that'): 146,
#          ('the', 'City'): 4,
#          ('City', 'the'): 4,
#          ('City', 'Executive'): 1,
#          ('Executive', 'City'): 1,
#          ('Executive', 'Committee'): 2,
#          ('Committee', 'Executive'): 1,
#          ('Committee', ','): 7,
#          (',', 'Committee'): 7,
#          (',', 'which'): 74,
#          ('which', ','): 76,
#          ('which', 'had'): 7,
#          ('had', 'which'): 7,
#          ('had', 'over-all'): 1,
#          ('over-all', 'had'): 1,
#          ('over-all', 'charge'): 1,
#          ('charge', 'over-all'): 1,
#          ('charge', 'of'): 9,
#          ('of', 'charge'): 9,
#          ('of', 'the'): 805,
#          ('the', 'of'): 844,
#          ('the', 'election'): 8,
#          ('election', 'the'): 9,
#          ('election', ','): 4,
#          (',', 'election'): 4,
#          (',', '``'): 94,
#          ('``', ','): 95,
#          ('``', 'deserves'): 1,
#          ('deserves', '``'): 1,
#          ('deserves', 'the'): 1,
#          ('the', 'deserves'): 1,
#          ('the', 'praise'): 1,
#          ('praise', 'the'): 1,
#          ('praise', 'and'): 1,
#          ('and', 'praise'): 1,
#          ('and', 'thanks'): 1,
#          ('thanks', 'and'): 1,
#          ('thanks', 'of'): 1,
#          ('of', 'thanks'): 1,
#          ('City', 'of'): 2,
#          ('of', 'City'): 2,
#          ('of', 'Atlanta'): 6,
#          ('Atlanta', 'of'): 4,
#          ('Atlanta', "''"): 1,
#          ("''", 'Atlanta'): 1,
#          ("''", 'for'): 3,
#          ('for', "''"): 3,
#          ('for', 'the'): 214,
#          ('the', 'for'): 217,
#          ('the', 'manner'): 2,
#          ('manner', 'the'): 2,
#          ('manner', 'in'): 2,
#          ('in', 'manner'): 2,
#          ('in', 'which'): 21,
#          ('which', 'in'): 21,
#          ('which', 'the'): 24,
#          ('the', 'which'): 24,
#          ('election', 'was'): 2,
#          ('was', 'election'): 2,
#          ('was', 'conducted'): 1,
#          ('term', 'September-October'): 1,
#          ('term', 'jury'): 1,
#          ('jury', 'term'): 1,
#          ('jury', 'had'): 1,
#          ('had', 'jury'): 1,
#          ('had', 'been'): 41,
#          ('been', 'had'): 45,
#          ('been', 'charged'): 1,
#          ('charged', 'been'): 1,
#          ('charged', 'by'): 1,
#          ('by', 'charged'): 1,
#          ('by', 'Fulton'): 1,
#          ('Fulton', 'by'): 1,
#          ('Fulton', 'Superior'): 2,
#          ('Superior', 'Fulton'): 2,
#          ('Superior', 'Court'): 5,
#          ('Court', 'Superior'): 5,
#          ('Court', 'Judge'): 1,
#          ('Judge', 'Court'): 1,
#          ('Judge', 'Durwood'): 1,
#          ('Durwood', 'Judge'): 1,
#          ('Durwood', 'Pye'): 1,
#          ('Pye', 'Durwood'): 1,
#          ('Pye', 'to'): 1,
#          ('to', 'Pye'): 1,
#          ('to', 'investigate'): 3,
#          ('investigate', 'to'): 2,
#          ('investigate', 'reports'): 1,
#          ('reports', 'investigate'): 1,
#          ('reports', 'of'): 4,
#          ('of', 'reports'): 4,
#          ('of', 'possible'): 1,
#          ('possible', 'of'): 1,
#          ('possible', '``'): 1,
#          ('``', 'possible'): 1,
#          ('``', 'irregularities'): 1,
#          ('irregularities', '``'): 1,
#          ('irregularities', "''"): 1,
#          ("''", 'irregularities'): 1,
#          ("''", 'in'): 6,
#          ('in', "''"): 6,
#          ('in', 'the'): 542,
#          ('the', 'in'): 547,
#          ('the', 'hard-fought'): 1,
#          ('hard-fought', 'the'): 1,
#          ('hard-fought', 'primary'): 1,
#          ('primary', 'hard-fought'): 1,
#          ('primary', 'which'): 1,
#          ('which', 'primary'): 1,
#          ('which', 'was'): 7,
#          ('was', 'which'): 7,
#          ('was', 'won'): 2,
#          ('won', 'was'): 2,
#          ('won', 'by'): 3,
#          ('by', 'won'): 3,
#          ('by', 'Mayor-nominate'): 1,
#          ('Mayor-nominate', 'by'): 1,
#          ('Mayor-nominate', 'Ivan'): 1,
#          ('Ivan', 'Mayor-nominate'): 1,
#          ('Ivan', 'Allen'): 2,
#          ('Allen', 'Ivan'): 2,
#          ('Allen', 'Jr.'): 2,
#          ('a', 'Only'): 1,
#          ('a', 'relative'): 1,
#          ('relative', 'a'): 1,
#          ('relative', 'handful'): 1,
#          ('handful', 'relative'): 1,
#          ('handful', 'of'): 1,
#          ('of', 'handful'): 1,
#          ('of', 'such'): 7,
#          ('such', 'of'): 7,
#          ('such', 'reports'): 1,
#          ('reports', 'such'): 1,
#          ('reports', 'was'): 1,
#          ('was', 'reports'): 1,
#          ('was', 'received'): 1,
#          ('received', 'was'): 1,
#          ('received', "''"): 1,
#          ("''", 'received'): 1,
#          ("''", ','): 198,
#          (',', "''"): 198,
#          (',', 'the'): 339,
#          ('the', ','): 364,
#          ('the', 'jury'): 20,
#          ('jury', 'the'): 18,
#          ('jury', 'said'): 5,
#          ('said', 'jury'): 6,
#          ('said', ','): 117,
#          (',', 'said'): 122,
#          ('``', 'considering'): 1,
#          ('considering', '``'): 1,
#          ('considering', 'the'): 1,
#          ('the', 'considering'): 1,
#          ('the', 'widespread'): 1,
#          ('widespread', 'the'): 1,
#          ('widespread', 'interest'): 1,
#          ('interest', 'widespread'): 1,
#          ('interest', 'in'): 8,
#          ('in', 'interest'): 8,
#          ('the', 'number'): 5,
#          ('number', 'the'): 5,
#          ('number', 'of'): 26,
#          ('of', 'number'): 27,
#          ('of', 'voters'): 1,
#          ('voters', 'of'): 1,
#          ('voters', 'and'): 1,
#          ('and', 'voters'): 1,
#          ('and', 'the'): 136,
#          ('the', 'and'): 136,
#          ('the', 'size'): 3,
#          ('size', 'the'): 3,
#          ('size', 'of'): 3,
#          ('of', 'size'): 3,
#          ('of', 'this'): 21,
#          ('this', 'of'): 23,
#          ('this', 'city'): 3,
#          ('city', 'this'): 1,
#          ('city', "''"): 1,
#          ('said', 'it'): 12,
#          ('it', 'said'): 13,
#          ('it', 'did'): 3,
#          ('did', 'it'): 3,
#          ('did', 'find'): 1,
#          ('find', 'did'): 1,
#          ('find', 'that'): 2,
#          ('that', 'find'): 2,
#          ('that', 'many'): 6,
#          ('many', 'that'): 5,
#          ('many', 'of'): 13,
#          ('of', 'many'): 13,
#          ('of', "Georgia's"): 3,
#          ("Georgia's", 'of'): 4,
#          ("Georgia's", 'registration'): 1,
#          ('registration', "Georgia's"): 1,
#          ('registration', 'and'): 1,
#          ('and', 'registration'): 1,
#          ('and', 'election'): 1,
#          ('election', 'and'): 1,
#          ('election', 'laws'): 1,
#          ('laws', 'election'): 1,
#          ('laws', '``'): 1,
#          ('``', 'laws'): 1,
#          ('``', 'are'): 8,
#          ('are', '``'): 8,
#          ('are', 'outmoded'): 1,
#          ('outmoded', 'are'): 1,
#          ('outmoded', 'or'): 1,
#          ('or', 'outmoded'): 1,
#          ('or', 'inadequate'): 1,
#          ('inadequate', 'or'): 1,
#          ('inadequate', 'and'): 1,
#          ('and', 'inadequate'): 1,
#          ('and', 'often'): 3,
#          ('often', 'and'): 3,
#          ('often', 'ambiguous'): 1,
#          ('ambiguous', 'often'): 1,
#          ('ambiguous', "''"): 1,
#          ('that', 'recommended'): 4,
#          ('that', 'Fulton'): 1,
#          ('Fulton', 'that'): 1,
#          ('Fulton', 'legislators'): 1,
#          ('legislators', 'Fulton'): 1,
#          ('legislators', 'act'): 1,
#          ('act', 'legislators'): 1,
#          ('act', '``'): 1,
#          ('``', 'act'): 1,
#          ('``', 'to'): 18,
#          ('to', '``'): 18,
#          ('to', 'have'): 44,
#          ('have', 'to'): 44,
#          ('have', 'these'): 2,
#          ('these', 'have'): 2,
#          ('these', 'laws'): 2,
#          ('laws', 'these'): 2,
#          ('laws', 'studied'): 1,
#          ('studied', 'laws'): 1,
#          ('studied', 'and'): 1,
#          ('and', 'studied'): 1,
#          ('and', 'revised'): 1,
#          ('revised', 'and'): 1,
#          ('revised', 'to'): 1,
#          ('to', 'revised'): 1,
#          ('to', 'the'): 268,
#          ('the', 'to'): 273,
#          ('the', 'end'): 13,
#          ('end', 'the'): 13,
#          ('end', 'of'): 9,
#          ('of', 'end'): 9,
#          ('of', 'modernizing'): 1,
#          ('modernizing', 'of'): 1,
#          ('modernizing', 'and'): 1,
#          ('and', 'modernizing'): 1,
#          ('and', 'improving'): 1,
#          ('improving', 'and'): 1,
#          ('improving', 'them'): 1,
#          ('them', 'improving'): 1,
#          ('them', "''"): 7,
#          ('jury', 'grand'): 5,
#          ('jury', 'commented'): 1,
#          ('commented', 'jury'): 1,
#          ('commented', 'on'): 2,
#          ('on', 'commented'): 2,
#          ('on', 'a'): 50,
#          ('a', 'on'): 51,
#          ('a', 'number'): 17,
#          ('number', 'a'): 18,
#          ('of', 'other'): 8,
#          ('other', 'of'): 8,
#          ('other', 'topics'): 1,
#          ('topics', 'other'): 1,
#          ('topics', ','): 1,
#          (',', 'topics'): 1,
#          (',', 'among'): 6,
#          ('among', ','): 6,
#          ('among', 'them'): 2,
#          ('them', 'among'): 2,
#          ('them', 'the'): 3,
#          ('the', 'them'): 3,
#          ('the', 'Atlanta'): 5,
#          ('Atlanta', 'the'): 5,
#          ('Atlanta', 'and'): 1,
#          ('and', 'Atlanta'): 1,
#          ('and', 'Fulton'): 1,
#          ('Fulton', 'and'): 1,
#          ('Fulton', 'County'): 5,
#          ('County', 'purchasing'): 1,
#          ('purchasing', 'County'): 1,
#          ('purchasing', 'departments'): 1,
#          ('departments', 'purchasing'): 1,
#          ('departments', 'which'): 1,
#          ('which', 'departments'): 1,
#          ('which', 'it'): 5,
#          ('it', 'which'): 5,
#          ('said', '``'): 3,
#          ('``', 'said'): 4,
#          ('are', 'well'): 2,
#          ('well', 'are'): 2,
#          ('well', 'operated'): 1,
#          ('operated', 'well'): 1,
#          ('operated', 'and'): 2,
#          ('and', 'operated'): 2,
#          ('and', 'follow'): 1,
#          ('follow', 'and'): 1,
#          ('follow', 'generally'): 1,
#          ('generally', 'follow'): 1,
#          ('generally', 'accepted'): 1,
#          ('accepted', 'generally'): 1,
#          ('accepted', 'practices'): 1,
#          ('practices', 'accepted'): 1,
#          ('practices', 'which'): 1,
#          ('which', 'practices'): 1,
#          ('which', 'inure'): 1,
#          ('inure', 'which'): 1,
#          ('inure', 'to'): 1,
#          ('to', 'inure'): 1,
#          ('the', 'best'): 15,
#          ('best', 'the'): 13,
#          ('best', 'interest'): 1,
#          ('interest', 'best'): 1,
#          ('interest', 'of'): 6,
#          ('of', 'interest'): 6,
#          ('of', 'both'): 12,
#          ('both', 'of'): 12,
#          ('both', 'governments'): 1,
#          ('governments', 'both'): 1,
#          ('governments', "''"): 1,
#          ('it', 'believes'): 2,
#          ('believes', 'it'): 2,
#          ('believes', '``'): 1,
#          ('``', 'believes'): 1,
#          ('``', 'these'): 3,
#          ('these', '``'): 3,
#          ('these', 'two'): 3,
#          ('two', 'these'): 3,
#          ('two', 'offices'): 1,
#          ('offices', 'two'): 1,
#          ('offices', 'should'): 1,
#          ('should', 'offices'): 1,
#          ('should', 'be'): 28,
#          ('be', 'should'): 29,
#          ('be', 'combined'): 1,
#          ('combined', 'be'): 1,
#          ('combined', 'to'): 3,
#          ('to', 'combined'): 3,
#          ('to', 'achieve'): 6,
#          ('achieve', 'to'): 6,
#          ('achieve', 'greater'): 1,
#          ('greater', 'achieve'): 1,
#          ('greater', 'efficiency'): 1,
#          ('efficiency', 'greater'): 1,
#          ('efficiency', 'and'): 1,
#          ('and', 'efficiency'): 1,
#          ('and', 'reduce'): 1,
#          ('reduce', 'and'): 1,
#          ('reduce', 'the'): 4,
#          ('the', 'reduce'): 4,
#          ('the', 'cost'): 3,
#          ('cost', 'the'): 3,
#          ('cost', 'of'): 5,
#          ('of', 'cost'): 6,
#          ('of', 'administration'): 2,
#          ('administration', 'of'): 2,
#          ('administration', "''"): 1,
#          ('Purchasing', 'City'): 1,
#          ('Purchasing', 'Department'): 1,
#          ('Department', 'Purchasing'): 1,
#          ('Department', ','): 2,
#          (',', 'Department'): 2,
#          ('``', 'is'): 12,
#          ('is', '``'): 12,
#          ('is', 'lacking'): 1,
#          ('lacking', 'is'): 1,
#          ('lacking', 'in'): 2,
#          ('in', 'lacking'): 2,
#          ('in', 'experienced'): 1,
#          ('experienced', 'in'): 1,
#          ('experienced', 'clerical'): 1,
#          ('clerical', 'experienced'): 1,
#          ('clerical', 'personnel'): 1,
#          ('personnel', 'clerical'): 1,
#          ('personnel', 'as'): 1,
#          ('as', 'personnel'): 1,
#          ('as', 'a'): 81,
#          ('a', 'as'): 81,
#          ('a', 'result'): 14,
#          ('result', 'a'): 19,
#          ('result', 'of'): 17,
#          ('of', 'result'): 17,
#          ('of', 'city'): 3,
#          ('city', 'of'): 3,
#          ('city', 'personnel'): 1,
#          ('personnel', 'city'): 1,
#          ('personnel', 'policies'): 2,
#          ('policies', 'personnel'): 2,
#          ('policies', "''"): 1,
#          ('that', 'urged'): 4,
#          ('the', 'city'): 21,
#          ('city', 'the'): 19,
#          ('city', '``'): 1,
#          ('``', 'city'): 1,
#          ('``', 'take'): 1,
#          ('take', '``'): 1,
#          ('take', 'steps'): 2,
#          ('steps', 'take'): 2,
#          ('steps', 'to'): 4,
#          ('to', 'steps'): 4,
#          ('to', 'remedy'): 1,
#          ('remedy', 'to'): 1,
#          ('remedy', "''"): 1,
#          ("''", 'remedy'): 1,
#          ("''", 'this'): 3,
#          ('this', "''"): 4,
#          ('this', 'problem'): 3,
#          ("Georgia's", 'automobile'): 1,
#          ('automobile', "Georgia's"): 1,
#          ('automobile', 'title'): 1,
#          ('title', 'automobile'): 1,
#          ('title', 'law'): 1,
#          ('law', 'title'): 1,
#          ('law', 'was'): 2,
#          ('was', 'law'): 2,
#          ('was', 'also'): 11,
#          ('also', 'was'): 12,
#          ('also', 'recommended'): 2,
#          ('recommended', 'also'): 2,
#          ('recommended', 'by'): 1,
#          ('by', 'recommended'): 1,
#          ('by', 'the'): 109,
#          ('the', 'by'): 111,
#          ('the', 'outgoing'): 1,
#          ('outgoing', 'the'): 1,
#          ('outgoing', 'jury'): 1,
#          ('the', 'next'): 16,
#          ('next', 'the'): 16,
#          ('next', 'Legislature'): 1,
#          ('Legislature', 'next'): 1,
#          ('Legislature', '``'): 1,
#          ('``', 'Legislature'): 1,
#          ('``', 'provide'): 2,
#          ('provide', '``'): 2,
#          ('provide', 'enabling'): 1,
#          ('enabling', 'provide'): 1,
#          ('enabling', 'funds'): 1,
#          ('funds', 'enabling'): 1,
#          ('funds', 'and'): 3,
#          ('and', 'funds'): 3,
#          ('and', 're-set'): 1,
#          ('re-set', 'and'): 1,
#          ('re-set', 'the'): 1,
#          ('the', 're-set'): 1,
#          ('the', 'effective'): 2,
#          ('effective', 'the'): 2,
#          ('effective', 'date'): 1,
#          ('date', 'effective'): 1,
#          ('date', 'so'): 1,
#          ('so', 'date'): 1,
#          ('so', 'that'): 10,
#          ('that', 'so'): 10,
#          ('that', 'an'): 5,
#          ('an', 'that'): 5,
#          ('an', 'orderly'): 2,
#          ('orderly', 'an'): 2,
#          ('orderly', 'implementation'): 1,
#          ('implementation', 'orderly'): 1,
#          ('implementation', 'of'): 1,
#          ('of', 'implementation'): 1,
#          ('the', 'law'): 8,
#          ('law', 'the'): 6,
#          ('law', 'may'): 1,
#          ('may', 'law'): 1,
#          ('may', 'be'): 22,
#          ('be', 'may'): 23,
#          ('be', 'effected'): 1,
#          ('effected', 'be'): 1,
#          ('effected', "''"): 1,
#          ('jury', 'took'): 1,
#          ('took', 'jury'): 1,
#          ('took', 'a'): 4,
#          ('a', 'took'): 5,
#          ('a', 'swipe'): 1,
#          ('swipe', 'a'): 1,
#          ('swipe', 'at'): 1,
#          ('at', 'swipe'): 1,
#          ('at', 'the'): 177,
#          ('the', 'at'): 179,
#          ('the', 'State'): 17,
#          ('State', 'the'): 17,
#          ('State', 'Welfare'): 2,
#          ('Welfare', 'State'): 2,
#          ('Welfare', "Department's"): 1,
#          ("Department's", 'Welfare'): 1,
#          ("Department's", 'handling'): 1,
#          ('handling', "Department's"): 1,
#          ('handling', 'of'): 2,
#          ('of', 'handling'): 2,
#          ('of', 'federal'): 3,
#          ('federal', 'of'): 3,
#          ('federal', 'funds'): 2,
#          ('funds', 'federal'): 2,
#          ('funds', 'granted'): 1,
#          ('granted', 'funds'): 1,
#          ('granted', 'for'): 1,
#          ('for', 'granted'): 1,
#          ('for', 'child'): 1,
#          ('child', 'for'): 1,
#          ('child', 'welfare'): 1,
#          ('welfare', 'child'): 1,
#          ('welfare', 'services'): 1,
#          ('services', 'welfare'): 1,
#          ('services', 'in'): 1,
#          ('in', 'services'): 1,
#          ('in', 'foster'): 1,
#          ('foster', 'in'): 1,
#          ('foster', 'homes'): 1,
#          ('is', 'This'): 9,
#          ('is', 'one'): 10,
#          ('one', 'is'): 13,
#          ('one', 'of'): 58,
#          ('of', 'one'): 61,
#          ('the', 'major'): 5,
#          ('major', 'the'): 5,
#          ('major', 'items'): 1,
#          ('items', 'major'): 1,
#          ('items', 'in'): 1,
#          ('in', 'items'): 1,
#          ('the', 'Fulton'): 5,
#          ('Fulton', 'the'): 5,
#          ('County', 'general'): 1,
#          ('general', 'County'): 1,
#          ('general', 'assistance'): 2,
#          ('assistance', 'general'): 2,
#          ('assistance', 'program'): 1,
#          ('program', 'assistance'): 1,
#          ('program', "''"): 1,
#          ("''", 'program'): 1,
#          (',', 'but'): 94,
#          ('but', ','): 94,
#          ('but', 'the'): 16,
#          ('the', 'but'): 16,
#          ('Welfare', 'Department'): 1,
#          ('Department', 'Welfare'): 1,
#          ('Department', '``'): 1,
#          ('``', 'Department'): 1,
#          ('``', 'has'): 3,
#          ('has', '``'): 3,
#          ('has', 'seen'): 2,
#          ('seen', 'has'): 2,
#          ('seen', 'fit'): 1,
#          ('fit', 'seen'): 1,
#          ('fit', 'to'): 2,
#          ('to', 'fit'): 2,
#          ('to', 'distribute'): 1,
#          ('distribute', 'to'): 1,
#          ('distribute', 'these'): 1,
#          ('these', 'distribute'): 1,
#          ('these', 'funds'): 3,
#          ('funds', 'these'): 3,
#          ('funds', 'through'): 1,
#          ('through', 'funds'): 1,
#          ('through', 'the'): 21,
#          ('the', 'through'): 21,
#          ('the', 'welfare'): 3,
#          ('welfare', 'the'): 3,
#          ('welfare', 'departments'): 1,
#          ('departments', 'welfare'): 1,
#          ('departments', 'of'): 1,
#          ('of', 'departments'): 1,
#          ('of', 'all'): 32,
#          ('all', 'of'): 31,
#          ('all', 'the'): 18,
#          ('the', 'all'): 21,
#          ('the', 'counties'): 1,
#          ('counties', 'the'): 1,
#          ('counties', 'in'): 3,
#          ('in', 'counties'): 3,
#          ('the', 'state'): 44,
#          ('state', 'the'): 39,
#          ('state', 'with'): 2,
#          ('with', 'state'): 2,
#          ('with', 'the'): 131,
#          ('the', 'with'): 134,
#          ('the', 'exception'): 1,
#          ('exception', 'the'): 2,
#          ('exception', 'of'): 3,
#          ('of', 'exception'): 3,
#          ('of', 'Fulton'): 1,
#          ('Fulton', 'of'): 1,
#          ('County', ','): 5,
#          (',', 'County'): 5,
#          ('which', 'receives'): 1,
#          ('receives', 'which'): 1,
#          ('receives', 'none'): 1,
#          ('none', 'receives'): 1,
#          ('none', 'of'): 3,
#          ('of', 'none'): 3,
#          ('this', 'money'): 1,
#          ('said', 'jurors'): 1,
#          ('said', 'they'): 8,
#          ('they', 'said'): 8,
#          ('they', 'realize'): 1,
#          ('realize', 'they'): 1,
#          ('realize', '``'): 1,
#          ('``', 'realize'): 1,
#          ('``', 'a'): 29,
#          ('a', '``'): 29,
#          ('a', 'proportionate'): 1,
#          ('proportionate', 'a'): 1,
#          ('proportionate', 'distribution'): 1,
#          ('distribution', 'proportionate'): 1,
#          ('distribution', 'of'): 3,
#          ('of', 'distribution'): 3,
#          ('of', 'these'): 14,
#          ('these', 'of'): 18,
#          ('funds', 'might'): 1,
#          ('might', 'funds'): 1,
#          ('might', 'disable'): 1,
#          ('disable', 'might'): 1,
#          ('disable', 'this'): 1,
#          ('this', 'disable'): 1,
#          ('this', 'program'): 2,
#          ('program', 'this'): 2,
#          ('program', 'in'): 5,
#          ('in', 'program'): 5,
#          ('in', 'our'): 5,
#          ('our', 'in'): 5,
#          ('our', 'less'): 1,
#          ('less', 'our'): 1,
#          ('less', 'populous'): 2,
#          ('populous', 'less'): 2,
#          ('populous', 'counties'): 1,
#          ('counties', 'populous'): 1,
#          ('counties', "''"): 1,
#          ('``', 'we'): 4,
#          ('we', '``'): 4,
#          ('we', 'feel'): 1,
#          ('feel', 'we'): 1,
#          ('feel', 'that'): 4,
#          ('that', 'feel'): 4,
#          ('that', 'in'): 6,
#          ('in', 'that'): 6,
#          ('the', 'future'): 10,
#          ('future', 'the'): 10,
#          ('future', 'Fulton'): 1,
#          ('Fulton', 'future'): 1,
#          ('County', 'should'): 1,
#          ('should', 'County'): 1,
#          ('should', 'receive'): 1,
#          ('receive', 'should'): 1,
#          ('receive', 'some'): 1,
#          ('some', 'receive'): 1,
#          ('some', 'portion'): 1,
#          ('portion', 'some'): 1,
#          ('portion', 'of'): 2,
#          ('of', 'portion'): 2,
#          ('these', 'available'): 1,
#          ('available', 'these'): 1,
#          ('available', 'funds'): 1,
#          ('funds', 'available'): 1,
#          ('funds', "''"): 2,
#          ("''", 'funds'): 2,
#          ('the', 'jurors'): 3,
#          ('jurors', 'the'): 3,
#          ('jurors', 'said'): 1,
#          ('to', 'Failure'): 1,
#          ('to', 'do'): 18,
#          ('do', 'to'): 18,
#          ('do', 'this'): 1,
#          ('this', 'do'): 1,
#          ('this', 'will'): 2,
#          ('will', 'this'): 2,
#          ('will', 'continue'): 3,
#          ('continue', 'will'): 3,
#          ('continue', 'to'): 9,
#          ('to', 'continue'): 9,
#          ('to', 'place'): 4,
#          ('place', 'to'): 3,
#          ('place', 'a'): 2,
#          ('a', 'place'): 2,
#          ('a', 'disproportionate'): 1,
#          ('disproportionate', 'a'): 1,
#          ('disproportionate', 'burden'): 1,
#          ('burden', 'disproportionate'): 1,
#          ('burden', "''"): 1,
#          ("''", 'burden'): 1,
#          ("''", 'on'): 12,
#          ('on', "''"): 12,
#          ('on', 'Fulton'): 1,
#          ('Fulton', 'on'): 1,
#          ('Fulton', 'taxpayers'): 1,
#          ('also', 'jury'): 1,
#          ('also', 'commented'): 1,
#          ('commented', 'also'): 1,
#          ('on', 'the'): 236,
#          ('the', 'on'): 238,
#          ('Fulton', "ordinary's"): 1,
#          ("ordinary's", 'Fulton'): 1,
#          ("ordinary's", 'court'): 1,
#          ('court', "ordinary's"): 1,
#          ('court', 'which'): 1,
#          ('which', 'court'): 1,
#          ('which', 'has'): 7,
#          ('has', 'which'): 7,
#          ('has', 'been'): 76,
#          ('been', 'has'): 87,
#          ('been', 'under'): 3,
#          ('under', 'been'): 3,
#          ('under', 'fire'): 2,
#          ('fire', 'under'): 2,
#          ('fire', 'for'): 2,
#          ('for', 'fire'): 2,
#          ('for', 'its'): 6,
#          ('its', 'for'): 7,
#          ('its', 'practices'): 1,
#          ('practices', 'its'): 1,
#          ('practices', 'in'): 1,
#          ('in', 'practices'): 1,
#          ('the', 'appointment'): 3,
#          ('appointment', 'the'): 3,
#          ('appointment', 'of'): 6,
#          ('of', 'appointment'): 6,
#          ('of', 'appraisers'): 1,
#          ('appraisers', 'of'): 1,
#          ('appraisers', ','): 1,
#          (',', 'appraisers'): 1,
#          (',', 'guardians'): 1,
#          ('guardians', ','): 1,
#          ('guardians', 'and'): 1,
#          ('and', 'guardians'): 1,
#          ('and', 'administrators'): 2,
#          ('administrators', 'and'): 2,
#          ('the', 'awarding'): 1,
#          ('awarding', 'the'): 1,
#          ('awarding', 'of'): 1,
#          ('of', 'awarding'): 1,
#          ('of', 'fees'): 1,
#          ('fees', 'of'): 1,
#          ('fees', 'and'): 1,
#          ('and', 'fees'): 1,
#          ('and', 'compensation'): 1,
#          ('it', 'found'): 1,
#          ('found', 'it'): 1,
#          ('found', 'the'): 4,
#          ('the', 'found'): 4,
#          ('the', 'court'): 6,
#          ('court', 'the'): 5,
#          ('court', '``'): 1,
#          ('``', 'court'): 1,
#          ('has', 'incorporated'): 1,
#          ('incorporated', 'has'): 1,
#          ('incorporated', 'into'): 1,
#          ('into', 'incorporated'): 1,
#          ('into', 'its'): 1,
#          ('its', 'into'): 1,
#          ('its', 'operating'): 1,
#          ('operating', 'its'): 1,
#          ('operating', 'procedures'): 1,
#          ('procedures', 'operating'): 1,
#          ('procedures', 'the'): 1,
#          ('the', 'procedures'): 1,
#          ('the', 'recommendations'): 1,
#          ('recommendations', 'the'): 1,
#          ('recommendations', "''"): 1,
#          ("''", 'recommendations'): 1,
#          ("''", 'of'): 10,
#          ('of', "''"): 10,
#          ('of', 'two'): 17,
#          ('two', 'of'): 17,
#          ('two', 'previous'): 2,
#          ('previous', 'two'): 2,
#          ('previous', 'grand'): 1,
#          ('grand', 'previous'): 1,
#          ('grand', 'juries'): 1,
#          ('juries', 'grand'): 1,
#          ('juries', ','): 1,
#          (',', 'juries'): 1,
#          ('Atlanta', 'Bar'): 1,
#          ('Bar', 'Atlanta'): 1,
#          ('Bar', 'Association'): 1,
#          ('Association', 'Bar'): 1,
#          ('Association', 'and'): 1,
#          ('and', 'Association'): 1,
#          ('and', 'an'): 9,
#          ('an', 'and'): 9,
#          ('an', 'interim'): 1,
#          ('interim', 'an'): 1,
#          ('interim', 'citizens'): 1,
#          ('citizens', 'interim'): 1,
#          ('citizens', 'committee'): 2,
#          ('actions', 'These'): 1,
#          ('actions', 'should'): 1,
#          ('should', 'actions'): 1,
#          ('should', 'serve'): 1,
#          ('serve', 'should'): 1,
#          ('serve', 'to'): 5,
#          ('to', 'serve'): 6,
#          ('to', 'protect'): 2,
#          ('protect', 'to'): 2,
#          ('protect', 'in'): 1,
#          ('in', 'protect'): 1,
#          ('in', 'fact'): 6,
#          ('fact', 'in'): 6,
#          ('fact', 'and'): 2,
#          ('and', 'fact'): 2,
#          ('and', 'in'): 16,
#          ('in', 'and'): 16,
#          ('in', 'effect'): 2,
#          ('effect', 'in'): 2,
#          ('effect', 'the'): 3,
#          ('the', 'effect'): 3,
#          ('the', "court's"): 1,
#          ("court's", 'the'): 1,
#          ("court's", 'wards'): 1,
#          ('wards', "court's"): 1,
#          ('wards', 'from'): 1,
#          ('from', 'wards'): 1,
#          ('from', 'undue'): 1,
#          ('undue', 'from'): 1,
#          ('undue', 'costs'): 1,
#          ('costs', 'undue'): 1,
#          ('costs', 'and'): 1,
#          ('and', 'costs'): 1,
#          ('and', 'its'): 8,
#          ('its', 'and'): 8,
#          ('its', 'appointed'): 1,
#          ('appointed', 'its'): 1,
#          ('appointed', 'and'): 1,
#          ('and', 'appointed'): 1,
#          ('and', 'elected'): 1,
#          ('elected', 'and'): 1,
#          ('elected', 'servants'): 1,
#          ('servants', 'elected'): 1,
#          ('servants', 'from'): 1,
#          ('from', 'servants'): 1,
#          ('from', 'unmeritorious'): 1,
#          ('unmeritorious', 'from'): 1,
#          ('unmeritorious', 'criticisms'): 1,
#          ('criticisms', 'unmeritorious'): 1,
#          ('criticisms', "''"): 1,
#          ("''", 'criticisms'): 1,
#          ('new', "Atlanta's"): 1,
#          ('new', 'multi-million-dollar'): 1,
#          ('multi-million-dollar', 'new'): 1,
#          ('multi-million-dollar', 'airport'): 1,
#          ('airport', 'multi-million-dollar'): 1,
#          ('airport', ','): 1,
#          (',', 'airport'): 1,
#          ('jury', 'recommended'): 2,
#          ('recommended', 'jury'): 2,
#          ('recommended', '``'): 1,
#          ('``', 'recommended'): 1,
#          ('``', 'that'): 12,
#          ('that', '``'): 12,
#          ('that', 'when'): 3,
#          ('when', 'that'): 3,
#          ('when', 'the'): 33,
#          ('the', 'when'): 33,
#          ('the', 'new'): 28,
#          ('new', 'the'): 29,
#          ('new', 'management'): 1,
#          ('management', 'new'): 1,
#          ('management', 'takes'): 1,
#          ('takes', 'management'): 1,
#          ('takes', 'charge'): 1,
#          ('charge', 'takes'): 1,
#          ('charge', 'Jan.'): 1,
#          ('Jan.', 'charge'): 1,
#          ('Jan.', '1'): 4,
#          ('1', 'Jan.'): 2,
#          ('1', 'the'): 1,
#          ('the', '1'): 1,
#          ('the', 'airport'): 2,
#          ('airport', 'the'): 2,
#          ('airport', 'be'): 1,
#          ('be', 'airport'): 1,
#          ('be', 'operated'): 1,
#          ('operated', 'be'): 1,
#          ('operated', 'in'): 1,
#          ('in', 'operated'): 1,
#          ('in', 'a'): 117,
#          ('a', 'in'): 117,
#          ('a', 'manner'): 1,
#          ('manner', 'a'): 1,
#          ('manner', 'that'): 1,
#          ('that', 'manner'): 1,
#          ('that', 'will'): 5,
#          ('will', 'that'): 5,
#          ('will', 'eliminate'): 1,
#          ('eliminate', 'will'): 1,
#          ('eliminate', 'political'): 1,
#          ('political', 'eliminate'): 1,
#          ('political', 'influences'): 1,
#          ('influences', 'political'): 1,
#          ('influences', "''"): 1,
#          ('did', 'jury'): 1,
#          ('did', 'not'): 19,
#          ('not', 'did'): 21,
#          ('not', 'elaborate'): 1,
#          ('elaborate', 'not'): 1,
#          ('elaborate', ','): 2,
#          (',', 'elaborate'): 2,
#          ('but', 'it'): 5,
#          ('it', 'but'): 5,
#          ('it', 'added'): 1,
#          ('added', 'it'): 1,
#          ('added', 'that'): 6,
#          ('that', 'added'): 7,
#          ('``', 'there'): 5,
#          ('there', '``'): 5,
#          ('there', 'should'): 2,
#          ('should', 'there'): 2,
#          ('be', 'periodic'): 1,
#          ('periodic', 'be'): 1,
#          ('periodic', 'surveillance'): 1,
#          ('surveillance', 'periodic'): 1,
#          ('surveillance', 'of'): 1,
#          ('of', 'surveillance'): 1,
#          ('the', 'pricing'): 1,
#          ('pricing', 'the'): 1,
#          ('pricing', 'practices'): 1,
#          ('practices', 'pricing'): 1,
#          ('practices', 'of'): 1,
#          ('of', 'practices'): 1,
#          ('the', 'concessionaires'): 1,
#          ('concessionaires', 'the'): 1,
#          ('concessionaires', 'for'): 1,
#          ('for', 'concessionaires'): 1,
#          ('the', 'purpose'): 2,
#          ('purpose', 'the'): 2,
#          ('purpose', 'of'): 5,
#          ('of', 'purpose'): 6,
#          ('of', 'keeping'): 1,
#          ('keeping', 'of'): 1,
#          ('keeping', 'the'): 1,
#          ('the', 'keeping'): 1,
#          ('the', 'prices'): 3,
#          ('prices', 'the'): 3,
#          ('prices', 'reasonable'): 1,
#          ('reasonable', 'prices'): 1,
#          ('reasonable', "''"): 1,
#          ('matters', 'other'): 1,
#          ('matters', ','): 2,
#          (',', 'matters'): 2,
#          ('recommended', 'that'): 3,
#          ('that', ':'): 1,
#          (':', 'that'): 1,
#          (':', '('): 1,
#          ...})

# %% [markdown]
# ### Weighting function
#
# GloVe includes a weighting function to scale down too frequent words.
#
# <img src = "figures/glove_weighting_func.png" width=400>

# %%
#simply a normalized function...don't worry too much
def weighting(w_i, w_j, X_ik):
        
    #check whether the co-occurrences exist between these two words
    try:
        x_ij = X_ik[(w_i, w_j)]
    except:
        x_ij = 1  #if does not exist, set it to 1
                
    x_max = 100 #100 # fixed in paper  #cannot exceed 100 counts
    alpha = 0.75
    
    #if co-occurrence does not exceed 100, scale it based on some alpha
    if x_ij < x_max:
        result = (x_ij/x_max)**alpha  #scale it
    else:
        result = 1  #if is greater than max, set it to 1 maximum
    
    return result

# %%
from itertools import combinations_with_replacement

X_ik = {}  #for keeping the co-occurences
weighting_dic = {} #scaling the percentage of sampling

for bigram in combinations_with_replacement(vocab, 2):
    if X_ik_skipgram.get(bigram) is not None:  #matches 
        co_occer = X_ik_skipgram[bigram]  #get the count from what we already counted
        X_ik[bigram] = co_occer + 1 # + 1 for stability issue
        X_ik[(bigram[1],bigram[0])] = co_occer+1   #count also for the opposite
    else:
        pass
        
    weighting_dic[bigram] = weighting(bigram[0], bigram[1], X_ik)
    weighting_dic[(bigram[1], bigram[0])] = weighting(bigram[1], bigram[0], X_ik)

print(f"{X_ik=}")
print(f"{weighting_dic=}")
# Out:
# Exception in callback BaseAsyncIOLoop._handle_events(1316, 1)
# handle: <Handle BaseAsyncIOLoop._handle_events(1316, 1)>
# Traceback (most recent call last):
#   File "c:\Users\Ekkar\anaconda3\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Ekkar\anaconda3\lib\site-packages\tornado\platform\asyncio.py", line 189, in _handle_events
#     handler_func(fileobj, events)
#   File "c:\Users\Ekkar\anaconda3\lib\site-packages\zmq\eventloop\zmqstream.py", line 577, in _handle_events
#     self._handle_recv()
#   File "c:\Users\Ekkar\anaconda3\lib\site-packages\zmq\eventloop\zmqstream.py", line 606, in _handle_recv
#     self._run_callback(callback, msg)
#   File "c:\Users\Ekkar\anaconda3\lib\site-packages\zmq\eventloop\zmqstream.py", line 556, in _run_callback
#     callback(*args, **kwargs)
#   File "c:\Users\Ekkar\anaconda3\lib\site-packages\ipykernel\iostream.py", line 120, in _handle_event
#     event_f()
#   File "c:\Users\Ekkar\anaconda3\lib\site-packages\ipykernel\iostream.py", line 510, in _flush
#     self.session.send(
#   File "c:\Users\Ekkar\anaconda3\lib\site-packages\jupyter_client\session.py", line 844, in send
#     to_send = self.serialize(msg, ident)
#   File "c:\Users\Ekkar\anaconda3\lib\site-packages\jupyter_client\session.py", line 718, in serialize
#     content = self.pack(content)
#   File "c:\Users\Ekkar\anaconda3\lib\site-packages\jupyter_client\session.py", line 99, in json_packer
#     return json.dumps(
#   File "c:\Users\Ekkar\anaconda3\lib\json\__init__.py", line 234, in dumps
#     return cls(
#   File "c:\Users\Ekkar\anaconda3\lib\json\encoder.py", line 199, in encode
#     chunks = self.iterencode(o, _one_shot=True)
#   File "c:\Users\Ekkar\anaconda3\lib\json\encoder.py", line 257, in iterencode
#     return _iterencode(o, 0)
# MemoryError

# %% [markdown]
# ## 3. Prepare train data

# %%
for c in corpus:
    print(c)
# Out:
# ['The', 'Fulton', 'County', 'Grand', 'Jury', 'said', 'Friday', 'an', 'investigation', 'of', "Atlanta's", 'recent', 'primary', 'election', 'produced', '``', 'no', 'evidence', "''", 'that', 'any', 'irregularities', 'took', 'place', '.']
# ['The', 'jury', 'further', 'said', 'in', 'term-end', 'presentments', 'that', 'the', 'City', 'Executive', 'Committee', ',', 'which', 'had', 'over-all', 'charge', 'of', 'the', 'election', ',', '``', 'deserves', 'the', 'praise', 'and', 'thanks', 'of', 'the', 'City', 'of', 'Atlanta', "''", 'for', 'the', 'manner', 'in', 'which', 'the', 'election', 'was', 'conducted', '.']
# ['The', 'September-October', 'term', 'jury', 'had', 'been', 'charged', 'by', 'Fulton', 'Superior', 'Court', 'Judge', 'Durwood', 'Pye', 'to', 'investigate', 'reports', 'of', 'possible', '``', 'irregularities', "''", 'in', 'the', 'hard-fought', 'primary', 'which', 'was', 'won', 'by', 'Mayor-nominate', 'Ivan', 'Allen', 'Jr.', '.']
# ['``', 'Only', 'a', 'relative', 'handful', 'of', 'such', 'reports', 'was', 'received', "''", ',', 'the', 'jury', 'said', ',', '``', 'considering', 'the', 'widespread', 'interest', 'in', 'the', 'election', ',', 'the', 'number', 'of', 'voters', 'and', 'the', 'size', 'of', 'this', 'city', "''", '.']
# ['The', 'jury', 'said', 'it', 'did', 'find', 'that', 'many', 'of', "Georgia's", 'registration', 'and', 'election', 'laws', '``', 'are', 'outmoded', 'or', 'inadequate', 'and', 'often', 'ambiguous', "''", '.']
# ['It', 'recommended', 'that', 'Fulton', 'legislators', 'act', '``', 'to', 'have', 'these', 'laws', 'studied', 'and', 'revised', 'to', 'the', 'end', 'of', 'modernizing', 'and', 'improving', 'them', "''", '.']
# ['The', 'grand', 'jury', 'commented', 'on', 'a', 'number', 'of', 'other', 'topics', ',', 'among', 'them', 'the', 'Atlanta', 'and', 'Fulton', 'County', 'purchasing', 'departments', 'which', 'it', 'said', '``', 'are', 'well', 'operated', 'and', 'follow', 'generally', 'accepted', 'practices', 'which', 'inure', 'to', 'the', 'best', 'interest', 'of', 'both', 'governments', "''", '.']
# ['Merger', 'proposed']
# ['However', ',', 'the', 'jury', 'said', 'it', 'believes', '``', 'these', 'two', 'offices', 'should', 'be', 'combined', 'to', 'achieve', 'greater', 'efficiency', 'and', 'reduce', 'the', 'cost', 'of', 'administration', "''", '.']
# ['The', 'City', 'Purchasing', 'Department', ',', 'the', 'jury', 'said', ',', '``', 'is', 'lacking', 'in', 'experienced', 'clerical', 'personnel', 'as', 'a', 'result', 'of', 'city', 'personnel', 'policies', "''", '.']
# ['It', 'urged', 'that', 'the', 'city', '``', 'take', 'steps', 'to', 'remedy', "''", 'this', 'problem', '.']
# ['Implementation', 'of', "Georgia's", 'automobile', 'title', 'law', 'was', 'also', 'recommended', 'by', 'the', 'outgoing', 'jury', '.']
# ['It', 'urged', 'that', 'the', 'next', 'Legislature', '``', 'provide', 'enabling', 'funds', 'and', 're-set', 'the', 'effective', 'date', 'so', 'that', 'an', 'orderly', 'implementation', 'of', 'the', 'law', 'may', 'be', 'effected', "''", '.']
# ['The', 'grand', 'jury', 'took', 'a', 'swipe', 'at', 'the', 'State', 'Welfare', "Department's", 'handling', 'of', 'federal', 'funds', 'granted', 'for', 'child', 'welfare', 'services', 'in', 'foster', 'homes', '.']
# ['``', 'This', 'is', 'one', 'of', 'the', 'major', 'items', 'in', 'the', 'Fulton', 'County', 'general', 'assistance', 'program', "''", ',', 'the', 'jury', 'said', ',', 'but', 'the', 'State', 'Welfare', 'Department', '``', 'has', 'seen', 'fit', 'to', 'distribute', 'these', 'funds', 'through', 'the', 'welfare', 'departments', 'of', 'all', 'the', 'counties', 'in', 'the', 'state', 'with', 'the', 'exception', 'of', 'Fulton', 'County', ',', 'which', 'receives', 'none', 'of', 'this', 'money', '.']
# ['The', 'jurors', 'said', 'they', 'realize', '``', 'a', 'proportionate', 'distribution', 'of', 'these', 'funds', 'might', 'disable', 'this', 'program', 'in', 'our', 'less', 'populous', 'counties', "''", '.']
# ['Nevertheless', ',', '``', 'we', 'feel', 'that', 'in', 'the', 'future', 'Fulton', 'County', 'should', 'receive', 'some', 'portion', 'of', 'these', 'available', 'funds', "''", ',', 'the', 'jurors', 'said', '.']
# ['``', 'Failure', 'to', 'do', 'this', 'will', 'continue', 'to', 'place', 'a', 'disproportionate', 'burden', "''", 'on', 'Fulton', 'taxpayers', '.']
# ['The', 'jury', 'also', 'commented', 'on', 'the', 'Fulton', "ordinary's", 'court', 'which', 'has', 'been', 'under', 'fire', 'for', 'its', 'practices', 'in', 'the', 'appointment', 'of', 'appraisers', ',', 'guardians', 'and', 'administrators', 'and', 'the', 'awarding', 'of', 'fees', 'and', 'compensation', '.']
# ['Wards', 'protected']
# ['The', 'jury', 'said', 'it', 'found', 'the', 'court', '``', 'has', 'incorporated', 'into', 'its', 'operating', 'procedures', 'the', 'recommendations', "''", 'of', 'two', 'previous', 'grand', 'juries', ',', 'the', 'Atlanta', 'Bar', 'Association', 'and', 'an', 'interim', 'citizens', 'committee', '.']
# ['``', 'These', 'actions', 'should', 'serve', 'to', 'protect', 'in', 'fact', 'and', 'in', 'effect', 'the', "court's", 'wards', 'from', 'undue', 'costs', 'and', 'its', 'appointed', 'and', 'elected', 'servants', 'from', 'unmeritorious', 'criticisms', "''", ',', 'the', 'jury', 'said', '.']
# ['Regarding', "Atlanta's", 'new', 'multi-million-dollar', 'airport', ',', 'the', 'jury', 'recommended', '``', 'that', 'when', 'the', 'new', 'management', 'takes', 'charge', 'Jan.', '1', 'the', 'airport', 'be', 'operated', 'in', 'a', 'manner', 'that', 'will', 'eliminate', 'political', 'influences', "''", '.']
# ['The', 'jury', 'did', 'not', 'elaborate', ',', 'but', 'it', 'added', 'that', '``', 'there', 'should', 'be', 'periodic', 'surveillance', 'of', 'the', 'pricing', 'practices', 'of', 'the', 'concessionaires', 'for', 'the', 'purpose', 'of', 'keeping', 'the', 'prices', 'reasonable', "''", '.']
# ['Ask', 'jail', 'deputies']
# ['On', 'other', 'matters', ',', 'the', 'jury', 'recommended', 'that', ':', '(', '1', ')']
# ['Four', 'additional', 'deputies', 'be', 'employed', 'at', 'the', 'Fulton', 'County', 'Jail', 'and', '``', 'a', 'doctor', ',', 'medical', 'intern', 'or', 'extern', 'be', 'employed', 'for', 'night', 'and', 'weekend', 'duty', 'at', 'the', 'jail', "''", '.']
# ['(', '2', ')']
# ['Fulton', 'legislators', '``', 'work', 'with', 'city', 'officials', 'to', 'pass', 'enabling', 'legislation', 'that', 'will', 'permit', 'the', 'establishment', 'of', 'a', 'fair', 'and', 'equitable', "''", 'pension', 'plan', 'for', 'city', 'employes', '.']
# ['The', 'jury', 'praised', 'the', 'administration', 'and', 'operation', 'of', 'the', 'Atlanta', 'Police', 'Department', ',', 'the', 'Fulton', 'Tax', "Commissioner's", 'Office', ',', 'the', 'Bellwood', 'and', 'Alpharetta', 'prison', 'farms', ',', 'Grady', 'Hospital', 'and', 'the', 'Fulton', 'Health', 'Department', '.']
# ['Mayor', 'William', 'B.', 'Hartsfield', 'filed', 'suit', 'for', 'divorce', 'from', 'his', 'wife', ',', 'Pearl', 'Williams', 'Hartsfield', ',', 'in', 'Fulton', 'Superior', 'Court', 'Friday', '.']
# ['His', 'petition', 'charged', 'mental', 'cruelty', '.']
# ['The', 'couple', 'was', 'married', 'Aug.', '2', ',', '1913', '.']
# ['They', 'have', 'a', 'son', ',', 'William', 'Berry', 'Jr.', ',', 'and', 'a', 'daughter', ',', 'Mrs.', 'J.', 'M.', 'Cheshire', 'of', 'Griffin', '.']
# ['Attorneys', 'for', 'the', 'mayor', 'said', 'that', 'an', 'amicable', 'property', 'settlement', 'has', 'been', 'agreed', 'upon', '.']
# ['The', 'petition', 'listed', 'the', "mayor's", 'occupation', 'as', '``', 'attorney', "''", 'and', 'his', 'age', 'as', '71', '.']
# ['It', 'listed', 'his', "wife's", 'age', 'as', '74', 'and', 'place', 'of', 'birth', 'as', 'Opelika', ',', 'Ala.', '.']
# ['The', 'petition', 'said', 'that', 'the', 'couple', 'has', 'not', 'lived', 'together', 'as', 'man', 'and', 'wife', 'for', 'more', 'than', 'a', 'year', '.']
# ['The', 'Hartsfield', 'home', 'is', 'at', '637', 'E.', 'Pelham', 'Rd.', 'Aj', '.']
# ['Henry', 'L.', 'Bowden', 'was', 'listed', 'on', 'the', 'petition', 'as', 'the', "mayor's", 'attorney', '.']
# ['Hartsfield', 'has', 'been', 'mayor', 'of', 'Atlanta', ',', 'with', 'exception', 'of', 'one', 'brief', 'interlude', ',', 'since', '1937', '.']
# ['His', 'political', 'career', 'goes', 'back', 'to', 'his', 'election', 'to', 'city', 'council', 'in', '1923', '.']
# ['The', "mayor's", 'present', 'term', 'of', 'office', 'expires', 'Jan.', '1', '.']
# ['He', 'will', 'be', 'succeeded', 'by', 'Ivan', 'Allen', 'Jr.', ',', 'who', 'became', 'a', 'candidate', 'in', 'the', 'Sept.', '13', 'primary', 'after', 'Mayor', 'Hartsfield', 'announced', 'that', 'he', 'would', 'not', 'run', 'for', 'reelection', '.']
# ['Georgia', 'Republicans', 'are', 'getting', 'strong', 'encouragement', 'to', 'enter', 'a', 'candidate', 'in', 'the', '1962', "governor's", 'race', ',', 'a', 'top', 'official', 'said', 'Wednesday', '.']
# ['Robert', 'Snodgrass', ',', 'state', 'GOP', 'chairman', ',', 'said', 'a', 'meeting', 'held', 'Tuesday', 'night', 'in', 'Blue', 'Ridge', 'brought', 'enthusiastic', 'responses', 'from', 'the', 'audience', '.']
# ['State', 'Party', 'Chairman', 'James', 'W.', 'Dorsey', 'added', 'that', 'enthusiasm', 'was', 'picking', 'up', 'for', 'a', 'state', 'rally', 'to', 'be', 'held', 'Sept.', '8', 'in', 'Savannah', 'at', 'which', 'newly', 'elected', 'Texas', 'Sen.', 'John', 'Tower', 'will', 'be', 'the', 'featured', 'speaker', '.']
# ['In', 'the', 'Blue', 'Ridge', 'meeting', ',', 'the', 'audience', 'was', 'warned', 'that', 'entering', 'a', 'candidate', 'for', 'governor', 'would', 'force', 'it', 'to', 'take', 'petitions', 'out', 'into', 'voting', 'precincts', 'to', 'obtain', 'the', 'signatures', 'of', 'registered', 'voters', '.']
# ['Despite', 'the', 'warning', ',', 'there', 'was', 'a', 'unanimous', 'vote', 'to', 'enter', 'a', 'candidate', ',', 'according', 'to', 'Republicans', 'who', 'attended', '.']
# ['When', 'the', 'crowd', 'was', 'asked', 'whether', 'it', 'wanted', 'to', 'wait', 'one', 'more', 'term', 'to', 'make', 'the', 'race', ',', 'it', 'voted', 'no', '--', 'and', 'there', 'were', 'no', 'dissents', '.']
# ['The', 'largest', 'hurdle', 'the', 'Republicans', 'would', 'have', 'to', 'face', 'is', 'a', 'state', 'law', 'which', 'says', 'that', 'before', 'making', 'a', 'first', 'race', ',', 'one', 'of', 'two', 'alternative', 'courses', 'must', 'be', 'taken', ':', '1']
# ['Five', 'per', 'cent', 'of', 'the', 'voters', 'in', 'each', 'county', 'must', 'sign', 'petitions', 'requesting', 'that', 'the', 'Republicans', 'be', 'allowed', 'to', 'place', 'names', 'of', 'candidates', 'on', 'the', 'general', 'election', 'ballot', ',', 'or', '2']
# ['The', 'Republicans', 'must', 'hold', 'a', 'primary', 'under', 'the', 'county', 'unit', 'system', '--', 'a', 'system', 'which', 'the', 'party', 'opposes', 'in', 'its', 'platform', '.']
# ['Sam', 'Caldwell', ',', 'State', 'Highway', 'Department', 'public', 'relations', 'director', ',', 'resigned', 'Tuesday', 'to', 'work', 'for', 'Lt.', 'Gov.', 'Garland', "Byrd's", 'campaign', '.']
# ["Caldwell's", 'resignation', 'had', 'been', 'expected', 'for', 'some', 'time', '.']
# ['He', 'will', 'be', 'succeeded', 'by', 'Rob', 'Ledford', 'of', 'Gainesville', ',', 'who', 'has', 'been', 'an', 'assistant', 'more', 'than', 'three', 'years', '.']
# ['When', 'the', 'gubernatorial', 'campaign', 'starts', ',', 'Caldwell', 'is', 'expected', 'to', 'become', 'a', 'campaign', 'coordinator', 'for', 'Byrd', '.']
# ['The', 'Georgia', 'Legislature', 'will', 'wind', 'up', 'its', '1961', 'session', 'Monday', 'and', 'head', 'for', 'home', '--', 'where', 'some', 'of', 'the', 'highway', 'bond', 'money', 'it', 'approved', 'will', 'follow', 'shortly', '.']
# ['Before', 'adjournment', 'Monday', 'afternoon', ',', 'the', 'Senate', 'is', 'expected', 'to', 'approve', 'a', 'study', 'of', 'the', 'number', 'of', 'legislators', 'allotted', 'to', 'rural', 'and', 'urban', 'areas', 'to', 'determine', 'what', 'adjustments', 'should', 'be', 'made', '.']
# ['Gov.', 'Vandiver', 'is', 'expected', 'to', 'make', 'the', 'traditional', 'visit', 'to', 'both', 'chambers', 'as', 'they', 'work', 'toward', 'adjournment', '.']
# ['Vandiver', 'likely', 'will', 'mention', 'the', '$100', 'million', 'highway', 'bond', 'issue', 'approved', 'earlier', 'in', 'the', 'session', 'as', 'his', 'first', 'priority', 'item', '.']
# ['Construction', 'bonds']
# ['Meanwhile', ',', 'it', 'was', 'learned', 'the', 'State', 'Highway', 'Department', 'is', 'very', 'near', 'being', 'ready', 'to', 'issue', 'the', 'first', '$30', 'million', 'worth', 'of', 'highway', 'reconstruction', 'bonds', '.']
# ['The', 'bond', 'issue', 'will', 'go', 'to', 'the', 'state', 'courts', 'for', 'a', 'friendly', 'test', 'suit', 'to', 'test', 'the', 'validity', 'of', 'the', 'act', ',', 'and', 'then', 'the', 'sales', 'will', 'begin', 'and', 'contracts', 'let', 'for', 'repair', 'work', 'on', 'some', 'of', "Georgia's", 'most', 'heavily', 'traveled', 'highways', '.']
# ['A', 'Highway', 'Department', 'source', 'said', 'there', 'also', 'is', 'a', 'plan', 'there', 'to', 'issue', 'some', '$3', 'million', 'to', '$4', 'million', 'worth', 'of', 'Rural', 'Roads', 'Authority', 'bonds', 'for', 'rural', 'road', 'construction', 'work', '.']
# ['A', 'revolving', 'fund']
# ['The', 'department', 'apparently', 'intends', 'to', 'make', 'the', 'Rural', 'Roads', 'Authority', 'a', 'revolving', 'fund', 'under', 'which', 'new', 'bonds', 'would', 'be', 'issued', 'every', 'time', 'a', 'portion', 'of', 'the', 'old', 'ones', 'are', 'paid', 'off', 'by', 'tax', 'authorities', '.']
# ['Vandiver', 'opened', 'his', 'race', 'for', 'governor', 'in', '1958', 'with', 'a', 'battle', 'in', 'the', 'Legislature', 'against', 'the', 'issuance', 'of', '$50', 'million', 'worth', 'of', 'additional', 'rural', 'roads', 'bonds', 'proposed', 'by', 'then', 'Gov.', 'Marvin', 'Griffin', '.']
# ['The', 'Highway', 'Department', 'source', 'told', 'The', 'Constitution', ',', 'however', ',', 'that', 'Vandiver', 'has', 'not', 'been', 'consulted', 'yet', 'about', 'the', 'plans', 'to', 'issue', 'the', 'new', 'rural', 'roads', 'bonds', '.']
# ['Schley', 'County', 'Rep.', 'B.', 'D.', 'Pelham', 'will', 'offer', 'a', 'resolution', 'Monday', 'in', 'the', 'House', 'to', 'rescind', 'the', "body's", 'action', 'of', 'Friday', 'in', 'voting', 'itself', 'a', '$10', 'per', 'day', 'increase', 'in', 'expense', 'allowances', '.']
# ['Pelham', 'said', 'Sunday', 'night', 'there', 'was', 'research', 'being', 'done', 'on', 'whether', 'the', '``', 'quickie', "''", 'vote', 'on', 'the', 'increase', 'can', 'be', 'repealed', 'outright', 'or', 'whether', 'notice', 'would', 'have', 'to', 'first', 'be', 'given', 'that', 'reconsideration', 'of', 'the', 'action', 'would', 'be', 'sought', '.']
# ['While', 'emphasizing', 'that', 'technical', 'details', 'were', 'not', 'fully', 'worked', 'out', ',', 'Pelham', 'said', 'his', 'resolution', 'would', 'seek', 'to', 'set', 'aside', 'the', 'privilege', 'resolution', 'which', 'the', 'House', 'voted', 'through', '87-31', '.']
# ['A', 'similar', 'resolution', 'passed', 'in', 'the', 'Senate', 'by', 'a', 'vote', 'of', '29-5', '.']
# ['As', 'of', 'Sunday', 'night', ',', 'there', 'was', 'no', 'word', 'of', 'a', 'resolution', 'being', 'offered', 'there', 'to', 'rescind', 'the', 'action', '.']
# ['Pelham', 'pointed', 'out', 'that', 'Georgia', 'voters', 'last', 'November', 'rejected', 'a', 'constitutional', 'amendment', 'to', 'allow', 'legislators', 'to', 'vote', 'on', 'pay', 'raises', 'for', 'future', 'Legislature', 'sessions', '.']
# ['A', 'veteran', 'Jackson', 'County', 'legislator', 'will', 'ask', 'the', 'Georgia', 'House', 'Monday', 'to', 'back', 'federal', 'aid', 'to', 'education', ',', 'something', 'it', 'has', 'consistently', 'opposed', 'in', 'the', 'past', '.']
# ['Rep.', 'Mac', 'Barber', 'of', 'Commerce', 'is', 'asking', 'the', 'House', 'in', 'a', 'privilege', 'resolution', 'to', '``', 'endorse', 'increased', 'federal', 'support', 'for', 'public', 'education', ',', 'provided', 'that', 'such', 'funds', 'be', 'received', 'and', 'expended', "''", 'as', 'state', 'funds', '.']
# ['Barber', ',', 'who', 'is', 'in', 'his', '13th', 'year', 'as', 'a', 'legislator', ',', 'said', 'there', '``', 'are', 'some', 'members', 'of', 'our', 'congressional', 'delegation', 'in', 'Washington', 'who', 'would', 'like', 'to', 'see', 'it', '(', 'the', 'resolution', ')', 'passed', "''", '.']
# ['But', 'he', 'added', 'that', 'none', 'of', "Georgia's", 'congressmen', 'specifically', 'asked', 'him', 'to', 'offer', 'the', 'resolution', '.']
# ['The', 'resolution', ',', 'which', 'Barber', 'tossed', 'into', 'the', 'House', 'hopper', 'Friday', ',', 'will', 'be', 'formally', 'read', 'Monday', '.']
# ['It', 'says', 'that', '``', 'in', 'the', 'event', 'Congress', 'does', 'provide', 'this', 'increase', 'in', 'federal', 'funds', "''", ',', 'the', 'State', 'Board', 'of', 'Education', 'should', 'be', 'directed', 'to', '``', 'give', 'priority', "''", 'to', 'teacher', 'pay', 'raises', '.']
# ['Colquitt']
# ['--', 'After', 'a', 'long', ',', 'hot', 'controversy', ',', 'Miller', 'County', 'has', 'a', 'new', 'school', 'superintendent', ',', 'elected', ',', 'as', 'a', 'policeman', 'put', 'it', ',', 'in', 'the', '``', 'coolest', 'election', 'I', 'ever', 'saw', 'in', 'this', 'county', "''", '.']
# ['The', 'new', 'school', 'superintendent', 'is', 'Harry', 'Davis', ',', 'a', 'veteran', 'agriculture', 'teacher', ',', 'who', 'defeated', 'Felix', 'Bush', ',', 'a', 'school', 'principal', 'and', 'chairman', 'of', 'the', 'Miller', 'County', 'Democratic', 'Executive', 'Committee', '.']
# ['Davis', 'received', '1,119', 'votes', 'in', "Saturday's", 'election', ',', 'and', 'Bush', 'got', '402', '.']
# ['Ordinary', 'Carey', 'Williams', ',', 'armed', 'with', 'a', 'pistol', ',', 'stood', 'by', 'at', 'the', 'polls', 'to', 'insure', 'order', '.']
# ['``', 'This', 'was', 'the', 'coolest', ',', 'calmest', 'election', 'I', 'ever', 'saw', "''", ',', 'Colquitt', 'Policeman', 'Tom', 'Williams', 'said', '.']
# ['``', 'Being', 'at', 'the', 'polls', 'was', 'just', 'like', 'being', 'at', 'church', '.']
# ['I', "didn't", 'smell', 'a', 'drop', 'of', 'liquor', ',', 'and', 'we', "didn't", 'have', 'a', 'bit', 'of', 'trouble', "''", '.']
# ['The', 'campaign', 'leading', 'to', 'the', 'election', 'was', 'not', 'so', 'quiet', ',', 'however', '.']
# ['It', 'was', 'marked', 'by', 'controversy', ',', 'anonymous', 'midnight', 'phone', 'calls', 'and', 'veiled', 'threats', 'of', 'violence', '.']
# ['The', 'former', 'county', 'school', 'superintendent', ',', 'George', 'P.', 'Callan', ',', 'shot', 'himself', 'to', 'death', 'March', '18', ',', 'four', 'days', 'after', 'he', 'resigned', 'his', 'post', 'in', 'a', 'dispute', 'with', 'the', 'county', 'school', 'board', '.']
# ['During', 'the', 'election', 'campaign', ',', 'both', 'candidates', ',', 'Davis', 'and', 'Bush', ',', 'reportedly', 'received', 'anonymous', 'telephone', 'calls', '.']
# ['Ordinary', 'Williams', 'said', 'he', ',', 'too', ',', 'was', 'subjected', 'to', 'anonymous', 'calls', 'soon', 'after', 'he', 'scheduled', 'the', 'election', '.']
# ['Many', 'local', 'citizens', 'feared', 'that', 'there', 'would', 'be', 'irregularities', 'at', 'the', 'polls', ',', 'and', 'Williams', 'got', 'himself', 'a', 'permit', 'to', 'carry', 'a', 'gun', 'and', 'promised', 'an', 'orderly', 'election', '.']
# ['Sheriff', 'Felix', 'Tabb', 'said', 'the', 'ordinary', 'apparently', 'made', 'good', 'his', 'promise', '.']
# ['``', 'Everything', 'went', 'real', 'smooth', "''", ',', 'the', 'sheriff', 'said', '.']
# ['``', 'There', "wasn't", 'a', 'bit', 'of', 'trouble', "''", '.']
# ['Austin', ',', 'Texas']
# ['--', 'Committee', 'approval', 'of', 'Gov.', 'Price', "Daniel's", '``', 'abandoned', 'property', "''", 'act', 'seemed', 'certain', 'Thursday', 'despite', 'the', 'adamant', 'protests', 'of', 'Texas', 'bankers', '.']
# ['Daniel', 'personally', 'led', 'the', 'fight', 'for', 'the', 'measure', ',', 'which', 'he', 'had', 'watered', 'down', 'considerably', 'since', 'its', 'rejection', 'by', 'two', 'previous', 'Legislatures', ',', 'in', 'a', 'public', 'hearing', 'before', 'the', 'House', 'Committee', 'on', 'Revenue', 'and', 'Taxation', '.']
# ['Under', 'committee', 'rules', ',', 'it', 'went', 'automatically', 'to', 'a', 'subcommittee', 'for', 'one', 'week', '.']
# ['But', 'questions', 'with', 'which', 'committee', 'members', 'taunted', 'bankers', 'appearing', 'as', 'witnesses', 'left', 'little', 'doubt', 'that', 'they', 'will', 'recommend', 'passage', 'of', 'it', '.']
# ['Daniel', 'termed', '``', 'extremely', 'conservative', "''", 'his', 'estimate', 'that', 'it', 'would', 'produce', '17', 'million', 'dollars', 'to', 'help', 'erase', 'an', 'anticipated', 'deficit', 'of', '63', 'million', 'dollars', 'at', 'the', 'end', 'of', 'the', 'current', 'fiscal', 'year', 'next', 'Aug.', '31', '.']
# ['He', 'told', 'the', 'committee', 'the', 'measure', 'would', 'merely', 'provide', 'means', 'of', 'enforcing', 'the', 'escheat', 'law', 'which', 'has', 'been', 'on', 'the', 'books', '``', 'since', 'Texas', 'was', 'a', 'republic', "''", '.']
# ['It', 'permits', 'the', 'state', 'to', 'take', 'over', 'bank', 'accounts', ',', 'stocks', 'and', 'other', 'personal', 'property', 'of', 'persons', 'missing', 'for', 'seven', 'years', 'or', 'more', '.']
# ['The', 'bill', ',', 'which', 'Daniel', 'said', 'he', 'drafted', 'personally', ',', 'would', 'force', 'banks', ',', 'insurance', 'firms', ',', 'pipeline', 'companies', 'and', 'other', 'corporations', 'to', 'report', 'such', 'property', 'to', 'the', 'state', 'treasurer', '.']
# ['The', 'escheat', 'law', 'cannot', 'be', 'enforced', 'now', 'because', 'it', 'is', 'almost', 'impossible', 'to', 'locate', 'such', 'property', ',', 'Daniel', 'declared', '.']
# ['Dewey', 'Lawrence', ',', 'a', 'Tyler', 'lawyer', 'representing', 'the', 'Texas', 'Bankers', 'Association', ',', 'sounded', 'the', 'opposition', 'keynote', 'when', 'he', 'said', 'it', 'would', 'force', 'banks', 'to', 'violate', 'their', 'contractual', 'obligations', 'with', 'depositors', 'and', 'undermine', 'the', 'confidence', 'of', 'bank', 'customers', '.']
# ['``', 'If', 'you', 'destroy', 'confidence', 'in', 'banks', ',', 'you', 'do', 'something', 'to', 'the', 'economy', "''", ',', 'he', 'said', '.']
# ['``', 'You', 'take', 'out', 'of', 'circulation', 'many', 'millions', 'of', 'dollars', "''", '.']
# ['Rep.', 'Charles', 'E.', 'Hughes', 'of', 'Sherman', ',', 'sponsor', 'of', 'the', 'bill', ',', 'said', 'a', 'failure', 'to', 'enact', 'it', 'would', 'amount', '``', 'to', 'making', 'a', 'gift', 'out', 'of', 'the', "taxpayers'", 'pockets', 'to', 'banks', ',', 'insurance', 'and', 'pipeline', 'companies', "''", '.']
# ['His', 'contention', 'was', 'denied', 'by', 'several', 'bankers', ',', 'including', 'Scott', 'Hudson', 'of', 'Sherman', ',', 'Gaynor', 'B.', 'Jones', 'of', 'Houston', ',', 'J.', 'B.', 'Brady', 'of', 'Harlingen', 'and', 'Howard', 'Cox', 'of', 'Austin', '.']
# ['Cox', 'argued', 'that', 'the', 'bill', 'is', '``', 'probably', 'unconstitutional', "''", 'since', ',', 'he', 'said', ',', 'it', 'would', 'impair', 'contracts', '.']
# ['He', 'also', 'complained', 'that', 'not', 'enough', 'notice', 'was', 'given', 'on', 'the', 'hearing', ',', 'since', 'the', 'bill', 'was', 'introduced', 'only', 'last', 'Monday', '.']
# ['Austin', ',', 'Texas']
# ['--', 'Senators', 'unanimously', 'approved', 'Thursday', 'the', 'bill', 'of', 'Sen.', 'George', 'Parkhouse', 'of', 'Dallas', 'authorizing', 'establishment', 'of', 'day', 'schools', 'for', 'the', 'deaf', 'in', 'Dallas', 'and', 'the', 'four', 'other', 'largest', 'counties', '.']
# ['The', 'bill', 'is', 'designed', 'to', 'provide', 'special', 'schooling', 'for', 'more', 'deaf', 'students', 'in', 'the', 'scholastic', 'age', 'at', 'a', 'reduced', 'cost', 'to', 'the', 'state', '.']
# ['There', 'was', 'no', 'debate', 'as', 'the', 'Senate', 'passed', 'the', 'bill', 'on', 'to', 'the', 'House', '.']
# ['It', 'would', 'authorize', 'the', 'Texas', 'Education', 'Agency', 'to', 'establish', 'county-wide', 'day', 'schools', 'for', 'the', 'deaf', 'in', 'counties', 'of', '300,000', 'or', 'more', 'population', ',', 'require', 'deaf', 'children', 'between', '6', 'and', '13', 'years', 'of', 'age', 'to', 'attend', 'the', 'day', 'schools', ',', 'permitting', 'older', 'ones', 'to', 'attend', 'the', 'residential', 'Texas', 'School', 'for', 'the', 'Deaf', 'here', '.']
# ['Operating', 'budget', 'for', 'the', 'day', 'schools', 'in', 'the', 'five', 'counties', 'of', 'Dallas', ',', 'Harris', ',', 'Bexar', ',', 'Tarrant', 'and', 'El', 'Paso', 'would', 'be', '$451,500', ',', 'which', 'would', 'be', 'a', 'savings', 'of', '$157,460', 'yearly', 'after', 'the', 'first', "year's", 'capital', 'outlay', 'of', '$88,000', 'was', 'absorbed', ',', 'Parkhouse', 'told', 'the', 'Senate', '.']
# ['The', 'TEA', 'estimated', 'there', 'would', 'be', '182', 'scholastics', 'to', 'attend', 'the', 'day', 'school', 'in', 'Dallas', 'County', ',', 'saving', 'them', 'from', 'coming', 'to', 'Austin', 'to', 'live', 'in', 'the', 'state', 'deaf', 'school', '.']
# ['Dallas', 'may', 'get', 'to', 'hear', 'a', 'debate', 'on', 'horse', 'race', 'parimutuels', 'soon', 'between', 'Reps.', 'V.', 'E.', '(', 'Red', ')', 'Berry', 'and', 'Joe', 'Ratcliff', '.']
# ['While', 'details', 'are', 'still', 'to', 'be', 'worked', 'out', ',', 'Ratcliff', 'said', 'he', 'expects', 'to', 'tell', 'home', 'folks', 'in', 'Dallas', 'why', 'he', 'thinks', "Berry's", 'proposed', 'constitutional', 'amendment', 'should', 'be', 'rejected', '.']
# ['``', "We're", 'getting', 'more', "'", 'pro', "'", 'letters', 'than', "'", 'con', "'", 'on', 'horse', 'race', 'betting', "''", ',', 'said', 'Ratcliff', '.']
# ['``', 'But', 'I', 'believe', 'if', 'people', 'were', 'better', 'informed', 'on', 'this', 'question', ',', 'most', 'of', 'them', 'would', 'oppose', 'it', 'also', '.']
# ["I'm", 'willing', 'to', 'stake', 'my', 'political', 'career', 'on', 'it', "''", '.']
# ['Rep.', 'Berry', ',', 'an', 'ex-gambler', 'from', 'San', 'Antonio', ',', 'got', 'elected', 'on', 'his', 'advocacy', 'of', 'betting', 'on', 'the', 'ponies', '.']
# ['A', 'House', 'committee', 'which', 'heard', 'his', 'local', 'option', 'proposal', 'is', 'expected', 'to', 'give', 'it', 'a', 'favorable', 'report', ',', 'although', 'the', 'resolution', 'faces', 'hard', 'sledding', 'later', '.']
# ['The', 'house', 'passed', 'finally', ',', 'and', 'sent', 'to', 'the', 'Senate', ',', 'a', 'bill', 'extending', 'the', 'State', 'Health', "Department's", 'authority', 'to', 'give', 'planning', 'assistance', 'to', 'cities', '.']
# ['The', 'senate', 'quickly', 'whipped', 'through', 'its', 'meager', 'fare', 'of', 'House', 'bills', 'approved', 'by', 'committees', ',', 'passing', 'the', 'three', 'on', 'the', 'calendar', '.']
# ['One', 'validated', 'acts', 'of', 'school', 'districts', '.']
# ['Another', 'enlarged', 'authority', 'of', 'the', 'Beaumont', 'Navigation', 'District', '.']
# ['The', 'third', 'amended', 'the', 'enabling', 'act', 'for', 'creation', 'of', 'the', 'Lamar', 'county', 'Hospital', 'District', ',', 'for', 'which', 'a', 'special', 'constitutional', 'amendment', 'previously', 'was', 'adopted', '.']
# ['Without', 'dissent', ',', 'senators', 'passed', 'a', 'bill', 'by', 'Sen.', 'A.', 'R.', 'Schwartz', 'of', 'Galveston', 'authorizing', 'establishment', 'in', 'the', 'future', 'of', 'a', 'school', 'for', 'the', 'mentally', 'retarded', 'in', 'the', 'Gulf', 'Coast', 'district', '.']
# ['Money', 'for', 'its', 'construction', 'will', 'be', 'sought', 'later', 'on', 'but', 'in', 'the', 'meantime', 'the', 'State', 'Hospital', 'board', 'can', 'accept', 'gifts', 'and', 'donations', 'of', 'a', 'site', '.']
# ['Two', 'tax', 'revision', 'bills', 'were', 'passed', '.']
# ['One', ',', 'by', 'Sen.', 'Louis', 'Crump', 'of', 'San', 'Saba', ',', 'would', 'aid', 'more', 'than', '17,000', 'retailers', 'who', 'pay', 'a', 'group', 'of', 'miscellaneous', 'excise', 'taxes', 'by', 'eliminating', 'the', 'requirement', 'that', 'each', 'return', 'be', 'notarized', '.']
# ['Instead', ',', 'retailers', 'would', 'sign', 'a', 'certificate', 'of', 'correctness', ',', 'violation', 'of', 'which', 'would', 'carry', 'a', 'penalty', 'of', 'one', 'to', 'five', 'years', 'in', 'prison', ',', 'plus', 'a', '$1,000', 'fine', '.']
# ['It', 'was', 'one', 'of', 'a', 'series', 'of', 'recommendations', 'by', 'the', 'Texas', 'Research', 'League', '.']
# ['The', 'other', 'bill', ',', 'by', 'Sen.', 'A.', 'M.', 'Aikin', 'Jr.', 'of', 'Paris', ',', 'would', 'relieve', 'real', 'estate', 'brokers', ',', 'who', 'pay', 'their', 'own', 'annual', 'licensing', 'fee', ',', 'from', 'the', '$12', 'annual', 'occupation', 'license', 'on', 'brokers', 'in', 'such', 'as', 'stocks', 'and', 'bonds', '.']
# ['Natural', 'gas', 'public', 'utility', 'companies', 'would', 'be', 'given', 'the', 'right', 'of', 'eminent', 'domain', ',', 'under', 'a', 'bill', 'by', 'Sen.', 'Frank', 'Owen', '3', ',', 'of', 'El', 'Paso', ',', 'to', 'acquire', 'sites', 'for', 'underground', 'storage', 'reservoirs', 'for', 'gas', '.']
# ['Marshall', 'Formby', 'of', 'Plainview', ',', 'former', 'chairman', 'of', 'the', 'Texas', 'Highway', 'Commission', ',', 'suggested', 'a', 'plan', 'to', 'fill', 'by', 'appointment', 'future', 'vacancies', 'in', 'the', 'Legislature', 'and', 'Congress', ',', 'eliminating', 'the', 'need', 'for', 'costly', 'special', 'elections', '.']
# ['Under', "Formby's", 'plan', ',', 'an', 'appointee', 'would', 'be', 'selected', 'by', 'a', 'board', 'composed', 'of', 'the', 'governor', ',', 'lieutenant', 'governor', ',', 'speaker', 'of', 'the', 'House', ',', 'attorney', 'general', 'and', 'chief', 'justice', 'of', 'the', 'Texas', 'Supreme', 'Court', '.']
# ['Austin', ',', 'Texas']
# ['--', 'State', 'representatives', 'decided', 'Thursday', 'against', 'taking', 'a', 'poll', 'on', 'what', 'kind', 'of', 'taxes', 'Texans', 'would', 'prefer', 'to', 'pay', '.']
# ['An', 'adverse', 'vote', 'of', '81', 'to', '65', 'kept', 'in', 'the', 'State', 'Affairs', 'Committee', 'a', 'bill', 'which', 'would', 'order', 'the', 'referendum', 'on', 'the', 'April', '4', 'ballot', ',', 'when', 'Texas', 'votes', 'on', 'a', 'U.S.', 'senator', '.']
# ['Rep.', 'Wesley', 'Roberts', 'of', 'Seminole', ',', 'sponsor', 'of', 'the', 'poll', 'idea', ',', 'said', 'that', 'further', 'delay', 'in', 'the', 'committee', 'can', 'kill', 'the', 'bill', '.']
# ['The', 'West', 'Texan', 'reported', 'that', 'he', 'had', 'finally', 'gotten', 'Chairman', 'Bill', 'Hollowell', 'of', 'the', 'committee', 'to', 'set', 'it', 'for', 'public', 'hearing', 'on', 'Feb.', '22', '.']
# ['The', 'proposal', 'would', 'have', 'to', 'receive', 'final', 'legislative', 'approval', ',', 'by', 'two-thirds', 'majorities', ',', 'before', 'March', '1', 'to', 'be', 'printed', 'on', 'the', 'April', '4', 'ballot', ',', 'Roberts', 'said', '.']
# ['Opponents', 'generally', 'argued', 'that', 'the', 'ballot', "couldn't", 'give', 'enough', 'information', 'about', 'tax', 'proposals', 'for', 'the', 'voters', 'to', 'make', 'an', 'intelligent', 'choice', '.']
# ['All', 'Dallas', 'members', 'voted', 'with', 'Roberts', ',', 'except', 'Rep.', 'Bill', 'Jones', ',', 'who', 'was', 'absent', '.']
# ['Austin', ',', 'Texas']
# ['--', 'Paradise', 'lost', 'to', 'the', 'alleged', 'water', 'needs', 'of', "Texas'", 'big', 'cities', 'Thursday', '.']
# ['Rep.', 'James', 'Cotten', 'of', 'Weatherford', 'insisted', 'that', 'a', 'water', 'development', 'bill', 'passed', 'by', 'the', 'Texas', 'House', 'of', 'Representatives', 'was', 'an', 'effort', 'by', 'big', 'cities', 'like', 'Dallas', 'and', 'Fort', 'Worth', 'to', 'cover', 'up', 'places', 'like', 'Paradise', ',', 'a', 'Wise', 'County', 'hamlet', 'of', '250', 'people', '.']
# ['When', 'the', 'shouting', 'ended', ',', 'the', 'bill', 'passed', ',', '114', 'to', '4', ',', 'sending', 'it', 'to', 'the', 'Senate', ',', 'where', 'a', 'similar', 'proposal', 'is', 'being', 'sponsored', 'by', 'Sen.', 'George', 'Parkhouse', 'of', 'Dallas', '.']
# ['Most', 'of', 'the', 'fire', 'was', 'directed', 'by', 'Cotten', 'against', 'Dallas', 'and', 'Sen.', 'Parkhouse', '.']
# ['The', 'bill', 'would', 'increase', 'from', '$5,000,000', 'to', '$15,000,000', 'the', 'maximum', 'loan', 'the', 'state', 'could', 'make', 'to', 'a', 'local', 'water', 'project', '.']
# ['Cotten', 'construed', 'this', 'as', 'a', 'veiled', 'effort', 'by', 'Parkhouse', 'to', 'help', 'Dallas', 'and', 'other', 'large', 'cities', 'get', 'money', 'which', 'Cotten', 'felt', 'could', 'better', 'be', 'spent', 'providing', 'water', 'for', 'rural', 'Texas', '.']
# ['Statements', 'by', 'other', 'legislators', 'that', 'Dallas', 'is', 'paying', 'for', 'all', 'its', 'water', 'program', 'by', 'local', 'bonds', ',', 'and', 'that', 'less', 'populous', 'places', 'would', 'benefit', 'most', 'by', 'the', 'pending', 'bill', ',', 'did', 'not', 'sway', "Cotten's", 'attack', '.']
# ['The', "bill's", 'defenders', 'were', 'mostly', 'small-town', 'legislators', 'like', 'J.', 'W.', 'Buchanan', 'of', 'Dumas', ',', 'Eligio', '(', 'Kika', ')', 'De', 'La', 'Garza', 'of', 'Mission', ',', 'Sam', 'F.', 'Collins', 'of', 'Newton', 'and', 'Joe', 'Chapman', 'of', 'Sulphur', 'Springs', '.']
# ['``', 'This', 'is', 'a', 'poor', "boy's", 'bill', "''", ',', 'said', 'Chapman', '.']
# ['``', 'Dallas', 'and', 'Fort', 'Worth', 'can', 'vote', 'bonds', '.']
# ['This', 'would', 'help', 'the', 'little', 'peanut', 'districts', "''", '.']
# ['Austin', ',', 'Texas']
# ['--', 'A', 'Houston', 'teacher', ',', 'now', 'serving', 'in', 'the', 'Legislature', ',', 'proposed', 'Thursday', 'a', 'law', 'reducing', 'the', 'time', 'spent', 'learning', '``', 'educational', 'methods', "''", '.']
# ['Rep.', 'Henry', 'C.', 'Grover', ',', 'who', 'teaches', 'history', 'in', 'the', 'Houston', 'public', 'schools', ',', 'would', 'reduce', 'from', '24', 'to', '12', 'semester', 'hours', 'the', 'so-called', '``', 'teaching', 'methods', "''", 'courses', 'required', 'to', 'obtain', 'a', 'junior', 'or', 'senior', 'high', 'school', 'teaching', 'certificate', '.']
# ['A', 'normal', "year's", 'work', 'in', 'college', 'is', '30', 'semester', 'hours', '.']
# ['Grover', 'also', 'would', 'require', 'junior-senior', 'high', 'teachers', 'to', 'have', 'at', 'least', '24', 'semester', 'hours', 'credit', 'in', 'the', 'subject', 'they', 'are', 'teaching', '.']
# ['The', 'remainder', 'of', 'the', '4-year', 'college', 'requirement', 'would', 'be', 'in', 'general', 'subjects', '.']
# ['``', 'A', 'person', 'with', 'a', "master's", 'degree', 'in', 'physics', ',', 'chemistry', ',', 'math', 'or', 'English', ',', 'yet', 'who', 'has', 'not', 'taken', 'Education', 'courses', ',', 'is', 'not', 'permitted', 'to', 'teach', 'in', 'the', 'public', 'schools', "''", ',', 'said', 'Grover', '.']
# ['College', 'teachers', 'in', 'Texas', 'are', 'not', 'required', 'to', 'have', 'the', 'Education', 'courses', '.']
# ['Fifty-three', 'of', 'the', '150', 'representatives', 'immediately', 'joined', 'Grover', 'as', 'co-signers', 'of', 'the', 'proposal', '.']
# ['Paris', ',', 'Texas', '(', 'sp.', ')']
# ['--', 'The', 'board', 'of', 'regents', 'of', 'Paris', 'Junior', 'College', 'has', 'named', 'Dr.', 'Clarence', 'Charles', 'Clark', 'of', 'Hays', ',', 'Kan.', 'as', 'the', "school's", 'new', 'president', '.']
# ['Dr.', 'Clark', 'will', 'succeed', 'Dr.', 'J.', 'R.', 'McLemore', ',', 'who', 'will', 'retire', 'at', 'the', 'close', 'of', 'the', 'present', 'school', 'term', '.']
# ['Dr.', 'Clark', 'holds', 'an', 'earned', 'Doctor', 'of', 'Education', 'degree', 'from', 'the', 'University', 'of', 'Oklahoma', '.']
# ['He', 'also', 'received', 'a', 'Master', 'of', 'Science', 'degree', 'from', 'Texas', 'A', '&', 'I', 'College', 'and', 'a', 'Bachelor', 'of', 'Science', 'degree', 'from', 'Southwestern', 'State', 'College', ',', 'Weatherford', ',', 'Okla.', '.']
# ['In', 'addition', ',', 'Dr.', 'Clark', 'has', 'studied', 'at', 'Rhode', 'Island', 'State', 'College', 'and', 'Massachusetts', 'Institute', 'of', 'Technology', '.']
# ['During', 'his', 'college', 'career', ',', 'Dr.', 'Clark', 'was', 'captain', 'of', 'his', 'basketball', 'team', 'and', 'was', 'a', 'football', 'letterman', '.']
# ['Dr.', 'Clark', 'has', 'served', 'as', 'teacher', 'and', 'principal', 'in', 'Oklahoma', 'high', 'schools', ',', 'as', 'teacher', 'and', 'athletic', 'director', 'at', 'Raymondville', ',', 'Texas', ',', 'High', 'School', ',', 'as', 'an', 'instructor', 'at', 'the', 'University', 'of', 'Oklahoma', ',', 'and', 'as', 'an', 'associate', 'professor', 'of', 'education', 'at', 'Fort', 'Hays', ',', 'Kan.', ',', 'State', 'College', '.']
# ['He', 'has', 'served', 'as', 'a', 'border', 'patrolman', 'and', 'was', 'in', 'the', 'Signal', 'Corps', 'of', 'the', 'U.S.', 'Army', '.']
# ['Denton', ',', 'Texas', '(', 'sp.', ')']
# ['--', 'Principals', 'of', 'the', '13', 'schools', 'in', 'the', 'Denton', 'Independent', 'School', 'District', 'have', 'been', 're-elected', 'for', 'the', '1961-62', 'session', 'upon', 'the', 'recommendation', 'of', 'Supt.', 'Chester', 'O.', 'Strickland', '.']
# ['State', 'and', 'federal', 'legislation', 'against', 'racial', 'discrimination', 'in', 'employment', 'was', 'called', 'for', 'yesterday', 'in', 'a', 'report', 'of', 'a', '``', 'blue', 'ribbon', "''", 'citizens', 'committee', 'on', 'the', 'aid', 'to', 'dependent', 'children', 'program', '.']
# ['The', 'report', ',', 'culminating', 'a', 'year', 'long', 'study', 'of', 'the', 'ADC', 'program', 'in', 'Cook', 'county', 'by', 'a', 'New', 'York', 'City', 'welfare', 'consulting', 'firm', ',', 'listed', '10', 'long', 'range', 'recommendations', 'designed', 'to', 'reduce', 'the', 'soaring', 'ADC', 'case', 'load', '.']
# ['The', 'report', 'called', 'racial', 'discrimination', 'in', 'employment', '``', 'one', 'of', 'the', 'most', 'serious', 'causes', 'of', 'family', 'breakdown', ',', 'desertion', ',', 'and', 'ADC', 'dependency', "''", '.']
# ['``', 'Must', 'solve', 'problem', "''"]
# ['The', 'monthly', 'cost', 'of', 'ADC', 'to', 'more', 'than', '100,000', 'recipients', 'in', 'the', 'county', 'is', '4.4', 'million', 'dollars', ',', 'said', 'C.', 'Virgil', 'Martin', ',', 'president', 'of', 'Carson', 'Pirie', 'Scott', '&', 'Co.', ',', 'committee', 'chairman', '.']
# ['``', 'We', 'must', 'solve', 'the', 'problems', 'which', 'have', 'forced', 'these', 'people', 'to', 'depend', 'upon', 'ADC', 'for', 'subsistence', "''", ',', 'Martin', 'said', '.']
# ['The', 'volume', 'of', 'ADC', 'cases', 'will', 'decrease', ',', 'Martin', 'reported', ',', 'when', 'the', 'community', 'is', 'able', 'to', 'deal', 'effectively', 'with', 'two', 'problems', ':', 'Relatively', 'limited', 'skills', 'and', 'discrimination', 'in', 'employment', 'because', 'of', 'color', '.']
# ['These', ',', 'he', 'said', ',', 'are', '``', 'two', 'of', 'the', 'principal', 'underlying', 'causes', 'for', 'family', 'breakups', 'leading', 'to', 'ADC', "''", '.']
# ['Calls', 'for', 'extension']
# ['Other', 'recommendations', 'made', 'by', 'the', 'committee', 'are', ':']
# ['Extension', 'of', 'the', 'ADC', 'program', 'to', 'all', 'children', 'in', 'need', 'living', 'with', 'any', 'relatives', ',', 'including', 'both', 'parents', ',', 'as', 'a', 'means', 'of', 'preserving', 'family', 'unity', '.']
# ['Research', 'projects', 'as', 'soon', 'as', 'possible', 'on', 'the', 'causes', 'and', 'prevention', 'of', 'dependency', 'and', 'illegitimacy', '.']
# ['Several', 'defendants', 'in', 'the', 'Summerdale', 'police', 'burglary', 'trial', 'made', 'statements', 'indicating', 'their', 'guilt', 'at', 'the', 'time', 'of', 'their', 'arrest', ',', 'Judge', 'James', 'B.', 'Parsons', 'was', 'told', 'in', 'Criminal', 'court', 'yesterday', '.']
# ['The', 'disclosure', 'by', 'Charles', 'Bellows', ',', 'chief', 'defense', 'counsel', ',', 'startled', 'observers', 'and', 'was', 'viewed', 'as', 'the', 'prelude', 'to', 'a', 'quarrel', 'between', 'the', 'six', 'attorneys', 'representing', 'the', 'eight', 'former', 'policemen', 'now', 'on', 'trial', '.']
# ['Bellows', 'made', 'the', 'disclosure', 'when', 'he', 'asked', 'Judge', 'Parsons', 'to', 'grant', 'his', 'client', ',', 'Alan', 'Clements', ',', '30', ',', 'a', 'separate', 'trial', '.']
# ['Bellows', 'made', 'the', 'request', 'while', 'the', 'all-woman', 'jury', 'was', 'out', 'of', 'the', 'courtroom', '.']
# ['Fears', 'prejudicial', 'aspects']
# ['``', 'The', 'statements', 'may', 'be', 'highly', 'prejudicial', 'to', 'my', 'client', "''", ',', 'Bellows', 'told', 'the', 'court', '.']
# ['``', 'Some', 'of', 'the', 'defendants', 'strongly', 'indicated', 'they', 'knew', 'they', 'were', 'receiving', 'stolen', 'property', '.']
# ['It', 'is', 'impossible', 'to', 'get', 'a', 'fair', 'trial', 'when', 'some', 'of', 'the', 'defendants', 'made', 'statements', 'involving', 'themselves', 'and', 'others', "''", '.']
# ['Judge', 'Parsons', 'leaned', 'over', 'the', 'bench', 'and', 'inquired', ',', '``', 'You', 'mean', 'some', 'of', 'the', 'defendants', 'made', 'statements', 'admitting', 'this', "''", '?', '?']
# ['``', 'Yes', ',', 'your', 'honor', "''", ',', 'replied', 'Bellows', '.']
# ['``', 'What', 'this', 'amounts', 'to', ',', 'if', 'true', ',', 'is', 'that', 'there', 'will', 'be', 'a', 'free-for-all', 'fight', 'in', 'this', 'case', '.']
# ['There', 'is', 'a', 'conflict', 'among', 'the', 'defendants', "''", '.']
# ['Washington', ',', 'July', '24']
# ['--', 'President', 'Kennedy', 'today', 'pushed', 'aside', 'other', 'White', 'House', 'business', 'to', 'devote', 'all', 'his', 'time', 'and', 'attention', 'to', 'working', 'on', 'the', 'Berlin', 'crisis', 'address', 'he', 'will', 'deliver', 'tomorrow', 'night', 'to', 'the', 'American', 'people', 'over', 'nationwide', 'television', 'and', 'radio', '.']
# ['The', 'President', 'spent', 'much', 'of', 'the', 'week-end', 'at', 'his', 'summer', 'home', 'on', 'Cape', 'Cod', 'writing', 'the', 'first', 'drafts', 'of', 'portions', 'of', 'the', 'address', 'with', 'the', 'help', 'of', 'White', 'House', 'aids', 'in', 'Washington', 'with', 'whom', 'he', 'talked', 'by', 'telephone', '.']
# ['Shortly', 'after', 'the', 'Chief', 'Executive', 'returned', 'to', 'Washington', 'in', 'midmorning', 'from', 'Hyannis', 'Port', ',', 'Mass.', ',', 'a', 'White', 'House', 'spokesman', 'said', 'the', 'address', 'text', 'still', 'had', '``', 'quite', 'a', 'way', 'to', 'go', "''", 'toward', 'completion', '.']
# ['Decisions', 'are', 'made']
# ['Asked', 'to', 'elaborate', ',', 'Pierre', 'Salinger', ',', 'White', 'House', 'press', 'secretary', ',', 'replied', ',', '``', 'I', 'would', 'say', "it's", 'got', 'to', 'go', 'thru', 'several', 'more', 'drafts', "''", '.']
# ['Salinger', 'said', 'the', 'work', 'President', 'Kennedy', ',', 'advisers', ',', 'and', 'members', 'of', 'his', 'staff', 'were', 'doing', 'on', 'the', 'address', 'involved', 'composition', 'and', 'wording', ',', 'rather', 'than', 'last', 'minute', 'decisions', 'on', 'administration', 'plans', 'to', 'meet', 'the', 'latest', 'Berlin', 'crisis', 'precipitated', 'by', "Russia's", 'demands', 'and', 'proposals', 'for', 'the', 'city', '.']
# ['The', 'last', '10', 'cases', 'in', 'the', 'investigation', 'of', 'the', 'Nov.', '8', 'election', 'were', 'dismissed', 'yesterday', 'by', 'Acting', 'Judge', 'John', 'M.', 'Karns', ',', 'who', 'charged', 'that', 'the', 'prosecution', 'obtained', 'evidence', '``', 'by', 'unfair', 'and', 'fundamentally', 'illegal', 'means', "''", '.']
# ['Karns', 'said', 'that', 'the', 'cases', 'involved', 'a', 'matter', '``', 'of', 'even', 'greater', 'significance', 'than', 'the', 'guilt', 'or', 'innocence', "''", 'of', 'the', '50', 'persons', '.']
# ['He', 'said', 'evidence', 'was', 'obtained', '``', 'in', 'violation', 'of', 'the', 'legal', 'rights', 'of', 'citizens', "''", '.']
# ["Karns'", 'ruling', 'pertained', 'to', 'eight', 'of', 'the', '10', 'cases', '.']
# ['In', 'the', 'two', 'other', 'cases', 'he', 'ruled', 'that', 'the', 'state', 'had', 'been', '``', 'unable', 'to', 'make', 'a', 'case', "''", '.']
# ['Contempt', 'proceedings', 'originally', 'had', 'been', 'brought', 'against', '677', 'persons', 'in', '133', 'precincts', 'by', 'Morris', 'J.', 'Wexler', ',', 'special', 'prosecutor', '.']
# ['Issue', 'jury', 'subpoenas']
# ['Wexler', 'admitted', 'in', 'earlier', 'court', 'hearings', 'that', 'he', 'issued', 'grand', 'jury', 'subpenas', 'to', 'about', '200', 'persons', 'involved', 'in', 'the', 'election', 'investigation', ',', 'questioned', 'the', 'individuals', 'in', 'the', 'Criminal', 'courts', 'building', ',', 'but', 'did', 'not', 'take', 'them', 'before', 'the', 'grand', 'jury', '.']
# ['Mayer', 'Goldberg', ',', 'attorney', 'for', 'election', 'judges', 'in', 'the', '58th', 'precinct', 'of', 'the', '23d', 'ward', ',', 'argued', 'this', 'procedure', 'constituted', 'intimidation', '.']
# ['Wexler', 'has', 'denied', 'repeatedly', 'that', 'coercion', 'was', 'used', 'in', 'questioning', '.']
# ['Karns', 'said', 'it', 'was', 'a', '``', 'wrongful', 'act', "''", 'for', 'Wexler', 'to', 'take', 'statements', '``', 'privately', 'and', 'outside', 'of', 'the', 'grand', 'jury', 'room', "''", '.']
# ['He', 'said', 'this', 'constituted', 'a', '``', 'very', 'serious', 'misuse', "''", 'of', 'the', 'Criminal', 'court', 'processes', '.']
# ['``', 'Actually', ',', 'the', 'abuse', 'of', 'the', 'process', 'may', 'have', 'constituted', 'a', 'contempt', 'of', 'the', 'Criminal', 'court', 'of', 'Cook', 'county', ',', 'altho', 'vindication', 'of', 'the', 'authority', 'of', 'that', 'court', 'is', 'not', 'the', 'function', 'of', 'this', 'court', "''", ',', 'said', 'Karns', ',', 'who', 'is', 'a', 'City', 'judge', 'in', 'East', 'St.', 'Louis', 'sitting', 'in', 'Cook', 'County', 'court', '.']
# ['Faced', 'seven', 'cases']
# ['Karns', 'had', 'been', 'scheduled', 'this', 'week', 'to', 'hear', 'seven', 'cases', 'involving', '35', 'persons', '.']
# ['Wexler', 'had', 'charged', 'the', 'precinct', 'judges', 'in', 'these', 'cases', 'with', '``', 'complementary', "''", 'miscount', 'of', 'the', 'vote', ',', 'in', 'which', 'votes', 'would', 'be', 'taken', 'from', 'one', 'candidate', 'and', 'given', 'to', 'another', '.']
# ['The', 'cases', 'involved', 'judges', 'in', 'the', '33d', ',', '24th', ',', 'and', '42d', 'precincts', 'of', 'the', '31st', 'ward', ',', 'the', '21st', 'and', '28th', 'precincts', 'of', 'the', '29th', 'ward', ',', 'the', '18th', 'precinct', 'of', 'the', '4th', 'ward', ',', 'and', 'the', '9th', 'precinct', 'of', 'the', '23d', 'ward', '.']
# ['The', 'case', 'of', 'the', 'judges', 'in', 'the', '58th', 'precinct', 'of', 'the', '23d', 'ward', 'had', 'been', 'heard', 'previously', 'and', 'taken', 'under', 'advisement', 'by', 'Karns', '.']
# ['Two', 'other', 'cases', 'also', 'were', 'under', 'advisement', '.']
# ['Claims', 'precedent', 'lacking']
# ['After', 'reading', 'his', 'statement', 'discharging', 'the', '23d', 'ward', 'case', ',', 'Karns', 'told', 'Wexler', 'that', 'if', 'the', 'seven', 'cases', 'scheduled', 'for', 'trial', 'also', 'involved', 'persons', 'who', 'had', 'been', 'subpenaed', ',', 'he', 'would', 'dismiss', 'them', '.']
# ['Washington', ',', 'Feb.', '9']
# ['--', 'President', 'Kennedy', 'today', 'proposed', 'a', 'mammoth', 'new', 'medical', 'care', 'program', 'whereby', 'social', 'security', 'taxes', 'on', '70', 'million', 'American', 'workers', 'would', 'be', 'raised', 'to', 'pay', 'the', 'hospital', 'and', 'some', 'other', 'medical', 'bills', 'of', '14.2', 'million', 'Americans', 'over', '65', 'who', 'are', 'covered', 'by', 'social', 'security', 'or', 'railroad', 'retirement', 'programs', '.']
# ['The', 'President', ',', 'in', 'a', 'special', 'message', 'to', 'Congress', ',', 'tied', 'in', 'with', 'his', 'aged', 'care', 'plan', 'requests', 'for', 'large', 'federal', 'grants', 'to', 'finance', 'medical', 'and', 'dental', 'scholarships', ',', 'build', '20', 'new', 'medical', 'and', '20', 'new', 'dental', 'schools', ',', 'and', 'expand', 'child', 'health', 'care', 'and', 'general', 'medical', 'research', '.']
# ['The', 'aged', 'care', 'plan', ',', 'similar', 'to', 'one', 'the', 'President', 'sponsored', 'last', 'year', 'as', 'a', 'senator', ',', 'a', 'fight', 'on', 'Capitol', 'hill', '.']
# ['It', 'was', 'defeated', 'in', 'Congress', 'last', 'year', '.']
# ['Cost', 'up', 'to', '$37', 'a', 'year']
# ['It', 'would', 'be', 'financed', 'by', 'boosting', 'the', 'social', 'security', 'payroll', 'tax', 'by', 'as', 'much', 'as', '$37', 'a', 'year', 'for', 'each', 'of', 'the', 'workers', 'now', 'paying', 'such', 'taxes', '.']
# ['The', 'social', 'security', 'payroll', 'tax', 'is', 'now', '6', 'per', 'cent', '--', '3', 'per', 'cent', 'on', 'each', 'worker', 'and', 'employer', '--', 'on', 'the', 'first', '$4,800', 'of', 'pay', 'per', 'year', '.']
# ...
# ['It', 'was', 'a', 'step', 'in', 'the', 'right', 'direction', ',', 'but', 'it', 'took', 'an', 'additional', 'act', 'passed', 'in', '1958', 'to', 'establish', 'fully', 'the', 'thriving', 'systems', 'of', 'today', '.']
# ['Under', 'this', 'law', 'annual', 'grants', 'are', 'given', 'to', 'systems', 'in', 'substantial', 'amounts', '.']
# ['An', 'earlier', 'difficulty', 'was', 'overcome', 'by', 'making', 'it', 'clear', 'that', 'individual', 'libraries', 'in', 'any', 'area', 'might', 'join', 'or', 'not', ',', 'as', 'they', 'saw', 'fit', '.']
# ['Some', 'library', 'boards', 'are', 'wary', 'of', 'the', 'plan', '.']
# ['A', 'large', ',', 'well-stocked', 'library', ',', 'surrounded', 'in', 'a', 'county', 'by', 'smaller', 'ones', ',', 'may', 'feel', 'that', 'the', 'demands', 'on', 'its', 'resources', 'are', 'likely', 'to', 'be', 'too', 'great', '.']
# ['A', 'small', 'library', 'may', 'cherish', 'its', 'independence', 'and', 'established', 'ways', ',', 'and', 'resist', 'joining', 'in', 'a', 'cooperative', 'movement', 'that', 'sometimes', 'seems', 'radical', 'to', 'older', 'members', 'of', 'the', 'board', '.']
# ['Within', 'a', 'system', ',', 'however', ',', 'the', 'autonomy', 'of', 'each', 'member', 'library', 'is', 'preserved', '.']
# ['The', 'local', 'community', 'maintains', 'responsibility', 'for', 'the', 'financial', 'support', 'of', 'its', 'own', 'library', 'program', ',', 'facilities', ',', 'and', 'services', ',', 'but', 'wider', 'resources', 'and', 'additional', 'services', 'become', 'available', 'through', 'membership', 'in', 'a', 'system', '.']
# ['All', 'services', 'are', 'given', 'without', 'cost', 'to', 'members', '.']
# ['So', 'obvious', 'are', 'these', 'advantages', 'that', 'nearly', '95', 'per', 'cent', 'of', 'the', 'population', 'of', 'New', 'York', 'State', 'now', 'has', 'access', 'to', 'a', 'system', ',', 'and', 'enthusiastic', 'librarians', 'foresee', 'the', 'day', ',', 'not', 'too', 'distant', ',', 'when', 'all', 'the', 'libraries', 'in', 'the', 'state', 'will', 'belong', 'to', 'a', 'co-op', '.']
# ['To', 'set', 'up', 'a', 'co-operative', 'library', 'system', ',', 'the', 'law', 'requires', 'a', 'central', 'book', 'collection', 'of', '100,000', 'nonfiction', 'volumes', 'as', 'the', 'nucleus', ',', 'and', 'the', 'system', 'is', 'organized', 'around', 'it', '.']
# ['The', 'collection', 'may', 'be', 'in', 'an', 'existing', 'library', ',', 'or', 'it', 'may', 'be', 'built', 'up', 'in', 'a', 'central', 'collection', '.']
# ['Each', 'system', 'develops', 'differently', ',', 'according', 'to', 'the', 'area', 'it', 'serves', ',', 'but', 'the', 'universal', 'goal', 'is', 'to', 'pool', 'the', 'resources', 'of', 'a', 'given', 'area', 'for', 'maximum', 'efficiency', '.']
# ['The', 'basic', 'state', 'grant', 'is', 'thirty', 'cents', 'for', 'each', 'person', 'served', ',', 'and', 'there', 'is', 'a', 'further', 'book', 'incentive', 'grant', 'that', 'provides', 'an', 'extra', 'twenty', 'cents', 'up', 'to', 'fifty', 'cents', 'per', 'capita', ',', 'if', 'a', 'library', 'spends', 'a', 'certain', 'number', 'of', 'dollars', '.']
# ['In', 'Nassau', 'County', ',', 'for', 'example', ',', 'the', 'heavily', 'settled', 'Long', 'Island', 'suburb', 'of', 'New', 'York', 'City', ',', 'the', 'system', 'is', 'credited', 'by', 'the', 'state', 'with', 'serving', 'one', 'million', 'persons', ',', 'a', 'figure', 'that', 'has', 'doubled', 'since', '1950', '.']
# ['This', 'system', ',', 'by', 'virtue', 'of', 'its', 'variety', 'and', 'size', ',', 'offers', 'an', 'inclusive', 'view', 'of', 'the', 'plan', 'in', 'operation', '.']
# ['The', 'Nassau', 'system', 'recognizes', 'that', 'its', 'major', 'task', 'it', 'to', 'broaden', 'reference', 'service', ',', 'what', 'with', 'the', 'constant', 'expansion', 'of', 'education', 'and', 'knowledge', ',', 'and', 'the', 'pressure', 'of', 'population', 'growth', 'in', 'a', 'metropolitan', 'area', '.']
# ['The', 'need', 'is', 'for', 'reference', 'works', 'of', 'a', 'more', 'specialized', 'nature', 'than', 'individual', 'libraries', ',', 'adequate', 'to', 'satisfy', 'everyday', 'needs', ',', 'could', 'afford', '.']
# ['Nassau', 'is', 'currently', 'building', 'a', 'central', 'collection', 'of', 'reference', 'materials', 'in', 'its', 'Hempstead', 'headquarters', ',', 'which', 'will', 'reach', 'its', 'goal', 'of', '100,000', 'volumes', 'by', '1965', '.']
# ['The', 'major', 'part', 'of', 'this', 'collection', 'is', 'in', 'the', 'central', 'headquarters', 'building', ',', 'and', 'the', 'remainder', 'is', 'divided', 'among', 'five', 'libraries', 'in', 'the', 'system', 'designated', 'as', 'subject', 'centers', '.']
# ['Basic', 'reference', 'tools', 'are', 'the', 'backbone', 'of', 'the', 'collection', ',', 'but', 'there', 'is', 'also', 'specialization', 'in', 'science', 'and', 'technology', ',', 'an', 'indicated', 'weakness', 'in', 'local', 'libraries', '.']
# ['On', 'microfilm', ',', 'headquarters', 'also', 'has', 'a', 'file', 'of', 'the', 'New', 'York', 'Times', 'from', 'its', 'founding', 'in', '1851', 'to', 'the', 'present', 'day', ',', 'as', 'well', 'as', 'bound', 'volumes', 'of', 'important', 'periodicals', '.']
# ['The', 'entire', 'headquarters', 'collection', 'is', 'available', 'to', 'the', 'patrons', 'of', 'all', 'members', 'on', 'interlibrary', 'loans', '.']
# ['Headquarters', 'gets', 'about', '100', 'requests', 'every', 'day', '.']
# ['It', 'is', 'connected', 'by', 'teletype', 'with', 'the', 'State', 'Library', 'in', 'Albany', ',', 'which', 'will', 'supply', 'any', 'book', 'to', 'a', 'system', 'that', 'the', 'system', 'itself', 'cannot', 'provide', '.']
# ['The', 'books', 'are', 'carried', 'around', 'by', 'truck', 'in', 'canvas', 'bags', 'from', 'headquarters', 'to', 'the', 'other', 'libraries', '.']
# ['Each', 'subject', 'center', 'library', 'was', 'chosen', 'because', 'of', 'its', 'demonstrated', 'strength', 'in', 'a', 'particular', 'area', ',', 'which', 'headquarters', 'could', 'then', 'build', 'upon', '.']
# ['East', 'Meadow', 'has', 'philosophy', ',', 'psychology', ',', 'and', 'religion', ';', ';']
# ['Freeport', 'houses', 'social', 'science', ',', 'pure', 'science', ',', 'and', 'language', ';', ';']
# ['history', ',', 'biography', ',', 'and', 'education', 'are', 'centered', 'in', 'Hempstead', ';', ';']
# ['Levittown', 'has', 'applied', 'science', ',', 'business', ',', 'and', 'literature', ';', ';']
# ['while', 'Hewlett-Woodmere', 'is', 'the', 'repository', 'of', 'art', ',', 'music', ',', 'and', 'foreign', 'languages', '.']
# ['The', 'reference', 'coordinator', 'at', 'headquarters', 'also', 'serves', 'as', 'a', 'consultant', ',', 'and', 'is', 'available', 'to', 'work', 'with', 'the', 'local', 'librarian', 'in', 'helping', 'to', 'strengthen', 'local', 'reference', 'service', '.']
# ['This', 'kind', 'of', 'cooperation', 'is', 'not', 'wholly', 'new', ',', 'of', 'course', '.']
# ['Public', 'libraries', 'in', 'Nassau', 'County', 'have', 'been', 'lending', 'books', 'to', 'each', 'other', 'by', 'mail', 'for', 'a', 'quarter-century', ',', 'but', 'the', 'system', 'enables', 'this', 'process', 'to', 'operate', 'on', 'an', 'organized', 'and', 'far', 'more', 'comprehensive', 'basis', '.']
# ['Local', 'libraries', 'find', ',', 'too', ',', 'that', 'the', 'new', 'plan', 'saves', 'tax', 'dollars', 'because', 'books', 'can', 'be', 'bought', 'through', 'the', 'system', ',', 'and', 'since', 'the', 'system', 'buys', 'in', 'bulk', 'it', 'is', 'able', 'to', 'obtain', 'larger', 'discounts', 'than', 'would', 'be', 'available', 'to', 'an', 'individual', 'library', '.']
# ['The', 'system', 'passes', 'on', 'these', 'savings', 'to', 'its', 'members', '.']
# ['Further', 'money', 'is', 'saved', 'through', 'economy', 'in', 'bookkeeping', 'and', 'clerical', 'detail', 'as', 'the', 'result', 'of', 'central', 'billing', '.']
# ['Books', 'are', 'not', 'the', 'only', 'resource', 'of', 'the', 'system', '.']
# ['Schools', 'and', 'community', 'groups', 'turn', 'to', 'the', 'headquarters', 'film', 'library', 'for', 'documentary', ',', 'art', ',', 'and', 'experimental', 'films', 'to', 'show', 'at', 'libraries', 'that', 'sponsor', 'local', 'programs', ',', 'and', 'to', 'organizations', 'in', 'member', 'communities', '.']
# ['The', 'most', 'recent', 'film', 'catalogue', ',', 'available', 'at', 'each', 'library', ',', 'lists', '110', 'titles', 'presently', 'in', 'the', 'collection', ',', 'any', 'of', 'which', 'may', 'be', 'borrowed', 'without', 'charge', '.']
# ['This', 'catalogue', 'lists', 'separately', 'films', 'suitable', 'for', 'children', ',', 'young', 'adults', ',', 'or', 'adults', ',', 'although', 'some', 'classics', 'cut', 'across', 'age', 'groups', ',', 'such', 'as', '``', 'Nanook', 'Of', 'The', 'North', "''", ',', '``', 'The', "Emperor's", 'Nightingale', "''", ',', 'and', '``', 'The', 'Red', 'Balloon', "''", '.']
# ['Workshops', 'are', 'conducted', 'by', 'the', "system's", 'audio-visual', 'consultant', 'for', 'the', 'staffs', 'of', 'member', 'libraries', ',', 'teaching', 'them', 'the', 'effective', 'use', 'of', 'film', 'as', 'a', 'library', 'service', '.']
# ['The', 'system', 'well', 'understands', 'that', 'one', 'of', 'its', 'primary', 'responsibilities', 'is', 'to', 'bring', 'children', 'and', 'books', 'together', ';', ';']
# ['consequently', 'an', 'experienced', "children's", 'librarian', 'at', 'headquarters', 'conducts', 'a', 'guidance', 'program', 'designed', 'to', 'promote', 'well-planned', 'library', 'activities', ',', 'cooperating', 'with', 'the', "children's", 'librarians', 'in', 'member', 'libraries', 'by', 'means', 'of', 'individual', 'conferences', ',', 'workshops', ',', 'and', 'frequent', 'visits', '.']
# ['Headquarters', 'has', 'also', 'set', 'up', 'a', 'central', 'juvenile', 'book-review', 'and', 'book-selection', 'center', ',', 'to', 'provide', 'better', 'methods', 'of', 'purchasing', 'and', 'selection', '.']
# ['Sample', 'copies', 'of', 'new', 'books', 'are', 'on', 'display', 'at', 'headquarters', ',', 'where', 'librarians', 'may', 'evaluate', 'them', 'by', 'themselves', 'or', 'in', 'workshop', 'groups', '.']
# ['Story', 'hours', ',', 'pre-school', 'programs', ',', 'activities', 'with', 'community', 'agencies', ',', 'and', 'lists', 'of', 'recommended', 'reading', 'are', 'all', 'in', 'the', 'province', 'of', 'the', "children's", 'consultant', '.']
# ['Headquarters', 'of', 'the', 'Nassau', 'system', 'is', 'an', 'increasingly', 'busy', 'place', 'these', 'days', ',', 'threatening', 'to', 'expand', 'beyond', 'its', 'boundaries', '.']
# ['In', 'addition', 'to', 'the', 'interlibrary', 'loan', 'service', 'and', 'the', "children's", 'program', ',', 'headquarters', 'has', 'a', 'public', 'relations', 'director', 'who', 'seeks', 'to', 'get', 'wider', 'grassroots', 'support', 'for', 'quality', 'library', 'service', 'in', 'the', 'county', ';', ';']
# ['it', 'prepares', 'cooperative', 'displays', '(', 'posters', ',', 'booklists', ',', 'brochures', ',', 'and', 'other', 'promotional', 'material', ')', 'for', 'use', 'in', 'member', 'libraries', ';', ';']
# ['it', 'maintains', 'a', 'central', 'exhibit', 'collection', 'to', 'share', 'displays', 'already', 'created', 'and', 'used', ';', ';']
# ['and', 'it', 'publishes', 'Sum', 'And', 'Substance', ',', 'a', 'monthly', 'newsletter', ',', 'which', 'reports', 'the', "system's", 'activities', 'to', 'the', 'staffs', 'and', 'trustees', 'of', 'member', 'libraries', '.']
# ['The', 'system', 'itself', 'is', 'governed', 'by', 'a', 'board', 'of', 'trustees', ',', 'geographically', 'representing', 'its', 'membership', '.']
# ['In', 'Nassau', ',', 'as', 'in', 'other', 'systems', ',', 'the', 'long-range', 'objective', 'is', 'to', 'bring', 'the', 'maximum', 'service', 'of', 'libraries', 'to', 'bear', 'on', 'the', 'schools', ',', 'and', 'on', 'adult', 'education', 'in', 'general', '.']
# ['Librarians', ',', 'a', 'patient', 'breed', 'of', 'men', 'and', 'women', 'who', 'have', 'borne', 'much', 'with', 'dedication', ',', 'can', 'begin', 'to', 'see', 'results', 'today', '.']
# ['Library', 'use', 'is', 'multiplying', 'daily', ',', 'and', 'the', 'bulk', 'of', 'the', 'newcomers', 'are', 'those', 'maligned', 'Americans', ',', 'the', 'teen-agers', '.']
# ['To', 'them', 'especially', 'the', 'librarians', ',', 'with', 'the', 'help', 'of', 'co-ops', ',', 'hope', 'they', 'will', 'never', 'have', 'to', 'say', ',', '``', "I'm", 'sorry', ',', 'we', "don't", 'have', 'that', 'book', "''", '.']
# ['Today', ',', 'more', 'than', 'ever', 'before', ',', 'the', 'survival', 'of', 'our', 'free', 'society', 'depends', 'upon', 'the', 'citizen', 'who', 'is', 'both', 'informed', 'and', 'concerned', '.']
# ['The', 'great', 'advances', 'made', 'in', 'recent', 'years', 'in', 'Communist', 'strength', 'and', 'in', 'our', 'own', 'capacity', 'to', 'destroy', 'require', 'an', 'educated', 'citizenry', 'in', 'the', 'Western', 'world', '.']
# ['The', 'need', 'for', 'lifetime', 'reading', 'is', 'apparent', '.']
# ['Education', 'must', 'not', 'be', 'limited', 'to', 'our', 'youth', 'but', 'must', 'be', 'a', 'continuing', 'process', 'through', 'our', 'entire', 'lives', ',', 'for', 'it', 'is', 'only', 'through', 'knowledge', 'that', 'we', ',', 'as', 'a', 'nation', ',', 'can', 'cope', 'with', 'the', 'dangers', 'that', 'threaten', 'our', 'society', '.']
# ['The', 'desire', 'and', 'ability', 'to', 'read', 'are', 'important', 'aspects', 'of', 'our', 'cultural', 'life', '.']
# ['We', 'cannot', 'consider', 'ourselves', 'educated', 'if', 'we', 'do', 'not', 'read', ';', ';']
# ['if', 'we', 'are', 'not', 'discriminating', 'in', 'our', 'reading', ';', ';']
# ['if', 'we', 'do', 'not', 'know', 'how', 'to', 'use', 'what', 'we', 'do', 'read', '.']
# ['We', 'must', 'not', 'permit', 'our', 'society', 'to', 'become', 'a', 'slave', 'to', 'the', 'scientific', 'age', ',', 'as', 'might', 'well', 'happen', 'without', 'the', 'cultural', 'and', 'spiritual', 'restraint', 'that', 'comes', 'from', 'the', 'development', 'of', 'the', 'human', 'mind', 'through', 'wisdom', 'absorbed', 'from', 'the', 'written', 'word', '.']
# ['A', 'fundamental', 'source', 'of', 'knowledge', 'in', 'the', 'world', 'today', 'is', 'the', 'book', 'found', 'in', 'our', 'libraries', '.']
# ['Although', 'progress', 'has', 'been', 'made', 'in', "America's", 'system', 'of', 'libraries', 'it', 'still', 'falls', 'short', 'of', 'what', 'is', 'required', 'if', 'we', 'are', 'to', 'maintain', 'the', 'standards', 'that', 'are', 'needed', 'for', 'an', 'informed', 'America', '.']
# ['The', 'problem', 'grows', 'in', 'intensity', 'each', 'year', 'as', "man's", 'knowledge', ',', 'and', 'his', 'capacity', 'to', 'translate', 'such', 'knowledge', 'to', 'the', 'written', 'word', ',', 'continue', 'to', 'expand', '.']
# ['The', 'inadequacy', 'of', 'our', 'library', 'system', 'will', 'become', 'critical', 'unless', 'we', 'act', 'vigorously', 'to', 'correct', 'this', 'condition', '.']
# ['There', 'are', ',', 'for', 'example', ',', 'approximately', '25,000,000', 'people', 'in', 'this', 'country', 'with', 'no', 'public', 'library', 'service', 'and', 'about', '50,000,000', 'with', 'inadequate', 'service', '.']
# ['In', 'college', 'libraries', ',', '57', 'per', 'cent', 'of', 'the', 'total', 'number', 'of', 'books', 'are', 'owned', 'by', '124', 'of', '1,509', 'institutions', 'surveyed', 'last', 'year', 'by', 'the', 'U.S.', 'Office', 'of', 'Education', '.']
# ['And', 'over', '66', 'per', 'cent', 'of', 'the', 'elementary', 'schools', 'with', '150', 'or', 'more', 'pupils', 'do', 'not', 'have', 'any', 'library', 'at', 'all', '.']
# ['In', 'every', 'aspect', 'of', 'service', '--', 'to', 'the', 'public', ',', 'to', 'children', 'in', 'schools', ',', 'to', 'colleges', 'and', 'universities', '--', 'the', 'library', 'of', 'today', 'is', 'failing', 'to', 'render', 'vitally', 'needed', 'services', '.']
# ['Only', 'public', 'understanding', 'and', 'support', 'can', 'provide', 'that', 'service', '.']
# ['This', 'is', 'one', 'of', 'the', 'main', 'reasons', 'for', 'National', 'Library', 'Week', ',', 'April', '16-22', ',', 'and', 'for', 'its', 'theme', ':', '``', 'For', 'a', 'richer', ',', 'fuller', 'life', ',', 'read', "''", '!', '!']

# %%
import math

def random_batch(batch_size, word_sequence, skip_grams_id, X_ik, weighting_dic):
    
    #convert to id since our skip_grams is word, not yet id
    # skip_grams_id = [(word2index[skip_gram[0]], word2index[skip_gram[1]]) for skip_gram in skip_grams]
    
    random_inputs = []
    random_labels = []
    random_coocs  = []
    random_weightings = []
    random_index = np.random.choice(range(len(skip_grams_id)), batch_size, replace=False) #randomly pick without replacement
        
    for i in random_index:
        random_inputs.append([skip_grams_id[i][0]])  # target, e.g., 2
        random_labels.append([skip_grams_id[i][1]])  # context word, e.g., 3
        
        #get cooc
        pair = skip_grams[i]
        try:
            cooc = X_ik[pair]
        except:
            cooc = 1
        random_coocs.append([math.log(cooc)])
        
        #get weighting
        weighting = weighting_dic[pair]
        random_weightings.append([weighting])
                    
    return np.array(random_inputs), np.array(random_labels), np.array(random_coocs), np.array(random_weightings)

# %% [markdown]
# ### Testing the method

# %%
weighting_dic
# Out:
# {('Clearwater', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'rush'): 0.03162277660168379,
#  ('rush', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Indonesia'): 0.03162277660168379,
#  ('Indonesia', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'association'): 0.03162277660168379,
#  ('association', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'slashed'): 0.03162277660168379,
#  ('slashed', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', "writers'"): 0.03162277660168379,
#  ("writers'", 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'miscount'): 0.03162277660168379,
#  ('miscount', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'forecasts'): 0.03162277660168379,
#  ('forecasts', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Griffith-Jones'): 0.03162277660168379,
#  ('Griffith-Jones', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'bumper'): 0.03162277660168379,
#  ('bumper', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'sacker'): 0.03162277660168379,
#  ('sacker', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'stepping'): 0.03162277660168379,
#  ('stepping', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'telling'): 0.03162277660168379,
#  ('telling', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'infant'): 0.03162277660168379,
#  ('infant', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'gloomily'): 0.03162277660168379,
#  ('gloomily', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'India'): 0.03162277660168379,
#  ('India', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Channel'): 0.03162277660168379,
#  ('Channel', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Town'): 0.03162277660168379,
#  ('Town', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Truck'): 0.03162277660168379,
#  ('Truck', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'suspect'): 0.03162277660168379,
#  ('suspect', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Washington-Oregon'): 0.03162277660168379,
#  ('Washington-Oregon', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Souvanna'): 0.03162277660168379,
#  ('Souvanna', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'burning'): 0.03162277660168379,
#  ('burning', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'temporarily'): 0.03162277660168379,
#  ('temporarily', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'summertime'): 0.03162277660168379,
#  ('summertime', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'implement'): 0.03162277660168379,
#  ('implement', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'thoroughfare'): 0.03162277660168379,
#  ('thoroughfare', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', '3,000'): 0.03162277660168379,
#  ('3,000', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', '10,000,000'): 0.03162277660168379,
#  ('10,000,000', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'struggle'): 0.03162277660168379,
#  ('struggle', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'nitroglycerine'): 0.03162277660168379,
#  ('nitroglycerine', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'foster'): 0.03162277660168379,
#  ('foster', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Westinghouse'): 0.03162277660168379,
#  ('Westinghouse', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'came'): 0.03162277660168379,
#  ('came', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', '15th'): 0.03162277660168379,
#  ('15th', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Greer'): 0.03162277660168379,
#  ('Greer', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'oft-repeated'): 0.03162277660168379,
#  ('oft-repeated', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Lummus'): 0.03162277660168379,
#  ('Lummus', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'specifications'): 0.03162277660168379,
#  ('specifications', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'confronted'): 0.03162277660168379,
#  ('confronted', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', '6,000'): 0.03162277660168379,
#  ('6,000', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'cleared'): 0.03162277660168379,
#  ('cleared', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Ted'): 0.03162277660168379,
#  ('Ted', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'outrun'): 0.03162277660168379,
#  ('outrun', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Greenberg'): 0.03162277660168379,
#  ('Greenberg', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'smoldered'): 0.03162277660168379,
#  ('smoldered', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'attends'): 0.03162277660168379,
#  ('attends', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', '$5000'): 0.03162277660168379,
#  ('$5000', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'posed'): 0.03162277660168379,
#  ('posed', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'rebound'): 0.03162277660168379,
#  ('rebound', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Tranquility'): 0.03162277660168379,
#  ('Tranquility', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'respond'): 0.03162277660168379,
#  ('respond', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'grain'): 0.03162277660168379,
#  ('grain', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'portrayal'): 0.03162277660168379,
#  ('portrayal', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'forbid'): 0.03162277660168379,
#  ('forbid', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Eppler'): 0.03162277660168379,
#  ('Eppler', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', "Underwood's"): 0.03162277660168379,
#  ("Underwood's", 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Flower'): 0.03162277660168379,
#  ('Flower', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Basketball'): 0.03162277660168379,
#  ('Basketball', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'white'): 0.03162277660168379,
#  ('white', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Arlington'): 0.03162277660168379,
#  ('Arlington', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Corporation'): 0.03162277660168379,
#  ('Corporation', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Ankara'): 0.03162277660168379,
#  ('Ankara', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'guests'): 0.03162277660168379,
#  ('guests', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'pianist'): 0.03162277660168379,
#  ('pianist', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Fargo'): 0.03162277660168379,
#  ('Fargo', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'impossibly'): 0.03162277660168379,
#  ('impossibly', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'shoe'): 0.03162277660168379,
#  ('shoe', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'broadened'): 0.03162277660168379,
#  ('broadened', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'jolt'): 0.03162277660168379,
#  ('jolt', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'assemble'): 0.03162277660168379,
#  ('assemble', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'pops'): 0.03162277660168379,
#  ('pops', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'condemned'): 0.03162277660168379,
#  ('condemned', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'establish'): 0.03162277660168379,
#  ('establish', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Harvey'): 0.03162277660168379,
#  ('Harvey', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Lt.'): 0.03162277660168379,
#  ('Lt.', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', '$28,700,000'): 0.03162277660168379,
#  ('$28,700,000', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'topics'): 0.03162277660168379,
#  ('topics', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Nobody'): 0.03162277660168379,
#  ('Nobody', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'chemistry'): 0.03162277660168379,
#  ('chemistry', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'alternative'): 0.03162277660168379,
#  ('alternative', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'occasion'): 0.03162277660168379,
#  ('occasion', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'loomed'): 0.03162277660168379,
#  ('loomed', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'hopeful'): 0.03162277660168379,
#  ('hopeful', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', '676'): 0.03162277660168379,
#  ('676', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Holbrook'): 0.03162277660168379,
#  ('Holbrook', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Macassar'): 0.03162277660168379,
#  ('Macassar', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'executive'): 0.03162277660168379,
#  ('executive', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Mayor'): 0.03162277660168379,
#  ('Mayor', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'grocery'): 0.03162277660168379,
#  ('grocery', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'honors'): 0.03162277660168379,
#  ('honors', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'intervention'): 0.03162277660168379,
#  ('intervention', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'yellow'): 0.03162277660168379,
#  ('yellow', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'tardiness'): 0.03162277660168379,
#  ('tardiness', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'figured'): 0.03162277660168379,
#  ('figured', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'accounted'): 0.03162277660168379,
#  ('accounted', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'earns'): 0.03162277660168379,
#  ('earns', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Coopers'): 0.03162277660168379,
#  ('Coopers', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'stand'): 0.03162277660168379,
#  ('stand', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Therefore'): 0.03162277660168379,
#  ('Therefore', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'freight'): 0.03162277660168379,
#  ('freight', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'sum'): 0.03162277660168379,
#  ('sum', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Cerebral'): 0.03162277660168379,
#  ('Cerebral', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'investigated'): 0.03162277660168379,
#  ('investigated', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Outlays'): 0.03162277660168379,
#  ('Outlays', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Time'): 0.03162277660168379,
#  ('Time', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Young'): 0.03162277660168379,
#  ('Young', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Since'): 0.03162277660168379,
#  ('Since', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'chose'): 0.03162277660168379,
#  ('chose', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'efficiently'): 0.03162277660168379,
#  ('efficiently', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'availability'): 0.03162277660168379,
#  ('availability', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'astray'): 0.03162277660168379,
#  ('astray', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'April-June'): 0.03162277660168379,
#  ('April-June', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Premier'): 0.03162277660168379,
#  ('Premier', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'LSU'): 0.03162277660168379,
#  ('LSU', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', '5847'): 0.03162277660168379,
#  ('5847', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'knew'): 0.03162277660168379,
#  ('knew', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'hike'): 0.03162277660168379,
#  ('hike', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Masque'): 0.03162277660168379,
#  ('Masque', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'high'): 0.03162277660168379,
#  ('high', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', "year's"): 0.03162277660168379,
#  ("year's", 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'uncontrolled'): 0.03162277660168379,
#  ('uncontrolled', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'extensive'): 0.03162277660168379,
#  ('extensive', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Sabbath'): 0.03162277660168379,
#  ('Sabbath', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'contribs'): 0.03162277660168379,
#  ('contribs', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'fifth'): 0.03162277660168379,
#  ('fifth', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'surely'): 0.03162277660168379,
#  ('surely', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', '228-229'): 0.03162277660168379,
#  ('228-229', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Award'): 0.03162277660168379,
#  ('Award', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'stove'): 0.03162277660168379,
#  ('stove', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Grinsfelder'): 0.03162277660168379,
#  ('Grinsfelder', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'snowfall'): 0.03162277660168379,
#  ('snowfall', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Indianapolis'): 0.03162277660168379,
#  ('Indianapolis', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Mill'): 0.03162277660168379,
#  ('Mill', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'heartbreaking'): 0.03162277660168379,
#  ('heartbreaking', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'mechanics'): 0.03162277660168379,
#  ('mechanics', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Sixty-seven'): 0.03162277660168379,
#  ('Sixty-seven', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'outfit'): 0.03162277660168379,
#  ('outfit', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'diplomat'): 0.03162277660168379,
#  ('diplomat', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'delay'): 0.03162277660168379,
#  ('delay', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Duren'): 0.03162277660168379,
#  ('Duren', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'submarine-ball'): 0.03162277660168379,
#  ('submarine-ball', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'lavishly'): 0.03162277660168379,
#  ('lavishly', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'percentage'): 0.03162277660168379,
#  ('percentage', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'insist'): 0.03162277660168379,
#  ('insist', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'imprudently'): 0.03162277660168379,
#  ('imprudently', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Clinton'): 0.03162277660168379,
#  ('Clinton', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Quite'): 0.03162277660168379,
#  ('Quite', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'medal'): 0.03162277660168379,
#  ('medal', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'drafted'): 0.03162277660168379,
#  ('drafted', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'animated'): 0.03162277660168379,
#  ('animated', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'grandchildren'): 0.03162277660168379,
#  ('grandchildren', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'rancho'): 0.03162277660168379,
#  ('rancho', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'congressmen'): 0.03162277660168379,
#  ('congressmen', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', '27-year-old'): 0.03162277660168379,
#  ('27-year-old', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', '8,280'): 0.03162277660168379,
#  ('8,280', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'along'): 0.03162277660168379,
#  ('along', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Homeowners'): 0.03162277660168379,
#  ('Homeowners', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Saul'): 0.03162277660168379,
#  ('Saul', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'go'): 0.03162277660168379,
#  ('go', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'information'): 0.03162277660168379,
#  ('information', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'moves'): 0.03162277660168379,
#  ('moves', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'offer'): 0.03162277660168379,
#  ('offer', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Smythe'): 0.03162277660168379,
#  ('Smythe', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'public'): 0.03162277660168379,
#  ('public', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', '1945'): 0.03162277660168379,
#  ('1945', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Wellesley'): 0.03162277660168379,
#  ('Wellesley', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Persons'): 0.03162277660168379,
#  ('Persons', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'museum'): 0.03162277660168379,
#  ('museum', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'drastic'): 0.03162277660168379,
#  ('drastic', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'outnumber'): 0.03162277660168379,
#  ('outnumber', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'productions'): 0.03162277660168379,
#  ('productions', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'flies'): 0.03162277660168379,
#  ('flies', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'husbands'): 0.03162277660168379,
#  ('husbands', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'catalogue'): 0.03162277660168379,
#  ('catalogue', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'delighted'): 0.03162277660168379,
#  ('delighted', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'remarkable'): 0.03162277660168379,
#  ('remarkable', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'NE'): 0.03162277660168379,
#  ('NE', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Camp'): 0.03162277660168379,
#  ('Camp', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'projects'): 0.03162277660168379,
#  ('projects', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'campaigned'): 0.03162277660168379,
#  ('campaigned', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'L.'): 0.03162277660168379,
#  ('L.', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Sandra'): 0.03162277660168379,
#  ('Sandra', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'seed'): 0.03162277660168379,
#  ('seed', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'clearing'): 0.03162277660168379,
#  ('clearing', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'boom'): 0.03162277660168379,
#  ('boom', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'negotiation'): 0.03162277660168379,
#  ('negotiation', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Presbyterian'): 0.03162277660168379,
#  ('Presbyterian', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'launched'): 0.03162277660168379,
#  ('launched', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'oriental'): 0.03162277660168379,
#  ('oriental', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'magic'): 0.03162277660168379,
#  ('magic', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', '5835'): 0.03162277660168379,
#  ('5835', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'inappropriate'): 0.03162277660168379,
#  ('inappropriate', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'sentencing'): 0.03162277660168379,
#  ('sentencing', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'vantage'): 0.03162277660168379,
#  ('vantage', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'duplication'): 0.03162277660168379,
#  ('duplication', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'customers'): 0.03162277660168379,
#  ('customers', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'compelled'): 0.03162277660168379,
#  ('compelled', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'outstanding'): 0.03162277660168379,
#  ('outstanding', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'inefficient'): 0.03162277660168379,
#  ('inefficient', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Members'): 0.03162277660168379,
#  ('Members', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'three-way'): 0.03162277660168379,
#  ('three-way', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Norris-LaGuardia'): 0.03162277660168379,
#  ('Norris-LaGuardia', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Pirate'): 0.03162277660168379,
#  ('Pirate', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'cloakrooms'): 0.03162277660168379,
#  ('cloakrooms', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', '390-foot'): 0.03162277660168379,
#  ('390-foot', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'unified'): 0.03162277660168379,
#  ('unified', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'unmatched'): 0.03162277660168379,
#  ('unmatched', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Solid'): 0.03162277660168379,
#  ('Solid', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Fifteen'): 0.03162277660168379,
#  ('Fifteen', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'enables'): 0.03162277660168379,
#  ('enables', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'suited'): 0.03162277660168379,
#  ('suited', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Salary'): 0.03162277660168379,
#  ('Salary', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'NYU'): 0.03162277660168379,
#  ('NYU', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'waited'): 0.03162277660168379,
#  ('waited', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'frustrated'): 0.03162277660168379,
#  ('frustrated', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Socola'): 0.03162277660168379,
#  ('Socola', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'fan'): 0.03162277660168379,
#  ('fan', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'allocation'): 0.03162277660168379,
#  ('allocation', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'decrease'): 0.03162277660168379,
#  ('decrease', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'organizing'): 0.03162277660168379,
#  ('organizing', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'improperly'): 0.03162277660168379,
#  ('improperly', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Dave'): 0.03162277660168379,
#  ('Dave', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Goldwater'): 0.03162277660168379,
#  ('Goldwater', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'contained'): 0.03162277660168379,
#  ('contained', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Hester'): 0.03162277660168379,
#  ('Hester', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'clerical'): 0.03162277660168379,
#  ('clerical', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Junior'): 0.03162277660168379,
#  ('Junior', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Carbones'): 0.03162277660168379,
#  ('Carbones', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'northernmost'): 0.03162277660168379,
#  ('northernmost', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'full'): 0.03162277660168379,
#  ('full', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Berlin'): 0.03162277660168379,
#  ('Berlin', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'deduction'): 0.03162277660168379,
#  ('deduction', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'spider-leg'): 0.03162277660168379,
#  ('spider-leg', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Willard'): 0.03162277660168379,
#  ('Willard', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'mechanisms'): 0.03162277660168379,
#  ('mechanisms', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Teller'): 0.03162277660168379,
#  ('Teller', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'exploit'): 0.03162277660168379,
#  ('exploit', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Norm'): 0.03162277660168379,
#  ('Norm', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'aforementioned'): 0.03162277660168379,
#  ('aforementioned', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'discarded'): 0.03162277660168379,
#  ('discarded', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Bevo'): 0.03162277660168379,
#  ('Bevo', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'rentals'): 0.03162277660168379,
#  ('rentals', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Open'): 0.03162277660168379,
#  ('Open', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Playboy'): 0.03162277660168379,
#  ('Playboy', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'irrationality'): 0.03162277660168379,
#  ('irrationality', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'assembled'): 0.03162277660168379,
#  ('assembled', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'generously'): 0.03162277660168379,
#  ('generously', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Woodland'): 0.03162277660168379,
#  ('Woodland', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'lamps'): 0.03162277660168379,
#  ('lamps', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'timely'): 0.03162277660168379,
#  ('timely', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Kililngsworth'): 0.03162277660168379,
#  ('Kililngsworth', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'services'): 0.03162277660168379,
#  ('services', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', "you're"): 0.03162277660168379,
#  ("you're", 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', '114'): 0.03162277660168379,
#  ('114', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'profit'): 0.03162277660168379,
#  ('profit', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', '42'): 0.03162277660168379,
#  ('42', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'sees'): 0.03162277660168379,
#  ('sees', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'employments'): 0.03162277660168379,
#  ('employments', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'advocacy'): 0.03162277660168379,
#  ('advocacy', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'spices'): 0.03162277660168379,
#  ('spices', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'tent'): 0.03162277660168379,
#  ('tent', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'losing'): 0.03162277660168379,
#  ('losing', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'rightfully'): 0.03162277660168379,
#  ('rightfully', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Issue'): 0.03162277660168379,
#  ('Issue', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', '25-foot'): 0.03162277660168379,
#  ('25-foot', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'pile'): 0.03162277660168379,
#  ('pile', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'skyjacked'): 0.03162277660168379,
#  ('skyjacked', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'god-like'): 0.03162277660168379,
#  ('god-like', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Dixiecrats'): 0.03162277660168379,
#  ('Dixiecrats', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'widowed'): 0.03162277660168379,
#  ('widowed', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'undergoing'): 0.03162277660168379,
#  ('undergoing', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', "Raiders'"): 0.03162277660168379,
#  ("Raiders'", 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', '1947'): 0.03162277660168379,
#  ('1947', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', "Field's"): 0.03162277660168379,
#  ("Field's", 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Cynthia'): 0.03162277660168379,
#  ('Cynthia', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Chester'): 0.03162277660168379,
#  ('Chester', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'significant'): 0.03162277660168379,
#  ('significant', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', '$1'): 0.03162277660168379,
#  ('$1', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'returns'): 0.03162277660168379,
#  ('returns', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'possessive'): 0.03162277660168379,
#  ('possessive', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'belted'): 0.03162277660168379,
#  ('belted', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Wragge'): 0.03162277660168379,
#  ('Wragge', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', "he's"): 0.03162277660168379,
#  ("he's", 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Eldon'): 0.03162277660168379,
#  ('Eldon', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'visitors'): 0.03162277660168379,
#  ('visitors', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', '9'): 0.03162277660168379,
#  ('9', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'marble'): 0.03162277660168379,
#  ('marble', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'hill'): 0.03162277660168379,
#  ('hill', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Kissak'): 0.03162277660168379,
#  ('Kissak', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'manual'): 0.03162277660168379,
#  ('manual', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', '$25-a-plate'): 0.03162277660168379,
#  ('$25-a-plate', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Regrets'): 0.03162277660168379,
#  ('Regrets', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'balls'): 0.03162277660168379,
#  ('balls', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'And'): 0.03162277660168379,
#  ('And', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'merely'): 0.03162277660168379,
#  ('merely', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', "Burkes'"): 0.03162277660168379,
#  ("Burkes'", 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'correspondents'): 0.03162277660168379,
#  ('correspondents', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Hotel'): 0.03162277660168379,
#  ('Hotel', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'language'): 0.03162277660168379,
#  ('language', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'substitute'): 0.03162277660168379,
#  ('substitute', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'presentation'): 0.03162277660168379,
#  ('presentation', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'playtime'): 0.03162277660168379,
#  ('playtime', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Grapefruit'): 0.03162277660168379,
#  ('Grapefruit', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Pate'): 0.03162277660168379,
#  ('Pate', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'homer'): 0.03162277660168379,
#  ('homer', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'exception'): 0.03162277660168379,
#  ('exception', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'violate'): 0.03162277660168379,
#  ('violate', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'enlarging'): 0.03162277660168379,
#  ('enlarging', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'distasteful'): 0.03162277660168379,
#  ('distasteful', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'wood'): 0.03162277660168379,
#  ('wood', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Baltimore'): 0.03162277660168379,
#  ('Baltimore', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'part'): 0.03162277660168379,
#  ('part', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'pepping'): 0.03162277660168379,
#  ('pepping', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', "Britain's"): 0.03162277660168379,
#  ("Britain's", 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Sent'): 0.03162277660168379,
#  ('Sent', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'thieves'): 0.03162277660168379,
#  ('thieves', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Business'): 0.03162277660168379,
#  ('Business', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', "Republicans'"): 0.03162277660168379,
#  ("Republicans'", 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Thirty-one'): 0.03162277660168379,
#  ('Thirty-one', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Latinovich'): 0.03162277660168379,
#  ('Latinovich', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'spread'): 0.03162277660168379,
#  ('spread', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'haze'): 0.03162277660168379,
#  ('haze', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'earliest'): 0.03162277660168379,
#  ('earliest', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'selection'): 0.03162277660168379,
#  ('selection', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'breathes'): 0.03162277660168379,
#  ('breathes', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'centralization'): 0.03162277660168379,
#  ('centralization', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'campaigning'): 0.03162277660168379,
#  ('campaigning', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'surveillance'): 0.03162277660168379,
#  ('surveillance', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'faults'): 0.03162277660168379,
#  ('faults', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'doings'): 0.03162277660168379,
#  ('doings', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'inauguration'): 0.03162277660168379,
#  ('inauguration', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'valid'): 0.03162277660168379,
#  ('valid', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'possessing'): 0.03162277660168379,
#  ('possessing', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Forever'): 0.03162277660168379,
#  ('Forever', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'gallery'): 0.03162277660168379,
#  ('gallery', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'blundered'): 0.03162277660168379,
#  ('blundered', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', "Shartzer's"): 0.03162277660168379,
#  ("Shartzer's", 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', '19th'): 0.03162277660168379,
#  ('19th', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'peddler'): 0.03162277660168379,
#  ('peddler', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Kerby'): 0.03162277660168379,
#  ('Kerby', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'piracy'): 0.03162277660168379,
#  ('piracy', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'hip'): 0.03162277660168379,
#  ('hip', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'sagging'): 0.03162277660168379,
#  ('sagging', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Bird'): 0.03162277660168379,
#  ('Bird', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'confession'): 0.03162277660168379,
#  ('confession', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'peace'): 0.03162277660168379,
#  ('peace', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'seen'): 0.03162277660168379,
#  ('seen', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Lyle'): 0.03162277660168379,
#  ('Lyle', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'speck'): 0.03162277660168379,
#  ('speck', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'fifteenth'): 0.03162277660168379,
#  ('fifteenth', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'juror'): 0.03162277660168379,
#  ('juror', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'churchmen'): 0.03162277660168379,
#  ('churchmen', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'fighters'): 0.03162277660168379,
#  ('fighters', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'flower'): 0.03162277660168379,
#  ('flower', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'desirable'): 0.03162277660168379,
#  ('desirable', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'disaster'): 0.03162277660168379,
#  ('disaster', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'usual'): 0.03162277660168379,
#  ('usual', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Ginghams'): 0.03162277660168379,
#  ('Ginghams', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'ten-concert'): 0.03162277660168379,
#  ('ten-concert', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Nordmann'): 0.03162277660168379,
#  ('Nordmann', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'contemptuous'): 0.03162277660168379,
#  ('contemptuous', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Goodbye'): 0.03162277660168379,
#  ('Goodbye', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Claus'): 0.03162277660168379,
#  ('Claus', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Georgia'): 0.03162277660168379,
#  ('Georgia', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'advertises'): 0.03162277660168379,
#  ('advertises', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Brooklyn'): 0.03162277660168379,
#  ('Brooklyn', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'freeze'): 0.03162277660168379,
#  ('freeze', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', "Don't"): 0.03162277660168379,
#  ("Don't", 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'noses'): 0.03162277660168379,
#  ('noses', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', '5,000'): 0.03162277660168379,
#  ('5,000', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', '19-12'): 0.03162277660168379,
#  ('19-12', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'bargaining'): 0.03162277660168379,
#  ('bargaining', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'occupation'): 0.03162277660168379,
#  ('occupation', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'license'): 0.03162277660168379,
#  ('license', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'durable'): 0.03162277660168379,
#  ('durable', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'noticed'): 0.03162277660168379,
#  ('noticed', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'delayed'): 0.03162277660168379,
#  ('delayed', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'miles'): 0.03162277660168379,
#  ('miles', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Meet'): 0.03162277660168379,
#  ('Meet', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'collecting'): 0.03162277660168379,
#  ('collecting', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', '46'): 0.03162277660168379,
#  ('46', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'remember'): 0.03162277660168379,
#  ('remember', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'penalized'): 0.03162277660168379,
#  ('penalized', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'at'): 0.03162277660168379,
#  ('at', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'clicked'): 0.03162277660168379,
#  ('clicked', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'prediction'): 0.03162277660168379,
#  ('prediction', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Long'): 0.03162277660168379,
#  ('Long', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'square'): 0.03162277660168379,
#  ('square', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Westminster'): 0.03162277660168379,
#  ('Westminster', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'dissatisfaction'): 0.03162277660168379,
#  ('dissatisfaction', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'foes'): 0.03162277660168379,
#  ('foes', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'luncheon'): 0.03162277660168379,
#  ('luncheon', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'slogan'): 0.03162277660168379,
#  ('slogan', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'featuring'): 0.03162277660168379,
#  ('featuring', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'flooded'): 0.03162277660168379,
#  ('flooded', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'discounts'): 0.03162277660168379,
#  ('discounts', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Implementation'): 0.03162277660168379,
#  ('Implementation', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'avidly'): 0.03162277660168379,
#  ('avidly', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Parliament'): 0.03162277660168379,
#  ('Parliament', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'setback'): 0.03162277660168379,
#  ('setback', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'directions'): 0.03162277660168379,
#  ('directions', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'reluctantly'): 0.03162277660168379,
#  ('reluctantly', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Oilers'): 0.03162277660168379,
#  ('Oilers', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'illustration'): 0.03162277660168379,
#  ('illustration', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'arises'): 0.03162277660168379,
#  ('arises', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'wonderful'): 0.03162277660168379,
#  ('wonderful', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'wish'): 0.03162277660168379,
#  ('wish', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'surged'): 0.03162277660168379,
#  ('surged', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', "Center's"): 0.03162277660168379,
#  ("Center's", 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'detachment'): 0.03162277660168379,
#  ('detachment', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'vehemence'): 0.03162277660168379,
#  ('vehemence', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'I.'): 0.03162277660168379,
#  ('I.', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Class'): 0.03162277660168379,
#  ('Class', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'regrouping'): 0.03162277660168379,
#  ('regrouping', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'stein'): 0.03162277660168379,
#  ('stein', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'killing'): 0.03162277660168379,
#  ('killing', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Corruption'): 0.03162277660168379,
#  ('Corruption', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', '25,000,000'): 0.03162277660168379,
#  ('25,000,000', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'before'): 0.03162277660168379,
#  ('before', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Sanitation'): 0.03162277660168379,
#  ('Sanitation', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'chamber'): 0.03162277660168379,
#  ('chamber', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'brings'): 0.03162277660168379,
#  ('brings', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'sank'): 0.03162277660168379,
#  ('sank', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'journalist'): 0.03162277660168379,
#  ('journalist', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'blond'): 0.03162277660168379,
#  ('blond', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', "world's"): 0.03162277660168379,
#  ("world's", 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Yanks'): 0.03162277660168379,
#  ('Yanks', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Show'): 0.03162277660168379,
#  ('Show', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'new'): 0.03162277660168379,
#  ('new', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'attorney'): 0.03162277660168379,
#  ('attorney', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'classed'): 0.03162277660168379,
#  ('classed', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'persuade'): 0.03162277660168379,
#  ('persuade', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'distribution'): 0.03162277660168379,
#  ('distribution', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'excavation'): 0.03162277660168379,
#  ('excavation', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'court-length'): 0.03162277660168379,
#  ('court-length', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', '1923'): 0.03162277660168379,
#  ('1923', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'original'): 0.03162277660168379,
#  ('original', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'substantiation'): 0.03162277660168379,
#  ('substantiation', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Which'): 0.03162277660168379,
#  ('Which', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'highest-paid'): 0.03162277660168379,
#  ('highest-paid', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'capital'): 0.03162277660168379,
#  ('capital', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', "Georgia's"): 0.03162277660168379,
#  ("Georgia's", 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Wealth'): 0.03162277660168379,
#  ('Wealth', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'averages'): 0.03162277660168379,
#  ('averages', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'robberies'): 0.03162277660168379,
#  ('robberies', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Dearborn'): 0.03162277660168379,
#  ('Dearborn', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'rationale'): 0.03162277660168379,
#  ('rationale', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', "There's"): 0.03162277660168379,
#  ("There's", 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'vigor'): 0.03162277660168379,
#  ('vigor', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'emerges'): 0.03162277660168379,
#  ('emerges', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'undergraduate'): 0.03162277660168379,
#  ('undergraduate', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'roughly'): 0.03162277660168379,
#  ('roughly', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Appeals'): 0.03162277660168379,
#  ('Appeals', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'transaction'): 0.03162277660168379,
#  ('transaction', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'menu'): 0.03162277660168379,
#  ('menu', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'top'): 0.03162277660168379,
#  ('top', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Blumberg'): 0.03162277660168379,
#  ('Blumberg', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'necessitate'): 0.03162277660168379,
#  ('necessitate', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Vermont'): 0.03162277660168379,
#  ('Vermont', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Sum'): 0.03162277660168379,
#  ('Sum', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'clerk'): 0.03162277660168379,
#  ('clerk', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Gevurtz'): 0.03162277660168379,
#  ('Gevurtz', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'exaltation'): 0.03162277660168379,
#  ('exaltation', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'ye'): 0.03162277660168379,
#  ('ye', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'theologian'): 0.03162277660168379,
#  ('theologian', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Lubbock'): 0.03162277660168379,
#  ('Lubbock', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'panel'): 0.03162277660168379,
#  ('panel', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'creed'): 0.03162277660168379,
#  ('creed', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'school'): 0.03162277660168379,
#  ('school', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'delinquency'): 0.03162277660168379,
#  ('delinquency', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', '154'): 0.03162277660168379,
#  ('154', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Bubenik'): 0.03162277660168379,
#  ('Bubenik', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'inboard'): 0.03162277660168379,
#  ('inboard', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'compulsory'): 0.03162277660168379,
#  ('compulsory', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'rock'): 0.03162277660168379,
#  ('rock', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'one-room'): 0.03162277660168379,
#  ('one-room', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Braves'): 0.03162277660168379,
#  ('Braves', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Malone'): 0.03162277660168379,
#  ('Malone', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', '63'): 0.03162277660168379,
#  ('63', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'ever-changing'): 0.03162277660168379,
#  ('ever-changing', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'compassionate'): 0.03162277660168379,
#  ('compassionate', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'haute'): 0.03162277660168379,
#  ('haute', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'invaded'): 0.03162277660168379,
#  ('invaded', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'qualified'): 0.03162277660168379,
#  ('qualified', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'secede'): 0.03162277660168379,
#  ('secede', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'heard'): 0.03162277660168379,
#  ('heard', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', "Russians'"): 0.03162277660168379,
#  ("Russians'", 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Juvenile'): 0.03162277660168379,
#  ('Juvenile', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'delivered'): 0.03162277660168379,
#  ('delivered', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Republicanism'): 0.03162277660168379,
#  ('Republicanism', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'perhaps'): 0.03162277660168379,
#  ('perhaps', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'baked'): 0.03162277660168379,
#  ('baked', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'cheery'): 0.03162277660168379,
#  ('cheery', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'aptly'): 0.03162277660168379,
#  ('aptly', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'Hat'): 0.03162277660168379,
#  ('Hat', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'citizen'): 0.03162277660168379,
#  ('citizen', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'ones'): 0.03162277660168379,
#  ('ones', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'bunters'): 0.03162277660168379,
#  ('bunters', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'endure'): 0.03162277660168379,
#  ('endure', 'Clearwater'): 0.03162277660168379,
#  ('Clearwater', 'joining'): 0.03162277660168379,
#  ...}

# %%
skip_grams
# Out:
# [('County', 'Fulton'),
#  ('County', 'Grand'),
#  ('Grand', 'County'),
#  ('Grand', 'Jury'),
#  ('Jury', 'Grand'),
#  ('Jury', 'said'),
#  ('said', 'Jury'),
#  ('said', 'Friday'),
#  ('Friday', 'said'),
#  ('Friday', 'an'),
#  ('an', 'Friday'),
#  ('an', 'investigation'),
#  ('investigation', 'an'),
#  ('investigation', 'of'),
#  ('of', 'investigation'),
#  ('of', "Atlanta's"),
#  ("Atlanta's", 'of'),
#  ("Atlanta's", 'recent'),
#  ('recent', "Atlanta's"),
#  ('recent', 'primary'),
#  ('primary', 'recent'),
#  ('primary', 'election'),
#  ('election', 'primary'),
#  ('election', 'produced'),
#  ('produced', 'election'),
#  ('produced', '``'),
#  ('``', 'produced'),
#  ('``', 'no'),
#  ('no', '``'),
#  ('no', 'evidence'),
#  ('evidence', 'no'),
#  ('evidence', "''"),
#  ("''", 'evidence'),
#  ("''", 'that'),
#  ('that', "''"),
#  ('that', 'any'),
#  ('any', 'that'),
#  ('any', 'irregularities'),
#  ('irregularities', 'any'),
#  ('irregularities', 'took'),
#  ('took', 'irregularities'),
#  ('took', 'place'),
#  ('further', 'jury'),
#  ('further', 'said'),
#  ('said', 'further'),
#  ('said', 'in'),
#  ('in', 'said'),
#  ('in', 'term-end'),
#  ('term-end', 'in'),
#  ('term-end', 'presentments'),
#  ('presentments', 'term-end'),
#  ('presentments', 'that'),
#  ('that', 'presentments'),
#  ('that', 'the'),
#  ('the', 'that'),
#  ('the', 'City'),
#  ('City', 'the'),
#  ('City', 'Executive'),
#  ('Executive', 'City'),
#  ('Executive', 'Committee'),
#  ('Committee', 'Executive'),
#  ('Committee', ','),
#  (',', 'Committee'),
#  (',', 'which'),
#  ('which', ','),
#  ('which', 'had'),
#  ('had', 'which'),
#  ('had', 'over-all'),
#  ('over-all', 'had'),
#  ('over-all', 'charge'),
#  ('charge', 'over-all'),
#  ('charge', 'of'),
#  ('of', 'charge'),
#  ('of', 'the'),
#  ('the', 'of'),
#  ('the', 'election'),
#  ('election', 'the'),
#  ('election', ','),
#  (',', 'election'),
#  (',', '``'),
#  ('``', ','),
#  ('``', 'deserves'),
#  ('deserves', '``'),
#  ('deserves', 'the'),
#  ('the', 'deserves'),
#  ('the', 'praise'),
#  ('praise', 'the'),
#  ('praise', 'and'),
#  ('and', 'praise'),
#  ('and', 'thanks'),
#  ('thanks', 'and'),
#  ('thanks', 'of'),
#  ('of', 'thanks'),
#  ('of', 'the'),
#  ('the', 'of'),
#  ('the', 'City'),
#  ('City', 'the'),
#  ('City', 'of'),
#  ('of', 'City'),
#  ('of', 'Atlanta'),
#  ('Atlanta', 'of'),
#  ('Atlanta', "''"),
#  ("''", 'Atlanta'),
#  ("''", 'for'),
#  ('for', "''"),
#  ('for', 'the'),
#  ('the', 'for'),
#  ('the', 'manner'),
#  ('manner', 'the'),
#  ('manner', 'in'),
#  ('in', 'manner'),
#  ('in', 'which'),
#  ('which', 'in'),
#  ('which', 'the'),
#  ('the', 'which'),
#  ('the', 'election'),
#  ('election', 'the'),
#  ('election', 'was'),
#  ('was', 'election'),
#  ('was', 'conducted'),
#  ('term', 'September-October'),
#  ('term', 'jury'),
#  ('jury', 'term'),
#  ('jury', 'had'),
#  ('had', 'jury'),
#  ('had', 'been'),
#  ('been', 'had'),
#  ('been', 'charged'),
#  ('charged', 'been'),
#  ('charged', 'by'),
#  ('by', 'charged'),
#  ('by', 'Fulton'),
#  ('Fulton', 'by'),
#  ('Fulton', 'Superior'),
#  ('Superior', 'Fulton'),
#  ('Superior', 'Court'),
#  ('Court', 'Superior'),
#  ('Court', 'Judge'),
#  ('Judge', 'Court'),
#  ('Judge', 'Durwood'),
#  ('Durwood', 'Judge'),
#  ('Durwood', 'Pye'),
#  ('Pye', 'Durwood'),
#  ('Pye', 'to'),
#  ('to', 'Pye'),
#  ('to', 'investigate'),
#  ('investigate', 'to'),
#  ('investigate', 'reports'),
#  ('reports', 'investigate'),
#  ('reports', 'of'),
#  ('of', 'reports'),
#  ('of', 'possible'),
#  ('possible', 'of'),
#  ('possible', '``'),
#  ('``', 'possible'),
#  ('``', 'irregularities'),
#  ('irregularities', '``'),
#  ('irregularities', "''"),
#  ("''", 'irregularities'),
#  ("''", 'in'),
#  ('in', "''"),
#  ('in', 'the'),
#  ('the', 'in'),
#  ('the', 'hard-fought'),
#  ('hard-fought', 'the'),
#  ('hard-fought', 'primary'),
#  ('primary', 'hard-fought'),
#  ('primary', 'which'),
#  ('which', 'primary'),
#  ('which', 'was'),
#  ('was', 'which'),
#  ('was', 'won'),
#  ('won', 'was'),
#  ('won', 'by'),
#  ('by', 'won'),
#  ('by', 'Mayor-nominate'),
#  ('Mayor-nominate', 'by'),
#  ('Mayor-nominate', 'Ivan'),
#  ('Ivan', 'Mayor-nominate'),
#  ('Ivan', 'Allen'),
#  ('Allen', 'Ivan'),
#  ('Allen', 'Jr.'),
#  ('a', 'Only'),
#  ('a', 'relative'),
#  ('relative', 'a'),
#  ('relative', 'handful'),
#  ('handful', 'relative'),
#  ('handful', 'of'),
#  ('of', 'handful'),
#  ('of', 'such'),
#  ('such', 'of'),
#  ('such', 'reports'),
#  ('reports', 'such'),
#  ('reports', 'was'),
#  ('was', 'reports'),
#  ('was', 'received'),
#  ('received', 'was'),
#  ('received', "''"),
#  ("''", 'received'),
#  ("''", ','),
#  (',', "''"),
#  (',', 'the'),
#  ('the', ','),
#  ('the', 'jury'),
#  ('jury', 'the'),
#  ('jury', 'said'),
#  ('said', 'jury'),
#  ('said', ','),
#  (',', 'said'),
#  (',', '``'),
#  ('``', ','),
#  ('``', 'considering'),
#  ('considering', '``'),
#  ('considering', 'the'),
#  ('the', 'considering'),
#  ('the', 'widespread'),
#  ('widespread', 'the'),
#  ('widespread', 'interest'),
#  ('interest', 'widespread'),
#  ('interest', 'in'),
#  ('in', 'interest'),
#  ('in', 'the'),
#  ('the', 'in'),
#  ('the', 'election'),
#  ('election', 'the'),
#  ('election', ','),
#  (',', 'election'),
#  (',', 'the'),
#  ('the', ','),
#  ('the', 'number'),
#  ('number', 'the'),
#  ('number', 'of'),
#  ('of', 'number'),
#  ('of', 'voters'),
#  ('voters', 'of'),
#  ('voters', 'and'),
#  ('and', 'voters'),
#  ('and', 'the'),
#  ('the', 'and'),
#  ('the', 'size'),
#  ('size', 'the'),
#  ('size', 'of'),
#  ('of', 'size'),
#  ('of', 'this'),
#  ('this', 'of'),
#  ('this', 'city'),
#  ('city', 'this'),
#  ('city', "''"),
#  ('said', 'jury'),
#  ('said', 'it'),
#  ('it', 'said'),
#  ('it', 'did'),
#  ('did', 'it'),
#  ('did', 'find'),
#  ('find', 'did'),
#  ('find', 'that'),
#  ('that', 'find'),
#  ('that', 'many'),
#  ('many', 'that'),
#  ('many', 'of'),
#  ('of', 'many'),
#  ('of', "Georgia's"),
#  ("Georgia's", 'of'),
#  ("Georgia's", 'registration'),
#  ('registration', "Georgia's"),
#  ('registration', 'and'),
#  ('and', 'registration'),
#  ('and', 'election'),
#  ('election', 'and'),
#  ('election', 'laws'),
#  ('laws', 'election'),
#  ('laws', '``'),
#  ('``', 'laws'),
#  ('``', 'are'),
#  ('are', '``'),
#  ('are', 'outmoded'),
#  ('outmoded', 'are'),
#  ('outmoded', 'or'),
#  ('or', 'outmoded'),
#  ('or', 'inadequate'),
#  ('inadequate', 'or'),
#  ('inadequate', 'and'),
#  ('and', 'inadequate'),
#  ('and', 'often'),
#  ('often', 'and'),
#  ('often', 'ambiguous'),
#  ('ambiguous', 'often'),
#  ('ambiguous', "''"),
#  ('that', 'recommended'),
#  ('that', 'Fulton'),
#  ('Fulton', 'that'),
#  ('Fulton', 'legislators'),
#  ('legislators', 'Fulton'),
#  ('legislators', 'act'),
#  ('act', 'legislators'),
#  ('act', '``'),
#  ('``', 'act'),
#  ('``', 'to'),
#  ('to', '``'),
#  ('to', 'have'),
#  ('have', 'to'),
#  ('have', 'these'),
#  ('these', 'have'),
#  ('these', 'laws'),
#  ('laws', 'these'),
#  ('laws', 'studied'),
#  ('studied', 'laws'),
#  ('studied', 'and'),
#  ('and', 'studied'),
#  ('and', 'revised'),
#  ('revised', 'and'),
#  ('revised', 'to'),
#  ('to', 'revised'),
#  ('to', 'the'),
#  ('the', 'to'),
#  ('the', 'end'),
#  ('end', 'the'),
#  ('end', 'of'),
#  ('of', 'end'),
#  ('of', 'modernizing'),
#  ('modernizing', 'of'),
#  ('modernizing', 'and'),
#  ('and', 'modernizing'),
#  ('and', 'improving'),
#  ('improving', 'and'),
#  ('improving', 'them'),
#  ('them', 'improving'),
#  ('them', "''"),
#  ('jury', 'grand'),
#  ('jury', 'commented'),
#  ('commented', 'jury'),
#  ('commented', 'on'),
#  ('on', 'commented'),
#  ('on', 'a'),
#  ('a', 'on'),
#  ('a', 'number'),
#  ('number', 'a'),
#  ('number', 'of'),
#  ('of', 'number'),
#  ('of', 'other'),
#  ('other', 'of'),
#  ('other', 'topics'),
#  ('topics', 'other'),
#  ('topics', ','),
#  (',', 'topics'),
#  (',', 'among'),
#  ('among', ','),
#  ('among', 'them'),
#  ('them', 'among'),
#  ('them', 'the'),
#  ('the', 'them'),
#  ('the', 'Atlanta'),
#  ('Atlanta', 'the'),
#  ('Atlanta', 'and'),
#  ('and', 'Atlanta'),
#  ('and', 'Fulton'),
#  ('Fulton', 'and'),
#  ('Fulton', 'County'),
#  ('County', 'Fulton'),
#  ('County', 'purchasing'),
#  ('purchasing', 'County'),
#  ('purchasing', 'departments'),
#  ('departments', 'purchasing'),
#  ('departments', 'which'),
#  ('which', 'departments'),
#  ('which', 'it'),
#  ('it', 'which'),
#  ('it', 'said'),
#  ('said', 'it'),
#  ('said', '``'),
#  ('``', 'said'),
#  ('``', 'are'),
#  ('are', '``'),
#  ('are', 'well'),
#  ('well', 'are'),
#  ('well', 'operated'),
#  ('operated', 'well'),
#  ('operated', 'and'),
#  ('and', 'operated'),
#  ('and', 'follow'),
#  ('follow', 'and'),
#  ('follow', 'generally'),
#  ('generally', 'follow'),
#  ('generally', 'accepted'),
#  ('accepted', 'generally'),
#  ('accepted', 'practices'),
#  ('practices', 'accepted'),
#  ('practices', 'which'),
#  ('which', 'practices'),
#  ('which', 'inure'),
#  ('inure', 'which'),
#  ('inure', 'to'),
#  ('to', 'inure'),
#  ('to', 'the'),
#  ('the', 'to'),
#  ('the', 'best'),
#  ('best', 'the'),
#  ('best', 'interest'),
#  ('interest', 'best'),
#  ('interest', 'of'),
#  ('of', 'interest'),
#  ('of', 'both'),
#  ('both', 'of'),
#  ('both', 'governments'),
#  ('governments', 'both'),
#  ('governments', "''"),
#  ('the', ','),
#  ('the', 'jury'),
#  ('jury', 'the'),
#  ('jury', 'said'),
#  ('said', 'jury'),
#  ('said', 'it'),
#  ('it', 'said'),
#  ('it', 'believes'),
#  ('believes', 'it'),
#  ('believes', '``'),
#  ('``', 'believes'),
#  ('``', 'these'),
#  ('these', '``'),
#  ('these', 'two'),
#  ('two', 'these'),
#  ('two', 'offices'),
#  ('offices', 'two'),
#  ('offices', 'should'),
#  ('should', 'offices'),
#  ('should', 'be'),
#  ('be', 'should'),
#  ('be', 'combined'),
#  ('combined', 'be'),
#  ('combined', 'to'),
#  ('to', 'combined'),
#  ('to', 'achieve'),
#  ('achieve', 'to'),
#  ('achieve', 'greater'),
#  ('greater', 'achieve'),
#  ('greater', 'efficiency'),
#  ('efficiency', 'greater'),
#  ('efficiency', 'and'),
#  ('and', 'efficiency'),
#  ('and', 'reduce'),
#  ('reduce', 'and'),
#  ('reduce', 'the'),
#  ('the', 'reduce'),
#  ('the', 'cost'),
#  ('cost', 'the'),
#  ('cost', 'of'),
#  ('of', 'cost'),
#  ('of', 'administration'),
#  ('administration', 'of'),
#  ('administration', "''"),
#  ('Purchasing', 'City'),
#  ('Purchasing', 'Department'),
#  ('Department', 'Purchasing'),
#  ('Department', ','),
#  (',', 'Department'),
#  (',', 'the'),
#  ('the', ','),
#  ('the', 'jury'),
#  ('jury', 'the'),
#  ('jury', 'said'),
#  ('said', 'jury'),
#  ('said', ','),
#  (',', 'said'),
#  (',', '``'),
#  ('``', ','),
#  ('``', 'is'),
#  ('is', '``'),
#  ('is', 'lacking'),
#  ('lacking', 'is'),
#  ('lacking', 'in'),
#  ('in', 'lacking'),
#  ('in', 'experienced'),
#  ('experienced', 'in'),
#  ('experienced', 'clerical'),
#  ('clerical', 'experienced'),
#  ('clerical', 'personnel'),
#  ('personnel', 'clerical'),
#  ('personnel', 'as'),
#  ('as', 'personnel'),
#  ('as', 'a'),
#  ('a', 'as'),
#  ('a', 'result'),
#  ('result', 'a'),
#  ('result', 'of'),
#  ('of', 'result'),
#  ('of', 'city'),
#  ('city', 'of'),
#  ('city', 'personnel'),
#  ('personnel', 'city'),
#  ('personnel', 'policies'),
#  ('policies', 'personnel'),
#  ('policies', "''"),
#  ('that', 'urged'),
#  ('that', 'the'),
#  ('the', 'that'),
#  ('the', 'city'),
#  ('city', 'the'),
#  ('city', '``'),
#  ('``', 'city'),
#  ('``', 'take'),
#  ('take', '``'),
#  ('take', 'steps'),
#  ('steps', 'take'),
#  ('steps', 'to'),
#  ('to', 'steps'),
#  ('to', 'remedy'),
#  ('remedy', 'to'),
#  ('remedy', "''"),
#  ("''", 'remedy'),
#  ("''", 'this'),
#  ('this', "''"),
#  ('this', 'problem'),
#  ("Georgia's", 'of'),
#  ("Georgia's", 'automobile'),
#  ('automobile', "Georgia's"),
#  ('automobile', 'title'),
#  ('title', 'automobile'),
#  ('title', 'law'),
#  ('law', 'title'),
#  ('law', 'was'),
#  ('was', 'law'),
#  ('was', 'also'),
#  ('also', 'was'),
#  ('also', 'recommended'),
#  ('recommended', 'also'),
#  ('recommended', 'by'),
#  ('by', 'recommended'),
#  ('by', 'the'),
#  ('the', 'by'),
#  ('the', 'outgoing'),
#  ('outgoing', 'the'),
#  ('outgoing', 'jury'),
#  ('that', 'urged'),
#  ('that', 'the'),
#  ('the', 'that'),
#  ('the', 'next'),
#  ('next', 'the'),
#  ('next', 'Legislature'),
#  ('Legislature', 'next'),
#  ('Legislature', '``'),
#  ('``', 'Legislature'),
#  ('``', 'provide'),
#  ('provide', '``'),
#  ('provide', 'enabling'),
#  ('enabling', 'provide'),
#  ('enabling', 'funds'),
#  ('funds', 'enabling'),
#  ('funds', 'and'),
#  ('and', 'funds'),
#  ('and', 're-set'),
#  ('re-set', 'and'),
#  ('re-set', 'the'),
#  ('the', 're-set'),
#  ('the', 'effective'),
#  ('effective', 'the'),
#  ('effective', 'date'),
#  ('date', 'effective'),
#  ('date', 'so'),
#  ('so', 'date'),
#  ('so', 'that'),
#  ('that', 'so'),
#  ('that', 'an'),
#  ('an', 'that'),
#  ('an', 'orderly'),
#  ('orderly', 'an'),
#  ('orderly', 'implementation'),
#  ('implementation', 'orderly'),
#  ('implementation', 'of'),
#  ('of', 'implementation'),
#  ('of', 'the'),
#  ('the', 'of'),
#  ('the', 'law'),
#  ('law', 'the'),
#  ('law', 'may'),
#  ('may', 'law'),
#  ('may', 'be'),
#  ('be', 'may'),
#  ('be', 'effected'),
#  ('effected', 'be'),
#  ('effected', "''"),
#  ('jury', 'grand'),
#  ('jury', 'took'),
#  ('took', 'jury'),
#  ('took', 'a'),
#  ('a', 'took'),
#  ('a', 'swipe'),
#  ('swipe', 'a'),
#  ('swipe', 'at'),
#  ('at', 'swipe'),
#  ('at', 'the'),
#  ('the', 'at'),
#  ('the', 'State'),
#  ('State', 'the'),
#  ('State', 'Welfare'),
#  ('Welfare', 'State'),
#  ('Welfare', "Department's"),
#  ("Department's", 'Welfare'),
#  ("Department's", 'handling'),
#  ('handling', "Department's"),
#  ('handling', 'of'),
#  ('of', 'handling'),
#  ('of', 'federal'),
#  ('federal', 'of'),
#  ('federal', 'funds'),
#  ('funds', 'federal'),
#  ('funds', 'granted'),
#  ('granted', 'funds'),
#  ('granted', 'for'),
#  ('for', 'granted'),
#  ('for', 'child'),
#  ('child', 'for'),
#  ('child', 'welfare'),
#  ('welfare', 'child'),
#  ('welfare', 'services'),
#  ('services', 'welfare'),
#  ('services', 'in'),
#  ('in', 'services'),
#  ('in', 'foster'),
#  ('foster', 'in'),
#  ('foster', 'homes'),
#  ('is', 'This'),
#  ('is', 'one'),
#  ('one', 'is'),
#  ('one', 'of'),
#  ('of', 'one'),
#  ('of', 'the'),
#  ('the', 'of'),
#  ('the', 'major'),
#  ('major', 'the'),
#  ('major', 'items'),
#  ('items', 'major'),
#  ('items', 'in'),
#  ('in', 'items'),
#  ('in', 'the'),
#  ('the', 'in'),
#  ('the', 'Fulton'),
#  ('Fulton', 'the'),
#  ('Fulton', 'County'),
#  ('County', 'Fulton'),
#  ('County', 'general'),
#  ('general', 'County'),
#  ('general', 'assistance'),
#  ('assistance', 'general'),
#  ('assistance', 'program'),
#  ('program', 'assistance'),
#  ('program', "''"),
#  ("''", 'program'),
#  ("''", ','),
#  (',', "''"),
#  (',', 'the'),
#  ('the', ','),
#  ('the', 'jury'),
#  ('jury', 'the'),
#  ('jury', 'said'),
#  ('said', 'jury'),
#  ('said', ','),
#  (',', 'said'),
#  (',', 'but'),
#  ('but', ','),
#  ('but', 'the'),
#  ('the', 'but'),
#  ('the', 'State'),
#  ('State', 'the'),
#  ('State', 'Welfare'),
#  ('Welfare', 'State'),
#  ('Welfare', 'Department'),
#  ('Department', 'Welfare'),
#  ('Department', '``'),
#  ('``', 'Department'),
#  ('``', 'has'),
#  ('has', '``'),
#  ('has', 'seen'),
#  ('seen', 'has'),
#  ('seen', 'fit'),
#  ('fit', 'seen'),
#  ('fit', 'to'),
#  ('to', 'fit'),
#  ('to', 'distribute'),
#  ('distribute', 'to'),
#  ('distribute', 'these'),
#  ('these', 'distribute'),
#  ('these', 'funds'),
#  ('funds', 'these'),
#  ('funds', 'through'),
#  ('through', 'funds'),
#  ('through', 'the'),
#  ('the', 'through'),
#  ('the', 'welfare'),
#  ('welfare', 'the'),
#  ('welfare', 'departments'),
#  ('departments', 'welfare'),
#  ('departments', 'of'),
#  ('of', 'departments'),
#  ('of', 'all'),
#  ('all', 'of'),
#  ('all', 'the'),
#  ('the', 'all'),
#  ('the', 'counties'),
#  ('counties', 'the'),
#  ('counties', 'in'),
#  ('in', 'counties'),
#  ('in', 'the'),
#  ('the', 'in'),
#  ('the', 'state'),
#  ('state', 'the'),
#  ('state', 'with'),
#  ('with', 'state'),
#  ('with', 'the'),
#  ('the', 'with'),
#  ('the', 'exception'),
#  ('exception', 'the'),
#  ('exception', 'of'),
#  ('of', 'exception'),
#  ('of', 'Fulton'),
#  ('Fulton', 'of'),
#  ('Fulton', 'County'),
#  ('County', 'Fulton'),
#  ('County', ','),
#  (',', 'County'),
#  (',', 'which'),
#  ('which', ','),
#  ('which', 'receives'),
#  ('receives', 'which'),
#  ('receives', 'none'),
#  ('none', 'receives'),
#  ('none', 'of'),
#  ('of', 'none'),
#  ('of', 'this'),
#  ('this', 'of'),
#  ('this', 'money'),
#  ('said', 'jurors'),
#  ('said', 'they'),
#  ('they', 'said'),
#  ('they', 'realize'),
#  ('realize', 'they'),
#  ('realize', '``'),
#  ('``', 'realize'),
#  ('``', 'a'),
#  ('a', '``'),
#  ('a', 'proportionate'),
#  ('proportionate', 'a'),
#  ('proportionate', 'distribution'),
#  ('distribution', 'proportionate'),
#  ('distribution', 'of'),
#  ('of', 'distribution'),
#  ('of', 'these'),
#  ('these', 'of'),
#  ('these', 'funds'),
#  ('funds', 'these'),
#  ('funds', 'might'),
#  ('might', 'funds'),
#  ('might', 'disable'),
#  ('disable', 'might'),
#  ('disable', 'this'),
#  ('this', 'disable'),
#  ('this', 'program'),
#  ('program', 'this'),
#  ('program', 'in'),
#  ('in', 'program'),
#  ('in', 'our'),
#  ('our', 'in'),
#  ('our', 'less'),
#  ('less', 'our'),
#  ('less', 'populous'),
#  ('populous', 'less'),
#  ('populous', 'counties'),
#  ('counties', 'populous'),
#  ('counties', "''"),
#  ('``', ','),
#  ('``', 'we'),
#  ('we', '``'),
#  ('we', 'feel'),
#  ('feel', 'we'),
#  ('feel', 'that'),
#  ('that', 'feel'),
#  ('that', 'in'),
#  ('in', 'that'),
#  ('in', 'the'),
#  ('the', 'in'),
#  ('the', 'future'),
#  ('future', 'the'),
#  ('future', 'Fulton'),
#  ('Fulton', 'future'),
#  ('Fulton', 'County'),
#  ('County', 'Fulton'),
#  ('County', 'should'),
#  ('should', 'County'),
#  ('should', 'receive'),
#  ('receive', 'should'),
#  ('receive', 'some'),
#  ('some', 'receive'),
#  ('some', 'portion'),
#  ('portion', 'some'),
#  ('portion', 'of'),
#  ('of', 'portion'),
#  ('of', 'these'),
#  ('these', 'of'),
#  ('these', 'available'),
#  ('available', 'these'),
#  ('available', 'funds'),
#  ('funds', 'available'),
#  ('funds', "''"),
#  ("''", 'funds'),
#  ("''", ','),
#  (',', "''"),
#  (',', 'the'),
#  ('the', ','),
#  ('the', 'jurors'),
#  ('jurors', 'the'),
#  ('jurors', 'said'),
#  ('to', 'Failure'),
#  ('to', 'do'),
#  ('do', 'to'),
#  ('do', 'this'),
#  ('this', 'do'),
#  ('this', 'will'),
#  ('will', 'this'),
#  ('will', 'continue'),
#  ('continue', 'will'),
#  ('continue', 'to'),
#  ('to', 'continue'),
#  ('to', 'place'),
#  ('place', 'to'),
#  ('place', 'a'),
#  ('a', 'place'),
#  ('a', 'disproportionate'),
#  ('disproportionate', 'a'),
#  ('disproportionate', 'burden'),
#  ('burden', 'disproportionate'),
#  ('burden', "''"),
#  ("''", 'burden'),
#  ("''", 'on'),
#  ('on', "''"),
#  ('on', 'Fulton'),
#  ('Fulton', 'on'),
#  ('Fulton', 'taxpayers'),
#  ('also', 'jury'),
#  ('also', 'commented'),
#  ('commented', 'also'),
#  ('commented', 'on'),
#  ('on', 'commented'),
#  ('on', 'the'),
#  ('the', 'on'),
#  ('the', 'Fulton'),
#  ('Fulton', 'the'),
#  ('Fulton', "ordinary's"),
#  ("ordinary's", 'Fulton'),
#  ("ordinary's", 'court'),
#  ('court', "ordinary's"),
#  ('court', 'which'),
#  ('which', 'court'),
#  ('which', 'has'),
#  ('has', 'which'),
#  ('has', 'been'),
#  ('been', 'has'),
#  ('been', 'under'),
#  ('under', 'been'),
#  ('under', 'fire'),
#  ('fire', 'under'),
#  ('fire', 'for'),
#  ('for', 'fire'),
#  ('for', 'its'),
#  ('its', 'for'),
#  ('its', 'practices'),
#  ('practices', 'its'),
#  ('practices', 'in'),
#  ('in', 'practices'),
#  ('in', 'the'),
#  ('the', 'in'),
#  ('the', 'appointment'),
#  ('appointment', 'the'),
#  ('appointment', 'of'),
#  ('of', 'appointment'),
#  ('of', 'appraisers'),
#  ('appraisers', 'of'),
#  ('appraisers', ','),
#  (',', 'appraisers'),
#  (',', 'guardians'),
#  ('guardians', ','),
#  ('guardians', 'and'),
#  ('and', 'guardians'),
#  ('and', 'administrators'),
#  ('administrators', 'and'),
#  ('administrators', 'and'),
#  ('and', 'administrators'),
#  ('and', 'the'),
#  ('the', 'and'),
#  ('the', 'awarding'),
#  ('awarding', 'the'),
#  ('awarding', 'of'),
#  ('of', 'awarding'),
#  ('of', 'fees'),
#  ('fees', 'of'),
#  ('fees', 'and'),
#  ('and', 'fees'),
#  ('and', 'compensation'),
#  ('said', 'jury'),
#  ('said', 'it'),
#  ('it', 'said'),
#  ('it', 'found'),
#  ('found', 'it'),
#  ('found', 'the'),
#  ('the', 'found'),
#  ('the', 'court'),
#  ('court', 'the'),
#  ('court', '``'),
#  ('``', 'court'),
#  ('``', 'has'),
#  ('has', '``'),
#  ('has', 'incorporated'),
#  ('incorporated', 'has'),
#  ('incorporated', 'into'),
#  ('into', 'incorporated'),
#  ('into', 'its'),
#  ('its', 'into'),
#  ('its', 'operating'),
#  ('operating', 'its'),
#  ('operating', 'procedures'),
#  ('procedures', 'operating'),
#  ('procedures', 'the'),
#  ('the', 'procedures'),
#  ('the', 'recommendations'),
#  ('recommendations', 'the'),
#  ('recommendations', "''"),
#  ("''", 'recommendations'),
#  ("''", 'of'),
#  ('of', "''"),
#  ('of', 'two'),
#  ('two', 'of'),
#  ('two', 'previous'),
#  ('previous', 'two'),
#  ('previous', 'grand'),
#  ('grand', 'previous'),
#  ('grand', 'juries'),
#  ('juries', 'grand'),
#  ('juries', ','),
#  (',', 'juries'),
#  (',', 'the'),
#  ('the', ','),
#  ('the', 'Atlanta'),
#  ('Atlanta', 'the'),
#  ('Atlanta', 'Bar'),
#  ('Bar', 'Atlanta'),
#  ('Bar', 'Association'),
#  ('Association', 'Bar'),
#  ('Association', 'and'),
#  ('and', 'Association'),
#  ('and', 'an'),
#  ('an', 'and'),
#  ('an', 'interim'),
#  ('interim', 'an'),
#  ('interim', 'citizens'),
#  ('citizens', 'interim'),
#  ('citizens', 'committee'),
#  ('actions', 'These'),
#  ('actions', 'should'),
#  ('should', 'actions'),
#  ('should', 'serve'),
#  ('serve', 'should'),
#  ('serve', 'to'),
#  ('to', 'serve'),
#  ('to', 'protect'),
#  ('protect', 'to'),
#  ('protect', 'in'),
#  ('in', 'protect'),
#  ('in', 'fact'),
#  ('fact', 'in'),
#  ('fact', 'and'),
#  ('and', 'fact'),
#  ('and', 'in'),
#  ('in', 'and'),
#  ('in', 'effect'),
#  ('effect', 'in'),
#  ('effect', 'the'),
#  ('the', 'effect'),
#  ('the', "court's"),
#  ("court's", 'the'),
#  ("court's", 'wards'),
#  ('wards', "court's"),
#  ('wards', 'from'),
#  ('from', 'wards'),
#  ('from', 'undue'),
#  ('undue', 'from'),
#  ('undue', 'costs'),
#  ('costs', 'undue'),
#  ('costs', 'and'),
#  ('and', 'costs'),
#  ('and', 'its'),
#  ('its', 'and'),
#  ('its', 'appointed'),
#  ('appointed', 'its'),
#  ('appointed', 'and'),
#  ('and', 'appointed'),
#  ('and', 'elected'),
#  ('elected', 'and'),
#  ('elected', 'servants'),
#  ('servants', 'elected'),
#  ('servants', 'from'),
#  ('from', 'servants'),
#  ('from', 'unmeritorious'),
#  ...]

# %%
#testing the method
batch_size = 2 # mini-batch size
skip_grams_id = [(word2index[skip_gram[0]], word2index[skip_gram[1]]) for skip_gram in skip_grams]
input_batch, target_batch, cooc_batch, weighting_batch = random_batch(batch_size, corpus, skip_grams_id, X_ik, weighting_dic)

print("Input: ", input_batch)
print("Target: ", target_batch)
print("Cooc: ", cooc_batch)
print("Weighting: ", weighting_batch)

#we will convert them to tensor during training, so don't worry...
# Out:
# Input:  [[13377]
#  [  624]]
# Target:  [[ 9539]
#  [14283]]
# Cooc:  [[1.09861229]
#  [0.69314718]]
# Weighting:  [[0.07208434]
#  [0.05318296]]

# %% [markdown]
# ## 4. Model
#
# <img src ="figures/glove.png">

# %%
class GloVe(nn.Module):
    
    def __init__(self, voc_size,embedding_size, word2index):
        super(GloVe,self).__init__()
        self.embedding_v = nn.Embedding(voc_size, embedding_size) # center embedding
        self.embedding_u = nn.Embedding(voc_size, embedding_size) # out embedding
        
        self.v_bias = nn.Embedding(voc_size, 1)
        self.u_bias = nn.Embedding(voc_size, 1)

        self.word2index = word2index
        
    def forward(self, center_words, target_words, coocs, weighting):
        center_embeds = self.embedding_v(center_words) # [batch_size, 1, emb_size]
        target_embeds = self.embedding_u(target_words) # [batch_size, 1, emb_size]
        
        center_bias = self.v_bias(center_words).squeeze(1)
        target_bias = self.u_bias(target_words).squeeze(1)
        
        inner_product = target_embeds.bmm(center_embeds.transpose(1, 2)).squeeze(2)
        #[batch_size, 1, emb_size] @ [batch_size, emb_size, 1] = [batch_size, 1, 1] = [batch_size, 1]
        
        #note that coocs already got log
        loss = weighting*torch.pow(inner_product +center_bias + target_bias - coocs, 2)
        
        return torch.sum(loss)
    
    def get_embed(self, word):
        word2index = self.word2index
        
        try:
            index = word2index[word]
        except:
            index = word2index['<UNK>']
            
        word = torch.LongTensor([index])
        
        embed_c = self.embedding_v(word)
        embed_o = self.embedding_u(word)
        embed   = (embed_c + embed_o) / 2
        
        return embed[0][0].item(), embed[0][1].item()

# %% [markdown]
# ## 5. Training

# %%
batch_size     = 10 # mini-batch size
embedding_size = 2 #so we can later plot
model          = GloVe(voc_size, embedding_size, word2index)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
def epoch_time(start_time, end_time):
    elapsed_time = end_time - start_time
    elapsed_mins = int(elapsed_time / 60)
    elapsed_secs = int(elapsed_time - (elapsed_mins * 60))
    return elapsed_mins, elapsed_secs

# %%
import time

# Training
num_epochs = 1000
start = time.time()
for epoch in range(num_epochs):
    
    # start = time.time()
    
    input_batch, target_batch, cooc_batch, weighting_batch = random_batch(batch_size, corpus, skip_grams_id, X_ik, weighting_dic)
    input_batch  = torch.LongTensor(input_batch)         #[batch_size, 1]
    target_batch = torch.LongTensor(target_batch)        #[batch_size, 1]
    cooc_batch   = torch.FloatTensor(cooc_batch)         #[batch_size, 1]
    weighting_batch = torch.FloatTensor(weighting_batch) #[batch_size, 1]
    
    optimizer.zero_grad()
    loss = model(input_batch, target_batch, cooc_batch, weighting_batch)
    
    loss.backward()
    optimizer.step()
    
    end = time.time()
    
    epoch_mins, epoch_secs = epoch_time(start, end)

    if (epoch + 1) % 100 == 0:
        print(f"Epoch: {epoch + 1} | cost: {loss:.6f} | time: {epoch_mins}m {epoch_secs}s")

print(f"\nComplete: \nTotal Loss: {loss:2.2f} | Time Taken: {epoch_mins} minutes and {epoch_secs} seconds")
# Out:
# Epoch: 100 | cost: 21.288506 | time: 0m 2s
# Epoch: 200 | cost: 68.209862 | time: 0m 4s
# Epoch: 300 | cost: 7.395502 | time: 0m 6s
# Epoch: 400 | cost: 4.879284 | time: 0m 8s
# Epoch: 500 | cost: 5.864134 | time: 0m 10s
# Epoch: 600 | cost: 6.610865 | time: 0m 12s
# Epoch: 700 | cost: 111.987602 | time: 0m 14s
# Epoch: 800 | cost: 7.311846 | time: 0m 16s
# Epoch: 900 | cost: 46.752598 | time: 0m 17s
# Epoch: 1000 | cost: 10.783981 | time: 0m 19s
#
# Complete:
# Total Loss: 10.78 | Time Taken: 0 minutes and 19 seconds

# %%
def open_file(path_to_file):
    content = []  # Initialize content to an empty list to avoid returning None
    try:
        with open(path_to_file, 'r') as file:
            content = file.readlines()  # Read all lines of the file into a list
    except FileNotFoundError:
        print(f"The file {path_to_file} does not exist.")  # File not found error
    except Exception as e:
        print(f"An error occurred: {e}")  # Handle any other exceptions (e.g., permission issues)

    return content  # Return content even if it's empty, but not None

# %%
file_path = "file/word-test.v1.1.txt"

content = open_file(file_path)

semantic = []
syntatic = []

current_test = semantic
for sent in content:
    if sent[0] == ':':
        current_test = syntatic
        continue
    
    current_test.append(sent.strip())

# %%
vector_space = []

for word in vocab:
    vector_space.append(model.get_embed(word))

vector_space = np.array(vector_space)

# %%
#scipy version
from scipy import spatial

def cos_sim(a, b):
    norm_a = a / np.linalg.norm(a)  # Normalize vector a
    norm_b = b / np.linalg.norm(b)  # Normalize vector b
    return 1 - spatial.distance.cosine(norm_a, norm_b)  # Cosine similarity after normalization


def cos_sim_scores(vector_space, target_vector):
    scores = []
    for each_vect in vector_space:
        scores.append(cos_sim(target_vector, each_vect))

    return np.array(scores)

def similarity(model, test_data):
    words = test_data.split(" ")
    embeddings = [np.array(model.get_embed(word)) for word in words[:3]]  # Precompute embeddings for all words
    embed0, embed1, embed2 = embeddings  # Unpack embeddings
    similar_vector = embed1 - embed0 + embed2  # Perform vector arithmetic

    similarity_scores = cos_sim_scores(vector_space, similar_vector)
    max_score_idx = np.argmax(similarity_scores)
    similar_word = index2word[max_score_idx]

    return similar_word == words[3]  # Directly return the result

# %% [markdown]
# Semantic accuracy

# %%
sem_total = len(semantic)
sem_correct = 0
for sent in semantic:
    if similarity(model, sent):
        sem_correct += 1

sem_accuracy = sem_correct / sem_total
print(f"Semantic accuracy: {sem_accuracy:2.2f}")
# Out:
# Semantic accuracy: 0.00

# %% [markdown]
# Syntactic Accuracy

# %%
syn_total = len(syntatic)
syn_correct = 0
for sent in syntatic:
    if similarity(model, sent):
        syn_correct += 1

syn_accuracy = syn_correct / syn_total
print(f"Syntatic accuracy: {syn_accuracy:2.2f}")
# Out:
# Syntatic accuracy: 0.00

# %% [markdown]
# Similarity Accuracy

# %%
file_path = "file/wordsim_similarity_goldstandard.txt"

content = open_file(file_path)

sim_data = []

for sent in content:
    sim_data.append(sent.strip())

# %%
def compute_similarity(model, test_data):
    words = test_data.split("\t")

    embed0 = np.array(model.get_embed(words[0].strip()))
    embed1 = np.array(model.get_embed(words[1].strip()))

    similarity_model = embed1 @ embed0.T
    similarity_provided = float(words[2].strip())

    return similarity_provided, similarity_model

# %%
ds_scores = []
model_scores = []
for sent in sim_data:
    ds_score, model_score = compute_similarity(model, sent)

    ds_scores.append(ds_score)
    model_scores.append(model_score)

# %%
from scipy.stats import spearmanr

correlation = spearmanr(ds_scores, model_scores)[0]

print(f"Correlation between the dataset similarity metrics and models’ dot product is {correlation:2.2f}.")
# Out:
# Correlation between the dataset similarity metrics and models’ dot product is 0.01.

# %% [markdown]
# Save model

# %%
import torch
import pickle

# Define the folder where want to save the files
model_folder = 'model'  # Change this to your desired folder path

# Save the model's state_dict
torch.save(model.state_dict(), f'{model_folder}/glove.model')

# Save the arguments (such as voc_size, emb_size, word2index)
glove_args = {
    'voc_size': voc_size,
    'embedding_size': embedding_size,
    'word2index': word2index,
}
with open(f'{model_folder}/glove.args', 'wb') as f:
    pickle.dump(glove_args, f)

print(f"Model and arguments saved to {model_folder}")
# Out:
# Model and arguments saved to model

# %%
import torch
import pickle

# Define the folder where the files are saved
model_folder = 'model'  # Change this to the folder where you saved the files

# Load the arguments from the pickle file
with open(f'{model_folder}/glove.args', 'rb') as f:
    glove_args = pickle.load(f)

# Define the model class and initialize it with the loaded arguments
# Make sure the model class and arguments match the training code
model_glove = GloVe(**glove_args)  # Assuming you have a GloVe model class

# Now, load the model weights (this should be from glove.model, not glove.args)
model_glove.load_state_dict(torch.load(f'{model_folder}/glove.model'))

# Now the model is loaded with the arguments and weights, and you're ready to use it
model_glove.eval()  # Set the model to evaluation mode if you're not training

print("Model loaded successfully.")
# Out:
# Model loaded successfully.
# C:\Users\Ekkar\AppData\Local\Temp\ipykernel_13296\4237514619.py:16: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model_glove.load_state_dict(torch.load(f'{model_folder}/glove.model'))

# %%
model_glove.get_embed('sad')
# Out:
# (-0.25097179412841797, 0.6753951907157898)

# %% [markdown]
# ## 6. Plotting the embeddings

# %%
#list of vocabs
vocab[:10]

# %%
word = vocab[0]

# %%
#numericalization
id = word2index[word]
id

# %%
id_tensor = torch.LongTensor([id])
id_tensor

# %%
#get the embedding by averaging
v_embed = model.embedding_v(id_tensor)
u_embed = model.embedding_u(id_tensor)

v_embed, u_embed

# %%
#average to get the word embedding
word_embed = (v_embed + u_embed) / 2
word_embed[0][1]

# %%
#let's write a function to get embedding given a word
def get_embed(word):
    id_tensor = torch.LongTensor([word2index[word]])
    v_embed = model.embedding_v(id_tensor)
    u_embed = model.embedding_u(id_tensor) 
    word_embed = (v_embed + u_embed) / 2 
    x, y = word_embed[0][0].item(), word_embed[0][1].item()

    return x, y

# %%
plt.figure(figsize=(6,3))
for i, word in enumerate(vocab[:20]): #loop each unique vocab
    x, y = get_embed(word)
    plt.scatter(x, y)
    plt.annotate(word, xy=(x, y), xytext=(5, 2), textcoords='offset points')
plt.show()

# %% [markdown]
# ## 7. Cosine similarity
#
# Formally the [Cosine Similarity](https://en.wikipedia.org/wiki/Cosine_similarity) $s$ between two vectors $p$ and $q$ is defined as:
#
# $$s = \frac{p \cdot q}{||p|| ||q||}, \textrm{ where } s \in [-1, 1] $$
#
# If $p$ and $q$ is super similar, the result is 1 otherwise 0.

# %%
vocab

# %%
#let's try similarity between first and second, and second and third
cat          = get_embed('cat')
fruit        = get_embed('fruit')
animal       = get_embed('animal')

# %%
#numpy version
from numpy import dot
from numpy.linalg import norm

def cos_sim(a, b):
    cos_sim = dot(a, b)/(norm(a)*norm(b))
    return cos_sim
    
print(f"cat vs. fruit: ",        cos_sim(cat, fruit))
print(f"cat vs. animal: ",       cos_sim(cat, animal))
print(f"cat vs. cat: ",          cos_sim(cat, cat))

# %%
#scipy version
from scipy import spatial

def cos_sim(a, b):
    cos_sim = 1 - spatial.distance.cosine(a, b)  #distance = 1 - similarlity, because scipy only gives distance
    return cos_sim

print(f"cat vs. fruit: ",     cos_sim(cat, fruit))
print(f"cat vs. animal: ",       cos_sim(cat, animal))
print(f"cat vs. cat: ",          cos_sim(cat, cat))
